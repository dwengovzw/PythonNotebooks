# %% [markdown]
# <img src="images/logodwengo.png" alt="Banner" width="150"/>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
# <h1>RÉGRESSION LINÉAIRE - APPLICATION DE LA COURBE DE TENDANCE - LA POSTE (FICHIER)</h1>    </font>
# </div>

# %% [markdown]
# <div class="alert alert-box alert-success">
# Dans ce notebook, vous trouverez des données dans un fichier sur la distribution postale belge. <br>    - Vous déterminez le degré d'association à l'aide du coefficient de corrélation.<br>    - Vous déterminez l'équation de la droite de régression. <br>    - Tu représentes clairement les données fournies et la droite de régression sur un graphique.</div>

# %% [markdown]
# ### TâcheLe nombre de lettres envoyées chaque année en Belgique connaît une tendance à la baisse. Le nombre de colis envoyés est en plein essor. Vous disposez pour ce notebook d'un fichier CSV contenant des chiffres à ce sujet pour la période 2004-2017. <br>Vous trouverez le fichier dans le dossier `data` : `post.csv`.
# - Lire les données.
# Ensuite, vous déterminez :- le degré de corrélation entre l'année et le nombre de lettres;- le degré de corrélation entre l'année et le nombre de paquets;les équations des droites de tendance pour les lettres et pour les colis, respectivement en fonction de l’année. <br>
# Enfin, représente clairement les données fournies et les lignes de tendance sur un graphique.

# %% [markdown]
# ### Exercice supplémentaireExaminez maintenant les revenus de bpost provenant des lettres et des colis. L’unité des revenus est la même, vous pouvez donc visualiser les deux sur un même graphique. Les revenus des lettres envoyées chaque année en Belgique présentent une tendance à la baisse. Les revenus liés au nombre de colis expédiés augmentent. Les données se trouvent dans le même fichier que celui du premier exercice.
# Ensuite, vous déterminez:- le degré d'association entre l'année et les revenus tirés des lettres ;- le degré de corrélation entre l'année et les revenus des colis;les équations des droites de régression pour les lettres et pour les colis, respectivement en fonction de l'année. <br>
# Enfin, présente clairement les données fournies et les droites de régression sur un seul et même graphique.

# %% [markdown]
# ### Encore une tâche supplémentaireExaminez la relation des revenus des lettres en fonction des revenus des colis.Établissez également une droite de régression et visualisez-la.

# %% [markdown]
# <div>
#     <h2>Liste de références</h2></div>

# %% [markdown]
# [1] Grommen, S. (20 août 2018). Pourquoi Bpost veut bouleverser la distribution du courrier : le déclin du courrier papier en chiffres. <br> &nbsp; &nbsp; &nbsp; &nbsp;https://www.vrt.be/vrtnws/nl/2018/08/20/de-tanende-brievenpost-en-boomende-pakjespost-in-cijfers/

# %% [markdown]
# <img src="images/cclic.png" alt="Banner" align="left" width="100"/><br><br>
# Notebook Python en mathématiques, voir Pensée computationnelle - Programmation en Python de <a href="http://www.aiopschool.be">AI Op School</a>, de F. wyffels, B. Van de Velde et N. Gesquière, sous licence <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution - Pas d’Utilisation Commerciale - Partage dans les Mêmes Conditions 4.0 International</a>.
