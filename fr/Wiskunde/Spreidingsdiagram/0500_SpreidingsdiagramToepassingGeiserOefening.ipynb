# %% [markdown]
# <img src="images/logodwengo.png" alt="Banner" width="150"/>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
# <h1>APPLICATION DIAGRAMME DE DISPERSION: GEYSER OLD FAITHFUL - EXERCICE</h1>    </font>
# </div>

# %% [markdown]
# <div class="alert alert-box alert-success">
# Dans ce notebook, vous présenterez des données relatives à l'activité du geyser Old Faithful.</div>

# %% [markdown]
# ### Importer les modules nécessaires

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib widget
import ipywidgets as widgets

# %% [markdown]
# [![Video Old Faithful](images/oldfaithful.jpg)](https://www.nps.gov/media/video/embed.htm?id=CAC818D4-155D-451F-677DCE1D358B9F71)

# %% [markdown]
# <center> Photo : Old Faithful 2003 ; Daniel Mayer [1].</center>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
# <h2>1. Lecture des données</h2>    </font>
# </div>

# %% [markdown]
# Le geyser Old Faithful dans le parc national de Yellowstone aux États-Unis entre en éruption à intervalles réguliers. <br>Vous lisez un fichier CSV qui contient, pour 272 observations, la durée de l’éruption et le temps d’attente jusqu’à la prochaine éruption en minutes [2]. Vous allez visualiser ces données.<br>Le fichier CSV `oldfaithfulgeiser.csv` se trouve dans le dossier `data`.

# %% [markdown]
# ### Exercice 1.1Lisez le fichier et affichez le résultat.

# %% [markdown]
# ### Exercice 1.2
# Définis maintenant les 2 variables `eruptie` et `wacht` que tu placeras sur les axes. <br>Il s'agit d'examiner si le temps d'attente avant la prochaine éruption dépend de la durée d'une éruption. Réfléchis à la variable à placer sur chaque axe.

# %% [markdown]
# ### Exercice 1.3
# Convertissez ces tableaux pandas en listes NumPy et affichez les listes.

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>2. Visualiser les données</h2>    </font>
# </div>

# %% [markdown]
# Maintenant que vous avez chargé les données et les avez placées dans des listes NumPy, vous pouvez les tracer sur un graphique !

# %% [markdown]
# ### Exercice 2.1
# Déterminez les limites des axes.

# %% [markdown]
# ### Exercice 2.2
# Maintenant que vous connaissez les limites du jeu de données, vous pouvez créer un graphique préliminaire. Essayez de le garder aussi simple que possible !

# %% [markdown]
# Liste de contrôle :
# - La fenêtre de dessin est-elle suffisamment grande ?- L'intervalle est-il adapté aux données ?- As-tu donné un titre au graphique ?- Les axes sont-ils libellés ?

# %% [markdown]
# ### Liste de références

# %% [markdown]
# [1] Mayer, D. (2003). CC BY-SA 3.0, via Wikimedia Commons. <br>       &nbsp; &nbsp; &nbsp; &nbsp; https://commons.wikimedia.org/wiki/File:Old_Faithful_Geyser_at_Yellowstone.JPG <br>[2] Wasserman, L. (2013). All of Statistics. https://www.stat.cmu.edu/~larry/all-of-statistics/<br>

# %% [markdown]
# <img src="images/cclic.png" alt="Banner" align="left" width="100"/><br><br>
# Notebook Python en mathématiques, voir Pensée computationnelle - Programmer en Python de <a href="http://www.aiopschool.be">AI Op School</a>, de F. wyffels & N. Gesquière, sous licence <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution - Pas d'Utilisation Commerciale - Partage dans les Mêmes Conditions 4.0 International</a>.
