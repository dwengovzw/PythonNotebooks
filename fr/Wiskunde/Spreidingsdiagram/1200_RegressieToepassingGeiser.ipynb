# %% [markdown]
# <img src="images/logodwengo.png" alt="Banner" width="150"/>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
# <h1>APPLICATION DU DIAGRAMME DE DISPERSION - RÉGRESSION</h1>        <h2>OLD FAITHFUL GEYSER - EXERCICE</h2>    </font>
# </div>

# %% [markdown]
# <div class="alert alert-box alert-success">
# Dans ce notebook, vous allez déterminer une droite de régression pour les données relatives à l’activité du geyser Old Faitful. Une droite de régression est une droite qui s’ajuste le mieux aux données et reflète une éventuelle tendance contenue dans les données.</div>

# %% [markdown]
# ### Importer les modules nécessaires

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from scipy.optimize import curve_fit                # voor regressie

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
# <h2>1. Importer et visualiser les données</h2>    </font>
# </div>

# %% [markdown]
# Le geyser Old Faithful dans le parc national de Yellowstone aux États-Unis entre en éruption à intervalles réguliers. Vous lisez un fichier CSV contenant, pour 272 observations [1], le temps d’attente entre les éruptions et la durée des éruptions, en minutes. Vous allez visualiser ces données. <br>Le fichier se trouve dans le dossier `data` : `oldfaithfulgeiser.csv`.

# %% [markdown]
# ### ExerciceImportez le fichier et affichez le nuage de points.

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
# <h2>2. Régression linéaire et représentation graphique</h2>    </font>
# </div>

# %% [markdown]
# ### ExerciceRédigez un script Python qui, à l’exécution, affiche la droite de régression correspondant au nuage de points.

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>3. Équation de la droite de régression</h2>    </font>
# </div>

# %% [markdown]
# ### Tâche- Rédigez un script Python pour déterminer l'équation de la droite de régression.- Exécutez le script.

# %% [markdown]
# ### Liste des références

# %% [markdown]
# [1] Wasserman, L. (2013). All of Statistics. https://www.stat.cmu.edu/~larry/all-of-statistics/<br>

# %% [markdown]
# <img src="images/cclic.png" alt="Banner" align="left" width="100"/><br><br>
# Carnet Python en mathématiques, voir Pensée computationnelle - Programmer en Python de <a href="http://www.aiopschool.be">AI Op School</a>, par F. wyffels et N. Gesquière, publié sous licence <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution - Pas d'Utilisation Commerciale - Partage dans les Mêmes Conditions 4.0 International</a>.
