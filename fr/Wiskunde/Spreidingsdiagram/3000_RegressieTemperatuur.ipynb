# %% [markdown]
# <img src="images/logodwengo.png" alt="Banner" width="150"/>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h1>RÉGRESSION - TEMPÉRATURE MOYENNE</h1>    </font>
# </div>

# %% [markdown]
# <div class="alert alert-box alert-success">
# Dans ce notebook, vous allez chercher une courbe qui s’ajuste à la température moyenne mesurée à Uccle sur la période 1991-2020.</div>

# %% [markdown]
# ### TâchePour ce notebook, vous disposez d'un fichier CSV contenant les données. <br>Vous trouverez le fichier dans le dossier `data` : `klimtemp.csv`.
# - Chargez les données.- Représentez les données sur un graphique.- Faites tracer une courbe qui s'ajuste aux données : une droite de régression.- Déterminez l’équation de la droite de régression.

# %% [markdown]
# <div>
#     <h2>Liste de références</h2></div>

# %% [markdown]
# [1] IRM (17 octobre 2022). Climat de la Belgique. Normales climatiques à Uccle. https://www.meteo.be/nl/klimaat/klimaat-van-belgie/klimaatnormalen-te-ukkel/luchttemperatuur/gemiddelde-temperatuur

# %% [markdown]
# <img src="images/cclic.png" alt="Banner" align="left" width="100"/><br><br>
# Notebook Python en mathématiques, voir Pensée computationnelle - Programmer en Python de <a href="http://www.aiopschool.be">AI Op School</a>, par F. wyffels & N. Gesquière, sous licence selon une <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">licence Creative Commons Attribution - Pas d’Utilisation Commerciale - Partage dans les Mêmes Conditions 4.0 International</a>.
