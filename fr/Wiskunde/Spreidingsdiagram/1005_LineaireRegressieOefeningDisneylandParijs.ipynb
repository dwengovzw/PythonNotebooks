# %% [markdown]
# <img src="images/logodwengo.png" alt="Banner" width="150"/>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h1>RÉGRESSION LINÉAIRE - APPLICATION DE LA LIGNE DE TENDANCE - DISNEYLAND PARIS</h1>    </font>
# </div>

# %% [markdown]
# <div class="alert alert-box alert-success">
# Dans ce notebook, vous trouverez des données sur le nombre de visiteurs de Disneyland Paris. <br>    - Vous déterminez le degré d'association à l'aide du coefficient de corrélation.<br>    - Vous définissez l'équation de la courbe de tendance. <br>    - Tu représentes clairement les données fournies et la ligne de tendance sur un graphique.</div>

# %% [markdown]
# ### TâcheVous disposez pour ce notebook d'un fichier CSV contenant des chiffres à ce sujet. Dans les données, vous pouvez observer une tendance : vous voyez comment le nombre de visiteurs évolue en fonction de l'année. <br>Vous trouverez le fichier dans le dossier `data` : `eurodisney.csv`.
# - Importez les données.
# Ensuite, vous déterminez :- le degré de corrélation entre l'année (pour la période 1992-**2019**) et le nombre de visiteurs ;- les équations de la droite de régression (ligne de tendance) pour les visiteurs en fonction de l'année. <br>
# Enfin, représente clairement les données fournies et la ligne de tendance sur un graphique.- Quelle tendance ressort des données ?- Combien de visiteurs aurait-on pu attendre en 2020 si la tendance s'était poursuivie ?- Comparez ceci avec le nombre réel de visiteurs.

# %% [markdown]
# <div>
#     <h2>Liste de références</h2></div>

# %% [markdown]
# [1] Wikipedia. (28 septembre 2021). Disneyland Paris. https://en.wikipedia.org/wiki/Disneyland_Paris

# %% [markdown]
# <img src="images/cclic.png" alt="Banner" align="left" width="100"/><br><br>
# Notebook Python en mathématiques, voir Pensée computationnelle - Programmer en Python de <a href="http://www.aiopschool.be">AI Op School</a>, par F. wyffels et N. Gesquière, sous licence selon une <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">licence Creative Commons Attribution - Pas d'Utilisation Commerciale - Partage dans les Mêmes Conditions 4.0 International</a>.
