# %% [markdown]
# <img src="images/logodwengo.png" alt="Banner" width="150"/>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
# <h1>IMPORTANCE DE LA VISUALISATION - ANSCOMBE</h1>    </font>
# </div>

# %% [markdown]
# <div class="alert alert-box alert-success">
# Le statisticien Francis Anscombe a constitué en 1973 quatre jeux de données, les coordonnées x et y d'un certain nombre de points.<br>Dans le notebook 'Importance de la visualisation - Anscombe', vous avez déjà commencé à travailler avec ces données. Les données y ont été visualisées dans un diagramme de dispersion et les coefficients de corrélation ont été calculés.<br>Dans ce notebook, vous tracez les droites de régression correspondant à chacun des quatre jeux de données.</div>

# %% [markdown]
# ### TâcheTu reprends l'exercice du notebook 'Importance de la visualisation - Anscombe'.- Vous lisez quatre fichiers CSV contenant les données d'Ascombe [1}. Vous les trouvez dans le dossier `data` : `anscombe1.csv`, `anscombe2.csv`, `anscombe3.csv` et `anscombe4.csv`. Chaque jeu de données contient deux colonnes, l'une avec la clé "x" et l'autre avec la clé "y".
# Complétez avec:- Calculez pour chaque jeu de données l’équation de la droite de régression.- Visualisez chaque jeu de données avec la ligne de régression. Placez tous les graphiques ensemble dans un seul graphique comportant 4 sous-graphiques.- Quelle est ta conclusion sur la relation et la droite de régression ?

# %% [markdown]
# ### Importer les modules nécessaires

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from scipy.optimize import curve_fit                # voor regressie

# %% [markdown]
# ### Exemple : graphique avec des sous-graphiques

# %% [markdown]
# Pour générer un graphique avec 12 sous-graphiques ou *subplots*, procédez par exemple comme suit :- Vous créez une fenêtre de dessin.- Vous divisez la fenêtre en trois lignes et quatre colonnes, donc douze zones, avec l'instruction `subplot(3,4,...)`. La fonction `subplot()` se trouve dans le sous-module pyplot de Matplotlib.- On fait référence à la première zone en haut à gauche avec `subplot(3,4,1)`, à la zone voisine avec `subplot(3,4,2)`, à celle encore à côté avec `subplot(3,4,3)`, et on accède à la dernière zone de la première ligne avec `subplot(3,4,4)`.- La zone à gauche de la deuxième rangée est accessible via `subplot(3,4,5)`, ..., et celle en bas à droite via `subplot(3,4,12)`.
# Exécutez la cellule de code :

# %%
x = np.array([2, 4, 6, 8])
y = np.array([8, 6, 4, 2])

plt.figure(figsize=(14,10))                     # creëer tekenvenster

plt.subplot(3,4,1)                              # eerste subplot
plt.axis(xmin=0, xmax=10, ymin=0, ymax=10)      # vensterinstellingen
plt.title("Subplot 1")
plt.xticks(np.arange(0, 11, step=1))
plt.yticks(np.arange(0, 11, step=1))    
plt.scatter(x, y, color="orange", marker="x")   # plo puntenwolk

plt.subplot(3,4,2)                              # tweede subplot
plt.axis(xmin=0, xmax=10, ymin=0, ymax=10)        
plt.title("Subplot 2")
plt.xticks(np.arange(0, 11, step=1))
plt.yticks(np.arange(0, 11, step=1))    
plt.scatter(x, y, color="green", marker="o")     

plt.subplot(3,4,3)                               # derde subplot
plt.axis(xmin=0, xmax=10, ymin=0, ymax=10)        
plt.title("Subplot 3")
plt.xticks(np.arange(0, 11, step=1))
plt.yticks(np.arange(0, 11, step=1))    
plt.scatter(x, y, color="blue", marker="o") 

plt.subplot(3,4,4)                               # vierde  subplot
plt.axis(xmin=0, xmax=10, ymin=0, ymax=10)        
plt.title("Subplot 4")
plt.xticks(np.arange(0, 11, step=1))
plt.yticks(np.arange(0, 11, step=1))    
plt.scatter(x, y, color="red", marker=">")

plt.subplot(3,4,5)                               # vijfde  subplot
plt.axis(xmin=0, xmax=10, ymin=0, ymax=10)        
plt.title("Subplot 5")
plt.xticks(np.arange(0, 11, step=1))
plt.yticks(np.arange(0, 11, step=1))    
plt.scatter(x, y, color="red", marker="o")

plt.subplot(3,4,6)                               # zesde  subplot
plt.axis(xmin=0, xmax=10, ymin=0, ymax=10)        
plt.title("Subplot 6")
plt.xticks(np.arange(0, 11, step=1))
plt.yticks(np.arange(0, 11, step=1))    
plt.scatter(x, y, color="orange", marker="o")

plt.subplot(3,4,7)                                
plt.axis(xmin=0, xmax=10, ymin=0, ymax=10)        
plt.title("Subplot 7")
plt.xticks(np.arange(0, 11, step=1))
plt.yticks(np.arange(0, 11, step=1))    
plt.scatter(x, y, color="blue", marker="<")

plt.subplot(3,4,8)                                
plt.axis(xmin=0, xmax=10, ymin=0, ymax=10)        
plt.title("Subplot 8")
plt.xticks(np.arange(0, 11, step=1))
plt.yticks(np.arange(0, 11, step=1))    
plt.scatter(x, y, color="red", marker="x")

plt.subplot(3,4,9)                                
plt.axis(xmin=0, xmax=10, ymin=0, ymax=10)        
plt.title("Subplot 9")
plt.xticks(np.arange(0, 11, step=1))
plt.yticks(np.arange(0, 11, step=1))    
plt.scatter(x, y, color="orange", marker="<")

plt.subplot(3,4,10)                                
plt.axis(xmin=0, xmax=10, ymin=0, ymax=10)        
plt.title("Subplot 10")
plt.xticks(np.arange(0, 11, step=1))
plt.yticks(np.arange(0, 11, step=1))    
plt.scatter(x, y, color="green", marker="<")

plt.subplot(3,4,11)                               
plt.axis(xmin=0, xmax=10, ymin=0, ymax=10)        
plt.title("Subplot 11")
plt.xticks(np.arange(0, 11, step=1))
plt.yticks(np.arange(0, 11, step=1))    
plt.scatter(x, y, color="blue", marker="x")

plt.subplot(3,4,12)                               # twaalfde  subplot
plt.axis(xmin=0, xmax=10, ymin=0, ymax=10)        
plt.title("Subplot 12")
plt.xticks(np.arange(0, 11, step=1))
plt.yticks(np.arange(0, 11, step=1))    
plt.scatter(x, y, color="green", marker="x")

plt.show()                                        # toon grafiek

# %% [markdown]
# ### Exécutez maintenant la tâche

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>Conclusion</h2>    </font>
# </div>

# %% [markdown]
# Réponse:

# %% [markdown]
# <div class="alert alert-box alert-info">
# L'art consiste à reconnaître, dans la forme du nuage de points, un motif particulier, comme une droite ou une parabole. Vous pouvez alors utiliser une courbe appropriée pour la ligne de régression. <br>Éventuellement, vous pouvez d'abord supprimer les valeurs aberrantes, mais vous perdez alors des informations. Et peut-être que ces valeurs aberrantes sont justement importantes pour faire des prévisions pour l'avenir. </div>

# %% [markdown]
# ### Liste de références

# %% [markdown]
# [1] Wikipedia (2019). Quatuor d'Anscombe. Consulté le 16 septembre 2021 via <br>&nbsp; &nbsp; &nbsp; &nbsp; https://nl.wikipedia.org/wiki/Kwartet_van_Anscombe

# %% [markdown]
# <img src="images/cclic.png" alt="Banner" align="left" width="100"/><br><br>
# Cahier Python en mathématiques, voir Pensée computationnelle - Programmer en Python de <a href="http://www.aiopschool.be">AI Op School</a>, par F. wyffels, B. Van de Velde & N. Gesquière, sous licence selon une <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Licence Creative Commons Attribution - Pas d'Utilisation Commerciale - Partage dans les Mêmes Conditions 4.0 International</a>.
