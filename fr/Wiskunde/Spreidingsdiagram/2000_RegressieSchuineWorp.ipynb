# %% [markdown]
# ![UGentDwengologo](images/bannerugentdwengo.png)

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h1>RÉGRESSION - TIR OBLIQUE</h1>    </font>
# </div>

# %% [markdown]
# <div class="alert alert-box alert-success">
# Dans ce notebook, des données relatives à un lancer oblique, collectées à l'aide du logiciel Kinovea, vous sont présentées.</div>

# %%
from IPython.display import YouTubeVideo

# %% [markdown]
# Regardez la vidéo suivante montrant un lancer oblique dont les données ont été collectées. (Vidéo par C. Boitsios.)

# %%
YouTubeVideo("lsHVw0XfFYo")

# %% [markdown]
# ### TâchePour ce notebook, vous disposez d'un fichier CSV avec les données : `schuineworp2.csv`.Vous trouverez le fichier dans le dossier `data`.
# - Chargez les données.- Représentez les données fournies sur un graphique.- Tracez une courbe qui s'ajuste aux données fournies.Déterminez l’équation de la courbe.

# %% [markdown]
# <div>
# <h2> Remerciements à :</h2></div>

# %% [markdown]
# ![Saint-Bavon](images/logobavo.jpg)

# %% [markdown]
# ![by-nc-sa](images/cclic.png)
# Notebook Python en mathématiques, voir Pensée computationnelle - Programmer en Python de <a href="http://www.aiopschool.be">AI Op School</a>, par F. wyffels et N. Gesquière, sous licence selon une <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">licence Creative Commons Attribution - Pas d'Utilisation Commerciale - Partage dans les Mêmes Conditions 4.0 International</a>.
