# %% [markdown]
# <img src="images/logodwengo.png" alt="Banner" width="150"/>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h1>APPLICATION DIAGRAMME DE DISPERSION - RÉGRESSION </h1>        <h2>POPULATION BELGE - EXERCICE</h2>    </font>
# </div>

# %% [markdown]
# <div class="alert alert-box alert-success">
# Dans ce notebook, vous déterminerez une droite de régression à partir des données relatives au nombre d’habitants en Belgique.</div>

# %% [markdown]
# ### Importer les modules nécessaires

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from scipy.optimize import curve_fit                # voor regressie

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
# <h2>1. Importer et visualiser les données</h2>    </font>
# </div>

# %% [markdown]
# Vous lisez un fichier CSV contenant l’évolution des effectifs de population sur plusieurs décennies [1]. Vous allez visualiser ces données. <br>Le fichier se trouve dans le dossier `data` : `bevolkingbelgie.csv`.

# %% [markdown]
# ### ExerciceChargez le fichier et affichez le nuage de points.

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
# <h2>2. Régression linéaire et représentation graphique</h2>    </font>
# </div>

# %% [markdown]
# ### ConsigneRédigez un script Python qui, à l’exécution, affiche la droite de régression correspondant au nuage de points.

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>3. Équation de la droite de régression</h2>    </font>
# </div>

# %% [markdown]
# ### Exercice- Rédigez un script Python pour déterminer l'équation de la droite de régression.- Exécutez le script.

# %% [markdown]
# ### Liste de références

# %% [markdown]
# [1] STATBEL. Mouvement de la population en 2020. https://statbel.fgov.be/nl/themas/bevolking/loop-van-de-bevolking#figures

# %% [markdown]
# <img src="images/cclic.png" alt="Banner" align="left" width="100"/><br><br>
# Notebook Python en mathématiques, voir Pensée computationnelle - Programmer en Python de <a href="http://www.aiopschool.be">AI Op School</a>, par F. wyffels & N. Gesquière, publié sous une <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">licence Creative Commons Attribution - Pas d’Utilisation Commerciale - Partage dans les Mêmes Conditions 4.0 International</a>.
