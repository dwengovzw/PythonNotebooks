# %% [markdown]
# <img src="images/logodwengo.png" alt="Banner" width="150"/>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
# <h1>APPLICATION DU DIAGRAMME DE DISPERSION : GARES</h1>    </font>
# </div>

# %% [markdown]
# <div class="alert alert-box alert-success">
# Dans ce notebook, vous tenterez de présenter de manière rigoureuse des données relatives à la localisation des gares belges. Pour cela, vous aurez besoin de tous les modules, fonctions et méthodes que vous avez appris à connaître jusqu'à présent !</div>

# %% [markdown]
# ### Importer les modules nécessaires

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>1. Chargement des données</h2>    </font>
# </div>

# %% [markdown]
# Vous visualiserez les données des gares desservies par la SNCB. <br>Le fichier `nmbsstations.csv` dans le dossier `data` contient les coordonnées géographiques de toutes ces gares [1].

# %% [markdown]
# Sur le graphique que tu vas créer, les éléments suivants doivent être présents :- la localisation de toutes les gares belges, chacune représentée par un point;- le titre 'Gares de Belgique';- libellés sur les axes horizontaux et verticaux.

# %% [markdown]
# ### Exercice 1.1Lisez le fichier et récupérez le résultat.

# %% [markdown]
# Combien de lignes et de colonnes le tableau a-t-il ?<br>Lignes: ...<br>Colonnes: ...

# %% [markdown]
# ### Exercice 1.2
# Définis maintenant les 2 variables `lengtegraad` et `breedtegraad` que tu placeras sur les axes. <br>Veillez à placer la 'longitude' et la 'latitude' sur l'axe le plus approprié !

# %% [markdown]
# ### Exercice 1.3
# Convertissez ces tableaux pandas en listes NumPy et affichez les listes.

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>2. Visualiser les données</h2>    </font>
# </div>

# %% [markdown]
# Maintenant que vous avez chargé les données et les avez placées dans des listes NumPy, vous pouvez tracer les données sur un graphique !

# %% [markdown]
# ### Exercice 2.1
# Définissez les limites des axes.

# %% [markdown]
# ### Exercice 2.2
# Maintenant que vous connaissez les limites de l'ensemble de données, vous pouvez créer un graphique préliminaire. Essayez de le garder aussi simple que possible !

# %% [markdown]
# ### Exercice 2.3
# C'est déjà un début, mais ce ne sont clairement pas uniquement des gares belges. La liste incluait apparemment aussi des gares aux Pays-Bas, en Allemagne, en France et en Grande-Bretagne !<br>Mettez maintenant le graphique en forme afin d'obtenir une représentation plus claire. Pour ce faire, procédez comme suit :- Ajustez la taille de la fenêtre de dessin.- Ajustez la portée afin que les stations situées en dehors de la Belgique n’y figurent plus. (Recherchez, si nécessaire, les coordonnées géographiques de la Belgique.)- Nommez le graphique "Gares de Belgique".- Étiquetez les axes.

# %% [markdown]
# Si vous avez tout bien fait, vous avez maintenant obtenu un diagramme de dispersion en forme de Belgique. En l’examinant brièvement, vous pouvez très rapidement reconnaître les villes et les chemins de fer importants !

# %% [markdown]
# ### Exercice 2.4
# - Quelles villes reconnais-tu ?- Donnez deux villes entre lesquelles passe une ligne ferroviaire importante.

# %% [markdown]
# Réponse:

# %% [markdown]
# Ce n’est qu’un seul exemple de la façon dont vous pouvez utiliser des diagrammes de dispersion ! Dans d’autres notebooks, ceux-ci seront utilisés pour étudier les relations entre les variables, par exemple au moyen d’une régression.

# %% [markdown]
# <div class="alert alert-box alert-info">
# Félicitations ! Tu viens juste de :<br>    - des données réelles lues à partir d'un fichier CSV;<br>    - préparé les données;<br>    - les données visualisées;<br>    - le graphique mis en forme;<br>    - les données interprétées.</div>

# %% [markdown]
# <div class="alert alert-box alert-danger">
# Si vous devez réaliser un graphique à partir de données constituées de mesures, <b>il peut être utile d’utiliser un système d’axes dont l’échelle est la même sur l’axe des x et sur l’axe des y, et dont l’origine est indiquée</b>! Sinon, vos données risquent d’être représentées de façon trompeuse, avec des différences exagérées ou au contraire minimisées!</div>

# %% [markdown]
# ### Liste de références

# %% [markdown]
# [1] SPF BOSA. Data.gov.be. Gares de la SNCB. https://data.gov.be/nl/dataset/nmbs-stations

# %% [markdown]
# <img src="images/cclic.png" alt="Banner" align="left" width="100"/><br><br>
# Cahier Python en mathématiques, voir Pensée computationnelle - Programmer en Python de <a href="http://www.aiopschool.be">AI Op School</a>, de F. wyffels, B. Van de Velde & N. Gesquière, sous licence selon une <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">licence Creative Commons Attribution - Pas d'Utilisation Commerciale - Partage dans les Mêmes Conditions 4.0 International</a>.
