# %% [markdown]
# <img src="images/logodwengo.png" alt="Banner" width="150"/>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h1>APPLICATION DIAGRAMME DE DISPERSION - RÉGRESSION </h1><h2>PAUVRETÉ DE LA POPULATION MONDIALE - EXERCICE</h2>    </font>
# </div>

# %% [markdown]
# <div class="alert alert-box alert-success">
# Dans ce notebook, tu vas déterminer une droite de régression à partir des données concernant le taux de pauvreté au sein de la population mondiale.</div>

# %% [markdown]
# Le seuil de pauvreté est fixé à $1,90 par jour et par personne. La Banque mondiale collecte des données pour suivre le pourcentage de la population mondiale vivant sous le seuil de pauvreté et mener des recherches sur l’ampleur et les causes de cette pauvreté.

# %% [markdown]
# ### Importation des modules nécessaires

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>1. Lecture et visualisation des données</h2>    </font>
# </div>

# %% [markdown]
# Vous importez un fichier CSV contenant le pourcentage de la population mondiale vivant sous le seuil de pauvreté sur plusieurs décennies [1]. Vous allez visualiser ces données. <br>Vous trouverez le fichier dans le dossier `data` : `armoedecijferswereldbank.csv`.

# %% [markdown]
# ### ÉnoncéChargez le fichier et affichez le nuage de points.

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
# <h2>2. Régression linéaire et représentation graphique</h2>    </font>
# </div>

# %% [markdown]
# ### TâcheRédigez un script Python qui, à l'exécution, affiche la droite de régression correspondant au diagramme de dispersion.

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>3. Équation de la droite de régression</h2>    </font>
# </div>

# %% [markdown]
# ### Tâche- Élaborez un script Python pour déterminer l'équation de la droite de régression.- Exécutez le script.

# %% [markdown]
# ### Liste de références

# %% [markdown]
# [1] Poverty headcount ratio at $1.90 a day (2011 PPP) (% of population). https://data.worldbank.org/topic/11

# %% [markdown]
# <img src="images/cclic.png" alt="Banner" align="left" width="100"/><br><br>
# Notebook Python en mathématiques, voir Pensée computationnelle - Programmer en Python de <a href="http://www.aiopschool.be">AI Op School</a>, de F. wyffels et N. Gesquière, sous licence selon une <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">licence Creative Commons Attribution - Pas d’Utilisation Commerciale - Partage dans les Mêmes Conditions 4.0 International</a>.
