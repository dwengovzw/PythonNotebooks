# %% [markdown]
# <img src="images/logodwengo.png" alt="Banner" width="150"/>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
# <h1>IMPORTANCE DE LA VISUALISATION DES DONNÉES</h1>    </font>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# Dans ce notebook, tu t'exerces à lire, afficher et visualiser des données stockées dans un fichier csv. <br>    Vous  calculez également la moyenne et la variance des différentes variables à l'aide de fonctions du module NumPy.</div>

# %% [markdown]
# La tâche que vous allez accomplir se compose de sous-tâches (**décomposition**). <br>Avant de poursuivre la lecture du notebook, réfléchis d'abord aux sous-tâches que cela comporte.

# %% [markdown]
# Réponse:

# %% [markdown]
# <img src="images/decompositiedwengo.png" alt="Banner" width="100"/>

# %% [markdown]
# ### Consigne-  Importez les modules nécessaires.

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>1. Un premier jeu de données</h2>    </font>
# </div>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h3>1.1 Lire les données et calculer les caractéristiques</h2>    </font>
# </div>

# %% [markdown]
# ### Tâche-  Lis les données à partir du fichier `data.csv` que tu trouveras dans le dossier `data`.-  Affichez le tableau à l'écran.
# À partir du nom de fichier, tu ne peux rien déduire des données. Tu disposes donc de très peu d’informations sur les points de données. Tu conviendras que, dans ce cas, les données sont dépourvues de sens.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Dans le notebook « Diagramme de dispersion. Données à partir d'un fichier », tu as reçu à la fin une cellule de code à utiliser concrètement pour lire des données à partir d'un fichier et les afficher. Tu dois bien sûr adapter la cellule au nouveau problème.</div>

# %%
# praktische code uit vorige notebook

csv = pd.read_csv("data/punten.csv")                 # inlezen van bestand, je kan zelf de variabelenaam kiezen!

x = csv["x"]                                         # 2e kolom een naam geven m.b.v. de sleutel x (hoofding van de kolom)
y = csv["y"]                                         # 3e kolom een naam geven m.b.v. de sleutel y

x = np.array(x)                                      # NumPy-lijst aanmaken met de gewenste data
y = np.array(y)

print(x)                                             # NumPy-lijst weergeven
print(y)

# %% [markdown]
# ### Tâche-  Calculez la moyenne et la variance des différentes variables. <br> Pour cela, vous utilisez les fonctions `mean()` et `var()` du module NumPy.

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h3>1.2 Visualiser les données</h2>    </font>
# </div>

# %% [markdown]
# Pour avoir une meilleure idée des données, vous allez visualiser les données.

# %% [markdown]
# ### Tâche-  Visualisez les données du fichier `data.csv`.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Dans le notebook 'Spreidingsdiagram. Data uit bestand', vous trouviez à la fin un aperçu du code, prêt à l’emploi, pour visualiser des données déjà chargées. Vous devez naturellement adapter la cellule au nouveau problème.</div>

# %%
# praktische code uit vorige notebook

x_min = x.min()
x_max = x.max()
y_min = y.min()
y_max = y.max()

print(x_min, x_max, y_min, y_max)

plt.figure()                                       # creëer tekenvenster

plt.axis(xmin=..., xmax=..., ymin=..., ymax=...)   # vensterinstellingen
plt.xticks(np.arange(..., ..., step=...))
plt.yticks(np.arange(..., ..., step=...))

plt.scatter(x, y)                                  # plot punten

...                                                # titel en labels

plt.show()                                         # toon grafiek

# %% [markdown]
# Donnez maintenant un titre approprié au graphique !

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>2. Un deuxième jeu de données</h2>    </font>
# </div>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h3>2.1 Chargement des données et calcul des caractéristiques</h2>    </font>
# </div>

# %% [markdown]
# ### Tâche-  Lisez les données du fichier `data2.csv` que vous trouvez dans le dossier `data`.-  Affichez le tableau à l'écran.
# À nouveau, le nom du fichier est peu explicite.

# %% [markdown]
# ### Tâche-  Calculez la moyenne et la variance des différentes variables.-  Comparez ces caractéristiques à celles de l'ensemble de données précédent. Que cela pourrait-il signifier pour le diagramme de dispersion de ce deuxième ensemble de données?

# %% [markdown]
# Réponse:

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h3>2.2 Visualiser les données</h2>    </font>
# </div>

# %% [markdown]
# ### Consigne-  Visualisez les données du fichier `data2.csv`.-  Votre réponse précédente était-elle correcte ?

# %% [markdown]
# <div class="alert alert-block alert-info">
# Vous calculez la moyenne et la variance d'une grandeur avec les fonctions mean() et var() du module NumPy.<br><br>Des points de données dont les moyennes et les variances sont quasi identiques peuvent pourtant produire des graphiques totalement différents.</div>

# %% [markdown]
# <div class="alert alert-box alert-warning">
# Consultez également le notebook 'Belang van visualisatie - Anscombe' et éventuellement le notebook 'Standaardiseren'. </div>

# %% [markdown]
# <div>
#     <h2>Liste de références</h2></div>

# %% [markdown]
# [1] Cairo, A. (2016). *Download the Datasaurus: Never trust summary statistics alone; always visualize your data* [Blogpost].<br>&nbsp; &nbsp; &nbsp; &nbsp; http://helloworld.cc/datasaurus<br>[2] Matejka, J. & Fitzmaurice, G. (2017). Same Stats, Different Graphs: Generating Datasets with Varied Appearance and <br>&nbsp; &nbsp; &nbsp; &nbsp;Identical Statistics through Simulated Annealing. <br>&nbsp; &nbsp; &nbsp; &nbsp;*Proceedings of the 2017 CHI Conference on Human Factors in Computing Systems*. Association for Computing Machinery, <br>&nbsp; &nbsp; &nbsp; &nbsp;New York, NY, USA, 1290–1294. https://doi.org/10.1145/3025453.3025912

# %% [markdown]
# <img src="images/cclic.png" alt="Banner" align="left" width="100"/><br><br>
# Cahier Python en mathématiques, voir Pensée computationnelle - Programmer en Python de <a href="http://www.aiopschool.be">AI Op School</a>, par F. wyffels et N. Gesquière, sous licence selon une <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">licence Creative Commons Attribution - Pas d’Utilisation Commerciale - Partage dans les Mêmes Conditions 4.0 International</a>.
