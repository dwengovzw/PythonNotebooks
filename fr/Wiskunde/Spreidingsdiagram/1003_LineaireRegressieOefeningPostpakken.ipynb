# %% [markdown]
# <img src="images/logodwengo.png" alt="Banner" width="150"/>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
# <h1>RÉGRESSION LINÉAIRE - APPLICATION DE LA LIGNE DE TENDANCE - COLIS POSTAUX</h1>    </font>
# </div>

# %% [markdown]
# <div class="alert alert-box alert-success">
# Dans ce notebook, tu recevras une tâche similaire à celle du notebook 'Régression linéaire - Application de la ligne de tendance - Post'.  </div>

# %% [markdown]
# ### TâcheDans la figure, on voit que le nombre de colis postaux qu’un Belge envoie par an a augmenté au cours de la période 2010-2015.
# Vous examinez le nombre de colis postaux envoyés par Belge et par an en fonction de l'année. <br>Extrayez les données dont vous avez besoin de la figure.
# Ensuite, vous déterminez :- le degré de corrélation entre l’année et le nombre de colis postaux à l’aide du coefficient de corrélation ;- l'équation de la **ligne de tendance**. <br>
# Enfin, représentez clairement les données fournies et la ligne de tendance sur un graphique.
# - Entre quelles grandeurs y a-t-il la plus forte corrélation : entre le nombre de lettres et l'année ou entre le nombre de colis postaux et l'année ?

# %% [markdown]
# <img src="images/postbode.jpg" alt="Banner" width="400"/>
# <center>Figure 1 : Le facteur ne passe plus à domicile tous les jours. [1]</center>

# %% [markdown]
# <div>
# <h2>Liste de références</h2></div>

# %% [markdown]
# [1] tlb, mtm. (21 février 2017). Le facteur ne passe plus tous les jours à domicile. *Het Nieuwsblad*. https://www.nieuwsblad.be/cnt/dmf20170220_02742099

# %% [markdown]
# <img src="images/cclic.png" alt="Banner" align="left" width="100"/><br><br>
# Notebook Python en mathématiques, voir Pensée computationnelle - Programmer en Python de <a href="http://www.aiopschool.be">AI Op School</a>, par F. wyffels & N. Gesquière, sous une <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">licence Creative Commons Attribution - Pas d’Utilisation Commerciale - Partage dans les Mêmes Conditions 4.0 International</a>.
