# %% [markdown]
# <img src="images/logodwengo.png" alt="Dwengo" width="150"/>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
# <h1>EXERCICES SUR LES OPÉRATEURS BOOLÉENS</h1>    </font>
# </div>

# %% [markdown]
# <div class="alert alert-box alert-success">
# Dans ce notebook, vous vous exercez aux opérateurs booléens (ou logiques) et aux propositions vraies et fausses.</div>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>1. Opérateurs de comparaison, opérateurs booléens et valeurs</h2>    </font>
# </div>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h3>Opérateurs de comparaison</h3>    </font>
# </div>
#
# <table>
#  <thead>
#     <tr>
#       <th>&nbsp;</th>  <th><p align="center">Mathématiques</th>      <th>&nbsp;</th>      <th><p align="center">Python</th>      </thead>
# <tr> <td> <p align="left">plus grand que          <td> <p align="center">&nbsp;&nbsp;&nbsp;&nbsp; >   <td> <td>      <p align="center">&nbsp;&nbsp;&nbsp;&nbsp; >   <tr> <td> <p align="left">inférieur à           <td> <p align="center">&nbsp;&nbsp;&nbsp;&nbsp; <  <td> <td>      <p align="center">&nbsp;&nbsp;&nbsp;&nbsp; <    <tr> <td>  <p align="left">égal à  <td> <p align="center">&nbsp;&nbsp;&nbsp;&nbsp; =   <td> <td>      <p align="center">&nbsp;&nbsp;&nbsp;&nbsp; ==  <tr> <td> <p align="left">différent de          <td> <p align="center">&nbsp;&nbsp;&nbsp;&nbsp; &#8800;  <td> <td>      <p align="center">&nbsp;&nbsp;&nbsp;&nbsp; !=      <tr> <td> <p align="left">supérieur ou égal à  <td> <p align="center">&nbsp;&nbsp;&nbsp;&nbsp; &#8805;    <td> <td>      <p align="center">&nbsp;&nbsp;&nbsp;&nbsp; >=  <tr> <td> <p align="left">inférieur ou égal à  <td> <p align="center">&nbsp;&nbsp;&nbsp;&nbsp; &#8804;  <td> <td>      <p align="center">&nbsp;&nbsp;&nbsp;&nbsp; <=     <tr> <td> <p align="left">appartient à  <td> <p align="center">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;  <td> <td>      <p align="center">&nbsp;&nbsp;&nbsp;&nbsp; dans    <tr> <td> <p align="left">n'appartient pas à  <td> <p align="center">&nbsp;&nbsp;&nbsp;&nbsp; &nbsp;  <td> <td>      <p align="center">&nbsp;&nbsp;&nbsp;&nbsp; not in         </table>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
# <h3>Opérateurs logiques ou booléens</h3>    </font>
# </div>
#
# <table>
#  <thead>
#     <tr>
#       <th>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</th>  <th><p align="center">Logique</th>      <th>&nbsp;</th>      <th><p align="center">Python</th>      </thead>
# <tr> <td> <p align="left">et           <td> <p align="center">&nbsp;&nbsp;&nbsp; &#8743;    <td> <td>      <p align="center">&nbsp;&nbsp;&nbsp;&nbsp; and     <tr> <td> <p align="left">ou            <td> <p align="center">&nbsp;&nbsp;&nbsp; &#8744;   <td> <td>      <p align="center">&nbsp;&nbsp;&nbsp;&nbsp; or    <tr> <td>  <p align="left">non         <td> <p align="center">&nbsp;&nbsp;&nbsp; &#172;   <td> <td>      <p align="center">&nbsp;&nbsp;&nbsp;&nbsp; not        </table>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <span style="background-color:whitesmoke; font-family:consolas; font-size:1em;">True</span> et <span style="background-color:whitesmoke; font-family:consolas; font-size:1em;">False</span> sont des <b>valeurs booléennes</b>.  <br><br>    Une <em>expression logique</em> ne peut prendre que les valeurs <span style="background-color:whitesmoke; font-family:consolas; font-size:1em;">False</span> et <span style="background-color:whitesmoke; font-family:consolas; font-size:1em;">True</span>.<br>Une telle expression logique est un objet de type <b>bool</b>. On parle aussi d'une <em>expression booléenne</em>.</div>

# %% [markdown]
# ### Exercice 1.1

# %%
# lijst ingeven
ontbijt = ["boter", "koffie", "ochtend", "choco"]

# %% [markdown]
# Quelle est la valeur des expressions logiques suivantes ?- ontbijt[2] == "matin"    - ontbijt[0] == "boten"- 5 <= 2- "bateaux" dans le petit-déjeuner- "beurre" au petit-déjeunerPlease provide the Dutch text (you can include HTML/Markdown or Python). I’ll translate it to French while preserving the syntax and filenames, and I’ll translate only the comments in any Python code.Vérifiez avec Python.

# %% [markdown]
# Réponse:

# %% [markdown]
# Ce qui se trouve dans les cellules de code ci-dessus est appelé une <b>expression logique</b>.<br> Lors de l'exécution des cellules de code, on vérifie chaque fois si l'expression (logique) donnée est vraie. Si elle est vraie, la sortie est <span style="background-color:whitesmoke; font-family:consolas; font-size:1em;">True</span>, sinon, la sortie est <span style="background-color:whitesmoke; font-family:consolas; font-size:1em;">False</span>.<br>

# %% [markdown]
# ### Exercice 1.2

# %% [markdown]
# Quel est le type de :- 7 <= 0- 7- "7"Please provide the Dutch text you want translated to French. If it includes HTML/Markdown or Python code, paste it as-is so I can preserve the syntax and filenames.
# Vérifiez avec Python.

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>2. Exercices</h2>    </font>
# </div>

# %% [markdown]
# ### Exemple 2.1

# %% [markdown]
# Quelle est la valeur des expressions logiques suivantes ?- ontbijt[0] != "boten" and 5 <= 2- ontbijt[0] != "boten" and 5 > 2- ontbijt[0] != "boten" or 5 <= 2- not(5>2)
# Vérifiez avec Python.

# %% [markdown]
# Réponse:

# %% [markdown]
# Vous pouvez également utiliser des **variables**.

# %%
p = (ontbijt[0] != "boten")
q = (5 <= 2)

# %%
p and q

# %% [markdown]
# ### Exercice 2.1- Consultez la cellule de code suivante sans l'exécuter.- Quelle sera la sortie du code ?

# %% [markdown]
# Réponse:

# %%
(ontbijt[1] == "koffie" or ontbijt[2] == "choco") and -2 < 0

# %% [markdown]
# - Exécute maintenant la cellule de code. Avais-tu correctement prédit la sortie ? Sinon, qu'est-ce qui s'est mal passé ?

# %% [markdown]
# Réponse:

# %% [markdown]
# - Refaites cet exercice, mais utilisez maintenant des variables.

# %% [markdown]
# ### Exercice 2.2aL'expression suivante est-elle vraie ou fausse ? Vérifiez-le en affichant la ligne correspondante du tableau de vérité.<br>$$((5^{2} = 25) \lor (7 < -9)) \land (\text{point} \; (2,5) \; \text{appartient à} \; a \leftrightarrow y = 2 x + 1) \lor  ( 7 \in \text{diviseurs de} \;714))$$

# %% [markdown]
# ### Exercice 2.2bL'expression suivante est-elle vraie ou fausse ? Vérifiez en affichant la ligne correspondante de la table de vérité.<br>$$((5^{2} = 25) \lor (7 < -9)) \land ((19 \; \text{est premier}) \lor  ( 7 \in \text{diviseurs de} \;714))$$

# %% [markdown]
# ### Exercice 2.3Tant l'expression logique p que l'expression logique q ne sont pas vraies. L'expression logique s est vraie.L'expression suivante est-elle vraie ou fausse ? Vérifiez-le en affichant la ligne correspondante de la table de vérité.<br>
# $$(s \lor p) \land ( q \land \neg s)$$

# %% [markdown]
# ### Exercice 2.4p est la proposition : x est un nombre premier et q est la proposition : x est pair.<br>Quelle affirmation est vraie si tu remplaces x par 3?<br>Vérifiez avec Python.<br>
# - $p \lor \neg q$- $p \land \neg q$- $p \lor q$- les trois affirmations sont vraies

# %% [markdown]
# Réponse:

# %% [markdown]
# ### Exercice 2.5Les expressions logiques p, q et r sont vraies.<br>L'expression suivante est-elle vraie ou fausse ? Vérifiez en affichant la ligne correspondante de la table de vérité.<br>
# $$(\neg p \land \neg q) \lor r$$

# %% [markdown]
# <img src="images/cclic.png" alt="Banner" align="left" width="100"/><br><br>
# Notebook Éléments de programmation avec Python, voir Pensée computationnelle - Programmer en Python de <a href="http://www.aiopschool.be">AI Op School</a>, par F. wyffels & N. Gesquière, est concédé sous licence selon une <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">licence Creative Commons Attribution - Pas d'Utilisation Commerciale - Partage dans les Mêmes Conditions 4.0 International</a>.
