# %% [markdown]
# <img src="images/logodwengo.png" alt="Banner" width="150"/>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
# <h1>PARAMÈTRES DE LA PARABOLE</h1>    </font>
# </div>

# %% [markdown]
# <div class="alert alert-box alert-success">
# Le graphe d'une parabole dépend des valeurs des paramètres $a$, $\alpha$ et $\beta$ dans l'expression de la fonction:    $$ y = a \; (x - \alpha)^2 + \beta.$$Dans ce notebook, vous pouvez, à l'aide de curseurs, ajuster les valeurs de $a$, $\alpha$ et $\beta$ et examiner l'effet de ces ajustements sur le graphique.</div>

# %% [markdown]
# ### Importer les modules nécessaires

# %%
# voor interactiviteit
# %matplotlib widget    

import ipywidgets as widgets         # voor widgets 
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>Influence des paramètres sur le graphique</h2>    </font>
# </div>

# %%
def parabool(x, a, alpha, beta):
    """Geef functiewaarde van x terug van parabool."""
    return a * (x - alpha)**2 + beta

# interactieve grafiek parabool
x = np.linspace(-5, 5, 100)     # x-waarden genereren

# interactief grafiekvenster aanmaken
fig, ax = plt.subplots(figsize=(6, 4))
ax.set_xlim([-5, 5])
ax.set_ylim([-5, 5])
ax.grid(True)
plt.title("Parabool $y = a \; (x - \u03B1)^2 + \u03B2$")

# sliders voor a, b, c en d 
# a varieert tussen -4 en 4, alpha tussen -3 en 3, beta tussen -3 en 3
@widgets.interact(a=(-4, 4, .1), alpha=(-3, 3, 0.1), beta=(-3, 3, 0.1))

# startwaarde voor a is 1, voor alpha en beta 0 
# functievoorschrift voor met sliders gekozen waarden
def update(a=1, alpha=0, beta=0):
    """Verwijder vorige grafiek en plot nieuwe."""
    [l.remove() for l in ax.lines]
    plt.vlines(0, -5, 5)
    plt.hlines(0, -5, 5)
    plt.plot(x, x**2, color="green")
    ax.plot(x, parabool(x, a, alpha, beta), color='C0')       # grafiek plotten

# %% [markdown]
# <img src="images/cclic.png" alt="Banner" align="left" width="100"/><br><br>
# Notebook Python en mathématiques, voir Pensée computationnelle - Programmation en Python de <a href="http://www.aiopschool.be">AI Op School</a>, de F. wyffels & N. Gesquière est sous licence selon une <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">licence Creative Commons Attribution - Pas d’Utilisation Commerciale - Partage dans les Mêmes Conditions 4.0 International</a>.
