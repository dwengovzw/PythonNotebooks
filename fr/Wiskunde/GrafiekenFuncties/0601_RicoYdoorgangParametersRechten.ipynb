# %% [markdown]
# <img src="images/logodwengo.png" alt="Banner" width="150"/>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
# <h1>PARAMÈTRES D'UNE DROITE OBLIQUE</h1><h2>Influence des paramètres sur le graphique sans ajustement continu</h2>    </font>
# </div>

# %% [markdown]
# <div class="alert alert-box alert-success">
# La représentation graphique d’une droite oblique dépend des valeurs des paramètres a et b dans l’expression de la fonction :$$ y = a  x + b.$$Dans ce notebook, vous pouvez, à l'aide de curseurs, ajuster les valeurs de a et b et étudier l'effet des modifications sur le graphique.</div>

# %% [markdown]
# ### Importer les modules nécessaires

# %% [markdown]
# Exécutez la cellule de code suivante (cliquez à l'intérieur et cliquez sur 'Run' dans le menu).

# %%
# voor interactiviteit
# %matplotlib widget                   
import ipywidgets as widgets         # voor widgets 

import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Dans ce notebook, le graphique ne sera mis à jour qu'au relâchement du curseur.

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>1. La valeur de a</h2>    </font>
# </div>

# %%
def update1(change):
    line1.set_ydata(change.new * x)      # nieuwe rechte
    fig1.canvas.draw()

x = np.arange(-10, 10, 0.1)             # x-waarden genereren
    
# interactief grafiekvenster aanmaken
fig1, ax1 = plt.subplots(figsize=(4, 4))
plt.axis("equal")                       # zelfde ijk op x-as en y-as
plt.hlines(0, -10, 10)                  # x-as
plt.vlines(0, -10, 10)                  # y-as 
ax1.grid(True)                           # rooster
plt.title("Rechte $y = a \; x$")
plt.plot(x, x, color="green")           # rechte met vergelijking y = x, in groen 

# rechte plotten
line1, = ax1.plot(x, x)                   # startrechte met vergelijking y = x, in blauw, bedekt groene rechte 

# slider voor a met gehele waarden en startwaarde 1    
# a varieert tussen -9 en 9
int_slider = widgets.IntSlider(
    value=1, 
    min=-9, max=9, step=1,
    description='$a$',
    continuous_update=False
)

# blauwe grafiek hertekenen voor met slider gekozen waarde voor a
int_slider.observe(update1, "value")
int_slider

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>2. La valeur de b</h2>    </font>
# </div>

# %%
def update2(change):
    line2.set_ydata(x + change.new)      # nieuwe rechte
    fig2.canvas.draw()

x = np.arange(-10, 10, 0.1)           # x-waarden genereren
    
# interactief grafiekvenster aanmaken
fig2, ax2 = plt.subplots(figsize=(4, 4))
plt.axis("equal")                       # zelfde ijk op x-as en y-as
plt.hlines(0, -10, 10)                  # x-as
plt.vlines(0, -10, 10)                  # y-as 
ax2.grid(True)                           # rooster
plt.title("Rechte $y = x + \; b$")
plt.plot(x, x, color="green")           # rechte met vergelijking y = x, in groen 

# rechte plotten
line2, = ax2.plot(x, x)                   # startrechte met vergelijking y = x + 0, in blauw, bedekt groene rechte 

# slider voor b met gehele waarden en startwaarde 0    
# b varieert tussen -10 en 10
int_slider = widgets.IntSlider(
    value=1, 
    min=-10, max=10, step=1,
    description='$b$',
    continuous_update=False
)

# blauwe grafiek hertekenen voor met slider gekozen waarde voor b
int_slider.observe(update2, "value")
int_slider

# %% [markdown]
# <img src="images/cclic.png" alt="Banner" align="left" width="100"/><br><br>
# Notebook Python en mathématiques, voir Pensée computationnelle - Programmer en Python de <a href="http://www.aiopschool.be">AI Op School</a>, par F. wyffels & N. Gesquière, est mis à disposition sous une <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">licence Creative Commons Attribution - Pas d’Utilisation Commerciale - Partage dans les Mêmes Conditions 4.0 International</a>.
