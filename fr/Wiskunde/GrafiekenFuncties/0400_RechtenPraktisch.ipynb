# %% [markdown]
# <img src="images/logodwengo.png" alt="Banner" width="150"/>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
# <h1>DROIT - PRATIQUE</h1>    </font>
# </div>

# %% [markdown]
# <div class="alert alert-box alert-success">
# Dans ce notebook, vous trouverez le code du notebook précédent 'Rechten' pour tracer rapidement une droite à l'aide de Python. <br>Il suffit d’adapter l’équation, et éventuellement l’intervalle.</div>

# %% [markdown]
# ### Importer les modules nécessaires et tracer le graphique d'une droite

# %%
# modules importeren

import numpy as np
import matplotlib.pyplot as plt


# grafiek van rechte met gegeven vergelijking

x = np.arange(-8, 8, 1)                          # kies x-coördinaten van punten die geplot worden        
y = 2 * x - 3                                    # overeenkomstige y-coördinaten voor rechte

plt.figure()                                     # creëer figuur

plt.axis(xmin=-10, xmax=10, ymin=-25, ymax=20)   # vensterinstellingen
plt.xticks(np.arange(-10, 11, step=1))
plt.yticks(np.arange(-25, 25, step=5))

plt.hlines(0, -10, 10, color="black")            # x-as
plt.vlines(0, -25, 20, color="black")            # y-as

plt.grid(True)                                   # plot rooster

plt.plot(x, y)                                   # plot rechte
 
plt.show()                                       # toon figuur

# %% [markdown]
# <img src="images/cclic.png" alt="Banner" align="left" width="100"/><br><br>
# Notebook Python en mathématiques, voir Pensée computationnelle - Programmer en Python de <a href="http://www.aiopschool.be">AI Op School</a>, de F. wyffels, B. Van de Velde et N. Gesquière est mis sous licence selon une <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">licence Creative Commons Attribution - Pas d’Utilisation Commerciale - Partage dans les Mêmes Conditions 4.0 International</a>.
