# %% [markdown]
# <img src="images/logodwengo.png" alt="Banner" width="150"/>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h1>PARAMÈTRES DE LA DROITE OBLIQUE</h1>     </font>
# </div>

# %% [markdown]
# <div class="alert alert-box alert-success">
# La représentation graphique d'une droite oblique dépend des valeurs des paramètres a et b dans l'expression de la fonction :    $$ y = a  x + b.$$ Dans ce notebook, vous pouvez, à l'aide de curseurs, ajuster les valeurs de a et b et étudier l'effet de ces modifications sur le graphique.</div>

# %% [markdown]
# ### Importer les modules nécessaires

# %% [markdown]
# Exécutez la cellule de code suivante (cliquez dedans et, dans le menu, cliquez sur 'Run').

# %%
# voor interactiviteit
# %matplotlib widget                   
import ipywidgets as widgets         # voor widgets 

import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# <div style='color: #690027;' markdown="1">
# <h2>Influence des paramètres sur le graphique</h2></div>

# %% [markdown]
# Exécutez la cellule de code suivante. Au bas du graphique, vous pouvez utiliser le curseur avec votre souris ou avec les touches fléchées.

# %%
def rechte(x, a, b):
    """Geef functiewaarde van x terug van schuine rechte."""
    return a * x + b
    
# interactieve grafiek schuine rechte
x = np.arange(-10, 10, 0.02)             # x-waarden genereren

# interactief grafiekvenster aanmaken
fig, ax = plt.subplots(figsize=(4, 4))
plt.axis("equal")                        # zelfde ijk op x-as en y-as
ax.set_xlim([-10, 10])
ax.set_ylim([-10, 10])
ax.grid(True)
plt.title("Rechte $y = a \; x + b$")

# sliders voor a en b 
# a varieert tussen -10 en 10, b tussen -8 en 8
@widgets.interact(b=(-8, 8, 0.5), a=(-10, 10, .1))

# functie definiëren om te werken met waarden gekozen via sliders
# startwaarde voor a is 1 en voor b is 0
def update(a=1, b=0):
    """Verwijder vorige grafiek en plot nieuwe."""
    [l.remove() for l in ax.lines]                # vorige grafiek verwijderen
    plt.hlines(0, -10, 10)
    plt.vlines(0, -10, 10)
    plt.plot(x, x, color="green")                 # rechte met vergelijking y = x
    ax.plot(x, rechte(x, a, b), color="C0")       # nieuwe grafiek plotten

# %% [markdown]
# <img src="images/cclic.png" alt="Banner" align="left" width="100"/><br><br>
# Cahier Python en mathématiques, voir Pensée computationnelle - Programmer en Python de <a href="http://www.aiopschool.be">AI Op School</a>, par F. wyffels & N. Gesquière, est mis à disposition sous une <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">licence Creative Commons Attribution - Pas d’Utilisation Commerciale - Partage dans les Mêmes Conditions 4.0 International</a>.
