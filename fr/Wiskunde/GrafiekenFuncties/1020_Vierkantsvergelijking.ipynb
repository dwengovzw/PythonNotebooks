# %% [markdown]
# <img src="images/bannerugentdwengo.png" alt="Banner" width="400"/>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
# <h1>ÉQUATION DU SECOND DEGRÉ</h1>    </font>
# </div>

# %% [markdown]
# <div class="alert alert-box alert-success">
# Dans ce carnet, vous travaillez avec des équations quadratiques et des paraboles.</div>

# %% [markdown]
# ### Importer les modules nécessaires

# %%
import numpy as np

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>1. La résolution d'une équation du second degré</h2>    </font>
# </div>

# %% [markdown]
# ### Tâche- Écrivez un script Python qui demande à un utilisateur de saisir les coefficients d'une équation du second degré et qui calcule ensuite, à l'aide du discriminant, les racines (réelles) de cette équation du second degré.- En sortie, le script doit afficher combien de racines il y a et quelles sont ces racines (si elles existent).

# %% [markdown]
# Utilisez pour cela la cellule de code suivante. Commentez le code.

# %%
# OPLOSSEN VIERKANTSVERGELIJKING

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>2. Exercices</h2>    </font>
# </div>

# %% [markdown]
# ### Exercice 2.1Écris un script qui, pour une parabole, renvoie s’il s’agit d’une parabole ouverte vers le haut (vallée) ou vers le bas (montagne) et combien de points d’intersection elle a avec l’axe des abscisses.

# %% [markdown]
# ### Exercice 2.2Écrivez un script qui, pour une parabole, indique si elle coupe l’axe des y en un point d’ordonnée positive ou négative, ou à l’origine.

# %% [markdown]
# ### Exercice 2.3Deux enfants lancent une balle en oblique vers le haut depuis le même endroit et à la même hauteur.<br>Les balles suivent une trajectoire donnée par les paraboles $p_{1}$ et $p_{2}$ ; les balles partent du point $(0, 50)$.$$p_{1} \leftrightarrow y = - 20 x^2 + 30 x + 50$$$$p_{2} \leftrightarrow y = - 70 x^2 + 50 x + 50$$Écrivez un script qui renvoie quelle balle vole le plus haut et laquelle vole le plus loin.

# %% [markdown]
# <img src="images/cclic.png" alt="Banner" align="left" width="100"/><br><br>
# Carnet Python en mathématiques, voir Pensée computationnelle - Programmer en Python de <a href="http://www.aiopschool.be">IA à l'école</a>, par F. wyffels, C. Boitsios & N. Gesquière est concédé sous licence conformément à une <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">licence Creative Commons Attribution - Pas d’Utilisation Commerciale - Partage dans les Mêmes Conditions 4.0 International</a>.
