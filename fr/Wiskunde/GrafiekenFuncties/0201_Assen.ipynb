# %% [markdown]
# <img src="images/logodwengo.png" alt="Banner" width="150"/>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h1>ASSEN</h1>    </font>
# </div>

# %% [markdown]
# <div class="alert alert-box alert-success">
# Ce notebook montre comment ajouter un axe des x et un axe des y à un diagramme de dispersion. <br></div>

# %% [markdown]
# ### Importer les modules nécessaires

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Vous pouvez facilement tracer les axes x et y à l’aide des fonctions `vlines()` et `hlines()` du module Matplotlib.<br>Exécutez la cellule de code ci-dessous pour voir comment cela fonctionne.

# %%
# ASSENSTELSEL TEKENEN

plt.figure()                                     # creëer tekenvenster

plt.hlines(0, -10, 10)                           # plot horizontale rechte van x = -10 tot x = 10 waarvoor y = 0 (x-as)
plt.vlines(0, -10, 10)                           # plot verticale rechte van y = -10 tot y = 10 waarvoor x = 0 (y-as)
 
plt.show()                                       # toon figuur

# %% [markdown]
# ### Tâche

# %% [markdown]
# - Que se passerait-il si vous modifiez le code en `hlines(0, -20, 30)`?- Que se passerait-il si vous modifiez le code en `vlines(6, -10, 10)` ?

# %% [markdown]
# Réponse:

# %% [markdown]
# <img src="images/cclic.png" alt="Banner" align="left" width="100"/><br><br>
# Cahier Python en mathématiques, voir Pensée computationnelle - Programmer en Python de <a href="http://www.aiopschool.be">AI Op School</a>, par F. wyffels, B. Van de Velde et N. Gesquière, est distribué sous une <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">licence Creative Commons Attribution - Pas d’Utilisation Commerciale - Partage dans les Mêmes Conditions 4.0 International</a>.
