# %% [markdown]
# <img src="images/bannerugentdwengo.png" alt="Banner" width="400"/>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
# <h1>STATISTIQUES EN PYTHON 3 : VISUALISER LES DONNÉES (DIAGRAMME EN BARRES)</h1>    </font>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# Dans ce notebook, vous apprendrez à générer un diagramme en barres avec Python.    </div>

# %% [markdown]
# ### Importez d'abord les modules nécessaires

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Dans ce notebook, vous allez représenter visuellement le jeu de données contenu dans le fichier `smartphoneafhankelijk.csv`. Ce jeu de données contient des résultats du Digimeter [1] : quel pourcentage des Flamands dans une catégorie d’âge donnée se sent dépendant du smartphone (en 2022) ?

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
# <h2>1. Jeu de données</h2>    </font>
# </div>

# %% [markdown]
# ### Exercice 1.1

# %% [markdown]
# Chargez l'ensemble de données, faites-y référence avec la variable `smartphone` et affichez-la à l'écran. Le nom du fichier est `smartphoneafhankelijk.csv` et vous trouverez le fichier dans le dossier `data`.

# %% [markdown]
# Vous avez ici affaire à une **variable bivariée** où chaque « point de données » se compose d'un groupe d'âge et d'un pourcentage. Pour chaque groupe d'âge, on examine la dépendance au smartphone. Ces données sont mieux représentées par un diagramme en barres. Sur l'axe des x figurent les groupes d'âge, et sur l'axe des y le pourcentage.

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>2. Diagramme en barres</h2>    </font>
# </div>

# %% [markdown]
# ### Exercice 2.1

# %% [markdown]
# Représentez ces données en utilisant la méthode pandas `plot()` avec `kind="bar"` et en l'appliquant à `smartphone`.Fournissez également à la méthode `plot()` une valeur pour le paramètre `figsize`, à savoir `figsize=(15,8)`.

# %% [markdown]
# ### Liste de références

# %% [markdown]
# [1] imec.digimeter 2022. https://www.imec.be/nl/kennisuitwisseling/techmeters/digimeter/digimeter-2022

# %% [markdown]
# <img src="images/cclic.png" alt="Banner" align="left" width="100"/><br><br>
#
# Notebook Python en mathématiques - Statistique, de F. wyffels & N. Gesquière, est concédé sous licence selon une <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">licence Creative Commons Attribution - Pas d’Utilisation Commerciale - Partage dans les Mêmes Conditions 4.0 International</a>.
