# %% [markdown]
# <img src="images/bannerugentdwengo.png" alt="Banner" width="400"/>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
# <h1>STATISTIQUES EN PYTHON 3 : VISUALISER LES DONNÉES</h1><h2>HISTOGRAMME</h2>    </font>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# Dans ce notebook, vous apprendrez à générer un histogramme avec Python.    </div>

# %% [markdown]
# ### Importez d'abord les modules nécessaires

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Dans ce notebook, vous allez représenter visuellement le jeu de données dans le fichier `belgischebevolking2023leeftijd.csv`. Ce jeu de données contient la population belge répartie selon l’âge. Les données ont été partagées par STATBEL [1].<br>STATBEL considère toutefois toutes les personnes de 100 ans et plus comme des 'centenaires', tandis que les autres âges sont considérés séparément pour chaque année d'âge. C'est pourquoi le groupe des 'centenaires' a été artificiellement ventilé par année d'âge de 100 à 110 ans inclus, en tenant compte du fait que le Belge le plus âgé a 110 ans [2].

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>1. Jeu de données</h2>    </font>
# </div>

# %% [markdown]
# ### Exercice 1.1

# %% [markdown]
# Chargez le jeu de données, faites-y référence avec la variable `bevolking` et affichez-les à l’écran. Le nom du fichier est `belgischebevolking2023leeftijd.csv` et vous trouverez le fichier dans le dossier `data`.

# %% [markdown]
# La variable d'échantillon est ici une variable **quantitative** ou **numérique**.

# %% [markdown]
# ### Exercice 1.2

# %% [markdown]
# Représentez ces données en utilisant la méthode pandas `plot.bar()` et en l'appliquant à `bevolking`.

# %% [markdown]
# ### Exercice 1.3
# Calculez l'âge moyen d'un Belge.

# %% [markdown]
# ### Exercice 1.4- Calculez la probabilité qu’un Belge soit âgé de 20 à 40 ans : $P(20<X<40)$.

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>2. Histogramme</h2>    </font>
# </div>

# %% [markdown]
# Pour avoir une bonne vue d'ensemble de la manière dont les différentes **catégories d'âge** sont représentées en Belgique, il est toutefois préférable de présenter ces données à l'aide d'un histogramme.<br>Vous présenterez ces données de manière claire, en classes d’âge par tranches de 10 ans. (En choisissant 10 ans comme amplitude de classe, le découpage artificiel est supprimé.)

# %% [markdown]
# <div class="alert alert-block alert-success">
# Dans cet histogramme, les classes d’âge seront sur l’axe des x et la fréquence relative sur l’axe des y. De plus, la <b>surface de chaque barre</b> doit être égale à la <b>fréquence (relative)</b>.    </div>

# %% [markdown]
# ### Exemple 2.1Exécute la cellule de code suivante. Comprends-tu les différentes instructions ?

# %%
# histogram van de leeftijdsgroepen met absolute frequenties (m.b.v. matplotlib)

# klassenbreedte = 10

# intervallen
# bins = [min(bevolking["leeftijd"]) + i * klassenbreedte for i in range((max(bevolking["leeftijd"]) - min(bevolking["leeftijd"])) // klassebreedte + 2)]
klassengrenzen = np.arange(0, 111, 10)

# plot histogram
plt.figure(figsize=(15,8))

plt.hist(bevolking["leeftijd"], bins=klassengrenzen, weights=bevolking["aantal"], color="yellowgreen", edgecolor="black")

plt.xlabel("leeftijd", fontsize=20)
plt.ylabel("aantal", fontsize=20)
plt.title("Belgische bevolking volgens leeftijd", fontsize=30)

# plt.xticks(range(min(bevolking["leeftijd"]), max(bevolking["leeftijd"]) + klassebreedte, klassebreedte))
plt.xticks(klassengrenzen)

plt.show()

# %%
# histogram van de leeftijdsgroepen met absolute frequenties (m.b.v. pandas)

klassengrenzen = np.arange(0, 111, 10)

# plot histogram
plt.figure()

bevolking.hist("leeftijd", bins=klassengrenzen, weights=bevolking["aantal"], color="yellowgreen", edgecolor="black", figsize=(15,8))

plt.xlabel("leeftijd", fontsize=20)
plt.ylabel("aantal", fontsize=20)
plt.title("Belgische bevolking volgens leeftijd", fontsize=30)

plt.xticks(klassengrenzen)

plt.show()

# %% [markdown]
# Tu peux déjà voir à quoi ressemble à peu près un tel histogramme. **Mais tu dois encore passer aux fréquences relatives au lieu des fréquences absolues.**
# Vous avez ici affaire à une caractéristique de chaque individu de la population belge : la classe d’âge. Et, pour cette classe d’âge, vous examinez quelle part de la population y appartient.

# %% [markdown]
# ### Exemple 2.2

# %% [markdown]
# **Pour un histogramme, on utilise les fréquences relatives plutôt que les fréquences absolues.**<br>Vous tenez également compte de la largeur des intervalles, afin que l’aire de chaque barre corresponde à la fréquence relative. Ici, la largeur de classe est de 10.
# Vous devez donc convertir les fréquences absolues en fréquences relatives, puis diviser ces fréquences relatives par 10.
# Pour ce faire, exécutez les cellules de code suivantes.

# %%
# kolom met relatieve frequenties toevoegen aan het data frame
bevolking["RF"] = bevolking["aantal"] / aantal_Belgen /10
bevolking

# %%
# histogram van de leeftijdsgroepen met relatieve frequenties (m.b.v. pandas)

klassengrenzen = np.arange(0, 111, 10)

# plot histogram
plt.figure()

bevolking.hist("leeftijd", bins=klassengrenzen, weights=bevolking["RF"], color="yellowgreen", edgecolor="black", figsize=(15,8))

plt.xlabel("leeftijd", fontsize=20)
plt.ylabel("aantal", fontsize=20)
plt.title("Belgische bevolking volgens leeftijd", fontsize=30)

plt.xticks(klassengrenzen)

plt.show()

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
# <h2>3. Extra : Calcul de la surface totale des barres</h2>    </font>
# </div>

# %% [markdown]
# L'aire totale des barres devrait être égale à 1. Vérifiez cela avec Python.

# %% [markdown]
# Cette somme vaut en fait 1, mais ici vous avez affaire à une erreur d’arrondi.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Les âges ne sont clairement pas répartis selon une distribution normale. Vous en apprendrez davantage sur la distribution normale dans un prochain notebook.</div>

# %% [markdown]
# ### Liste de références

# %% [markdown]
# [1] Population par sexe et groupe d'âge - Belgique, dernière année. https://bestat.statbel.fgov.be/bestat/crosstable.xhtml?view=5fee32f5-29b0-40df-9fb9-af43d1ac9032<br>[2] VRT. *La doyenne des Belges Marcelle Lévaz est décédée à l'âge de 111 ans*. https://www.vrt.be/vrtnws/nl/2022/11/14/oudste-belg-marcelle-levaz-op-111-jarige-leeftijd-overleden/

# %% [markdown]
# <img src="images/cclic.png" alt="Banner" align="left" width="100"/><br><br>
#
# Cahier Python en mathématiques - Statistique, de F. wyffels et N. Gesquière, est placé sous une <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">licence Creative Commons Attribution - Pas d’Utilisation Commerciale - Partage dans les Mêmes Conditions 4.0 International</a>.
