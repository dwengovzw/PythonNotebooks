# %% [markdown]
# <img src="images/bannerugentdwengo.png" alt="Banner" width="400"/>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h1>APPLICATION À LA FRÉQUENCE ABSOLUE ET RELATIVE</h1>    </font>
# </div>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>VIDEOGAMES</h2>    </font>
# </div>

# %% [markdown]
# <div class="alert alert-box alert-success">
# Dans ce notebook, vous utilisez un jeu de données qui est fourni dans un fichier csv `video_games_sales.csv` dans le dossier `data`.    </div>

# %% [markdown]
# Vous constaterez en réalisant les exercices que le jeu de données n’a pas été mis à jour depuis un certain temps. Les données les plus récentes datent de 2017.

# %% [markdown]
# ## Tâche
# Utilisez du code Python pour pouvoir répondre aux questions suivantes.
# - Combien de jeux vidéo de la liste sont sortis en 2015 ?- Donnez le pourcentage de jeux vidéo de l’ensemble de données qui ont été sortis par Nintendo ?- Générez un tableau de fréquences relatives pour les genres de jeux vidéo.- Indiquez le pourcentage de jeux vidéo de la liste qui sont sortis sur la PlayStation. Il s’agit des jeux vidéo sur les plateformes PS, PS2, PS3, PS4 ou PSP.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# Conseils:<ul><li>Commencez par examiner le jeu de données à l'écran et visitez la source des données. Celle-ci contient des explications sur ce que signifie chaque colonne. Cela aide à garder une vue d'ensemble pendant l'exercice.</li></ul><ul><li>Ensuite, vous terminez chaque tâche étape par étape. Essayer de réaliser tout l'exercice en une seule fois augmente le risque d'erreurs.</li></ul></div>

# %% [markdown]
# ### Liste de références

# %% [markdown]
# Ventes de jeux vidéo. https://www.kaggle.com/datasets/gregorut/videogamesales avec des données de https://www.vgchartz.com/

# %% [markdown]
# <img src="images/cclic.png" alt="Banner" align="left" width="100"/><br><br>
#
# Le Notebook Python en mathématiques - Statistique, par D. De Bolster, F. wyffels et N. Gesquière, est concédé sous une <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">licence Creative Commons Attribution - Pas d’Utilisation Commerciale - Partage dans les Mêmes Conditions 4.0 International</a>.
