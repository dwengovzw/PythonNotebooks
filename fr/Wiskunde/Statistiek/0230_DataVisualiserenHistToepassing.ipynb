# %% [markdown]
# <img src="images/bannerugentdwengo.png" alt="Banner" width="400"/>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
# <h1>STATISTIQUES EN PYTHON 3 : VISUALISER LES DONNÉES (HISTOGRAMME)</h1><h2>Application : playlist Spotify</h2>    </font>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# Dans ce notebook, vous générez un histogramme avec Python.    </div>

# %% [markdown]
# ### Importez d'abord les modules nécessaires

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# À l’emplacement `data/artists.csv`, vous trouverez un jeu de données contenant des informations sur les artistes sur Spotify [1].
# ## TâcheTracez un histogramme clair représentant la répartition de la popularité des artistes. Choisissez vous-même une largeur de classe appropriée et veillez à ce que les valeurs sur les deux axes soient claires.

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>Solution</h2>    </font>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# Pour indiquer facilement les limites des classes, vous pouvez utiliser la fonction <code>linspace()</code>du module <code>NumPy</code>.<br> <code>np.linspace(a, b, c)</code> génère une suite de c éléments allant de a à b, espacés régulièrement.</div>

# %% [markdown]
# <div>Quelques exemples :<ul>
#   <li><code>np.linspace(0, 10, 6)</code> = <code>[0, 2, 4, 6, 8, 10]</code></li>  <li><code>np.linspace(200, 600, 9)</code> = <code>[200, 250, 300, 350, 400, 450, 500, 550, 600]</code></li>  <li><code>np.linspace(8, 9, 5)</code> = <code>[8, 8.25, 8.5, 8.56, 9]</code></li>  <li>...</li>
# </ul>
# </div>

# %% [markdown]
# Quelle largeur de classe as-tu choisie et pourquoi ?

# %% [markdown]
# Réponse:

# %% [markdown]
# Que se passe-t-il si nous choisissons des classes trop larges ? Pourquoi cela donne-t-il un histogramme peu clair ?

# %% [markdown]
# Réponse:

# %% [markdown]
# Que se passe-t-il si nous choisissons des classes trop étroites ? Pourquoi cela donne-t-il un histogramme peu clair ?

# %% [markdown]
# Réponse :

# %% [markdown]
# ### Exercice 3.2

# %% [markdown]
# En ajoutant à `plot()` l’argument `density=True`, vous obtenez un histogramme des fréquences relatives. Appliquez cela à l’histogramme de la popularité des artistes.

# %% [markdown]
# ### Liste de références

# %% [markdown]
# [1] 6K Spotify Playlists. https://www.kaggle.com/datasets/viktoriiashkurenko/278k-spotify-songs

# %% [markdown]
# <img src="images/cclic.png" alt="Banner" align="left" width="100"/><br><br>
#
# Notebook Python en mathématiques - Statistique, par D. De Bolster, F. wyffels & N. Gesquière, sous licence selon une <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">licence Creative Commons Attribution - Pas d’Utilisation Commerciale - Partage dans les Mêmes Conditions 4.0 International</a>.
