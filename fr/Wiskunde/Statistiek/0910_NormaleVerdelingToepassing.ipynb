# %% [markdown]
# <img src="images/bannerugentdwengo.png" alt="Banner" width="400"/>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
# <h1>LA LOI NORMALE : APPLICATION</h1>    </font>
# </div>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>STATION MÉTÉO</h2>    </font>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# La loi normale est une loi de probabilité qui s’applique à de nombreuses variables aléatoires. Dans ce notebook, cela est illustré à l’aide de quelques grands jeux de données.</div>

# %% [markdown]
# ### Importez les modules nécessaires

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from scipy.stats import norm

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>1. Exercice station météo</h2>    </font>
# </div>

# %% [markdown]
# Dans de nombreux cas, les données d’un jeu de données suivent approximativement une loi normale. <br>Lors du traitement de grands jeux de données, l’utilisation d’un ordinateur peut vous faire gagner beaucoup de temps.

# %% [markdown]
# Considérez le jeu de données `weather_in_Antwerp.csv` dans le dossier `data` [1]. Ce jeu de données contient des mesures météorologiques à Anvers à différents moments.

# %% [markdown]
# **Au fil des exercices suivants, vous allez chercher la probabilité que la pression atmosphérique soit inférieure à 1 bar (1000 mbar ou 1000 hPa).** <br>
# Tu le fais de *deux manières* : une fois sans et une fois avec la distribution normale.

# %% [markdown]
# ### Exercice 1.1

# %% [markdown]
# -  Chargez l'ensemble de données et tracez un histogramme clair des fréquences relatives de la pression atmosphérique (`"barometer"`).

# %% [markdown]
# - Affichez les éléments de `pression atmosphérique'

# %% [markdown]
# ### Exercice 1.2

# %% [markdown]
# -  Référencez avec une nouvelle variable toutes les valeurs de `barometer` qui sont inférieures à 1 bar.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Souviens-toi que, dans <i>Statistique en Python 3 : analyser des données</i>, tu as utilisé le slicing pour filtrer des valeurs d'une colonne.</div>

# %% [markdown]
# -  Calculez le rapport entre la longueur de la colonne filtrée et la longueur de la colonne d'origine.

# %% [markdown]
# - Quelle est la signification de ce nombre ?

# %% [markdown]
# Réponse:

# %% [markdown]
# Tu as obtenu une bonne approximation de la probabilité que la pression atmosphérique à Anvers soit inférieure à 1 bar. Pourquoi parles-tu ici d'une approximation ?

# %% [markdown]
# Réponse:

# %% [markdown]
# -  Comment pouvez-vous faire en sorte que cette approche soit plus précise ?

# %% [markdown]
# Réponse:

# %% [markdown]
# -  À l'aide de l'histogramme, faites une estimation de la moyenne et de l'écart type de la pression atmosphérique.

# %% [markdown]
# Réponse:

# %% [markdown]
# ### Exercice 1.3

# %% [markdown]
# Vous calculez maintenant la même probabilité en approximant les données par une loi normale.

# %% [markdown]
# -  Calculez la pression atmosphérique moyenne exacte avec Python.-  Calculez également l'écart type de la pression atmosphérique. Cela est possible avec la fonction `std()` (de l'anglais *standard deviation*), analogue à la fonction `mean()`.-  Référez-vous aux résultats à l'aide des variables `luchtdruk_gemiddelde` et `luchtdruk_standaardafwijking`.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Reportez-vous à nouveau au notebook <i>Statistiques en Python 3 : Analyser des données</i>, si vous ne vous souvenez plus comment calculer la moyenne des éléments d'une colonne.</div>

# %% [markdown]
# - Les valeurs correspondent-elles à ton estimation ?

# %% [markdown]
# Réponse:

# %% [markdown]
# - Utilisez cette moyenne et cet écart-type comme paramètres pour une distribution normale. <br> Écrivez du code pour afficher cette distribution normale avec l'histogramme dans un graphique.

# %% [markdown]
# Vous voyez que la pression atmosphérique suit en effet approximativement une loi normale.

# %% [markdown]
# Pour calculer aisément la probabilité qu’une variable aléatoire suivant une loi normale soit inférieure à une certaine valeur, on utilise la fonction de répartition.

# %% [markdown]
# - Utilisez la fonction de répartition pour calculer la probabilité que la pression atmosphérique soit inférieure à 1000 mbar.

# %% [markdown]
# - Dans quelle mesure les résultats des deux méthodes diffèrent-ils ?

# %% [markdown]
# Réponse:

# %% [markdown]
# - Que signifie cela pour cette probabilité ?

# %% [markdown]
# Réponse:

# %% [markdown]
# ### Exercice 1.4

# %% [markdown]
# Utilisez la loi normale pour calculer les probabilités suivantes :* la probabilité que la pression atmosphérique soit supérieure à 1040 mbar;* la probabilité que la pression atmosphérique soit comprise entre 1000 mbar et 1010 mbar.

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>2. Exercice: Graphiques trompeurs</h2>    </font>
# </div>

# %% [markdown]
# Vous avez vu plus tôt que vous pouviez augmenter la précision de l’estimation d’une probabilité en collectant davantage de données. Toutefois, cela ne conduit pas toujours à une estimation qui correspond mieux à la réalité. Cela est illustré dans les exercices suivants.

# %% [markdown]
# ### Exercice 2.1

# %% [markdown]
# Le jeu de données de l’exercice précédent contient des données d’une station météorologique qui enregistrait une mesure toutes les demi-heures de 2012 à 2016. Supposons qu’une équipe de recherche souhaite améliorer la précision des calculs en ajoutant au jeu de données des mesures jusqu’en 2019, mais qu’en raison d’une erreur elle n’ajoute que les mesures des mois de mai à août.
# **Regardez quel est l'effet de cette erreur sur l'estimation de la température.**
# -  Pour ce faire, chargez d’abord le jeu de données mis à jour `weather_in_Antwerp_2012to2019.csv` dans le dossier `data` dans [1].-  Générez un histogramme de la température pour le jeu de données `weather_in_Antwerp_2012to2016` et pour `weather_in_Antwerp_2012to2019`. La température est donnée en °C dans la colonne `temp`.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# Affichez les histogrammes dans une fenêtre de graphique séparée.</div>

# %% [markdown]
# - Quelles différences entre les deux jeux de données pouvez-vous constater ? Faites attention à la moyenne et à l’écart-type.

# %% [markdown]
# Réponse:

# %% [markdown]
# ### Exercice 2.2

# %% [markdown]
# -  Calculez la moyenne et l’écart type des deux jeux de données.-  Faites-y référence à l'aide des variables `temperatuur_gemiddelde_2016`, `temperatuur_gemiddelde_2019`, `temperatuur_standaardafwijking_2016` et `temperatuur_standaardafwijking_2019`.

# %% [markdown]
# - Écrire du code pour générer un graphique de deux distributions normales. Une courbe bleue approxime le jeu de données jusqu’en 2016 et une courbe rouge jusqu’en 2019.

# %% [markdown]
# ### Exercice 2.3

# %% [markdown]
# Calculez la probabilité que la température soit supérieure à 30 °C.-  Utilisez d'abord une distribution normale basée sur le jeu de données jusqu'en 2016 pour approximer la probabilité.-  Utilisez ensuite le jeu de données mis à jour jusqu'en 2019.

# %% [markdown]
# La probabilité estimée qu’une température supérieure à 30 °C se produise au cours d’une année est plus élevée pour le jeu de données mis à jour de manière erronée.

# %% [markdown]
# On utilise différents termes pour désigner ce phénomène, comme **shopping sélectif**, **biais de sélection** ou **cherrypicking**. Parfois, cela se produit inconsciemment, mais bien trop souvent, il est utilisé pour fausser les résultats. <br>Pensez aux négationnistes du climat qui, par exemple, peuvent ajouter davantage de mesures provenant des mois d’hiver à l’ensemble de données et en conclure que le changement climatique n’existe pas. Il est donc important de toujours vérifier la source des données d’une étude avant de tirer soi-même des conclusions.

# %% [markdown]
# ### Liste de références

# %% [markdown]
# [1] Weather dataset in Antwerp, Belgium. https://www.kaggle.com/datasets/ramima/weather-dataset-in-antwerp-belgium<br>Données utilisées avec l'autorisation de CustomWeather, propriétaire des données de www.customweather.com utilisées dans ce jeu de données.

# %% [markdown]
# <img src="images/cclic.png" alt="Banner" align="left" width="100"/><br><br>
#
# Notebook Python en mathématiques - Statistique, de D. De Bolster, F. wyffels et N. Gesquière, est publié sous une <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">licence Creative Commons Attribution - Pas d’Utilisation Commerciale - Partage dans les Mêmes Conditions 4.0 International</a>.
