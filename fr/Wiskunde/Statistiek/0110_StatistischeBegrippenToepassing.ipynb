# %% [markdown]
# <img src="images/bannerugentdwengo.png" alt="Banner" width="400"/>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
# <h1>APPLICATION AUX FRÉQUENCES ABSOLUES ET RELATIVES</h1>    </font>
# </div>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>MISSIONS SPATIALES</h2>    </font>
# </div>

# %% [markdown]
# <div class="alert alert-box alert-success">
# Dans ce notebook, vous allez extraire des informations à partir d'un jeu de données <em>du monde réel</em>.    </div>

# %% [markdown]
# Dans ce notebook, vous utilisez le jeu de données *Space Mission Launches* [1]. Ce jeu de données est fourni dans un fichier CSV `missionlaunches.csv` dans le dossier `data`.

# %% [markdown]
# ### Importer les modules nécessaires

# %%
import pandas as pd  # importeer pandas-module

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>1. Fréquence absolue</h2>    </font>
# </div>

# %% [markdown]
# ### Exercice 1.1
# Chargez le jeu de données avec Python. Référez-vous à celui-ci avec la variable `ruimtemissies`.

# %%
# dataset inladen

# %% [markdown]
# À première vue, ce jeu de données semble assez complexe.

# %% [markdown]
# ### Exercice 1.2
# -  Combien de missions spatiales le tableau contient-il ?-  Combien de caractéristiques des missions spatiales retrouves-tu ?

# %% [markdown]
# Réponse:

# %% [markdown]
# ### Exercice 1.3
# Vous déterminerez pour chaque organisation combien de missions spatiales elle a déjà réalisées.

# %% [markdown]
# -  La colonne `Organisation` indique, pour chaque mission spatiale, quelle organisation l’a réalisée. Crée donc déjà une variable `organisaties` qui fait référence à cette colonne.

# %%
# organisaties

# %% [markdown]
# - Combien de missions spatiales chaque organisation a-t-elle effectuées ?

# %%
# aantal ruimtemissies per organisatie

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>2. Informations</h2>    </font>
# </div>

# %% [markdown]
# <div class="alert alert-box alert-info">
# Pour savoir combien de missions spatiales chaque organisation a effectuées, tu as établi le tableau des fréquences absolues. On peut y lire le nombre de missions spatiales par organisation.<br>Pour établir le tableau des fréquences absolues, il faut compter. Compter 4324 valeurs prendrait à un humain plusieurs heures de travail ; pour un ordinateur, cela ne prend que quelques millisecondes.</div>

# %% [markdown]
# Grâce au tableau des fréquences absolues, vous pouvez déjà extraire de nombreuses informations utiles du jeu de données, qui semblait complexe à première vue.

# %% [markdown]
# <div class="alert alert-box alert-info">
# Notez que 'données' et 'information' ne sont pas synonymes. </div>

# %% [markdown]
# ### Exercice 2.1
# - Quelle organisation a accompli le plus de missions ?

# %% [markdown]
# Réponse:

# %% [markdown]
# - Combien de missions Roscosmos a-t-il déjà accomplies ?

# %% [markdown]
# Réponse:

# %% [markdown]
# Bien sûr, vous pouvez le lire vous-même dans le tableau des fréquences absolues. Mais vous pouvez aussi l’obtenir à l’aide de code de programmation.

# %% [markdown]
# ### Exercice 2.2

# %% [markdown]
# - Écrivez du code qui utilise une variable représentant le nombre de missions spatiales menées par Boeing et affiche ce nombre à l’écran.

# %%
# Boeing

# %% [markdown]
# ### Exercice 2.3Calculez la fréquence absolue de la valeur `SpaceX` et faites-y référence avec la variable `absolute_frequentie_SpaceX`.- Affiche ensuite à l'écran la somme du nombre de missions spatiales organisées par Boeing et par SpaceX. Accompagne-la d'une courte phrase.

# %% [markdown]
# ### Exercice 2.4- Calculez la taille du jeu de données *mission_launches* et faites-y référence avec la variable `aantal_ruimtemissies`.

# %% [markdown]
# - Combien de lignes le jeu de données contient-il ?

# %% [markdown]
# Réponse :

# %% [markdown]
# ### Exercice 2.5Pour savoir si une mission a réussi ou échoué, consultez la colonne nommée `Mission_Status`.- Combien de missions ont réussi et combien ont échoué ?

# %% [markdown]
# Réponse:

# %% [markdown]
# ### Exercice 2.6Écrivez maintenant un script Python qui renvoie les informations suivantes :-  le nombre de missions réussies;-  le nombre de missions totalement échouées (donc la somme du nombre de missions avec Failure ou Prelaunch Failure);-  le nombre total de missions échouées.

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h3>3. Fréquence relative</h3>    </font>
# </div>

# %% [markdown]
# ### Exercice 3.1- Quel pourcentage des missions spatiales a été effectué par la NASA ?

# %% [markdown]
# Réponse:

# %% [markdown]
# ### Exercice 3.2- Écris du code Python pour calculer le pourcentage de missions qui ont échoué avant le lancement (`Prelaunch Failure`).

# %% [markdown]
# ### Exercice 3.3- Établissez un tableau de fréquences relatives.- Utilisez le tableau des fréquences relatives pour déterminer le pourcentage des missions spatiales effectuées par l'ESA.

# %% [markdown]
# ### Exercice 3.4-  Calculez avec Python le pourcentage des missions ayant un `Rocket_Status` actif ?

# %% [markdown]
# ### Liste de références

# %% [markdown]
# [1] Space Mission Launches. https://www.kaggle.com/datasets/sefercanapaydn/mission-launchesavec des données de https://nextspaceflight.com/

# %% [markdown]
# <img src="images/cclic.png" alt="Banner" align="left" width="100"/><br><br>
#
# Notebook Python en mathématiques - Statistique, de D. De Bolster, F. wyffels et N. Gesquière, est sous licence selon une <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Licence Creative Commons Attribution - Pas d’Utilisation Commerciale - Partage dans les Mêmes Conditions 4.0 International</a>.
