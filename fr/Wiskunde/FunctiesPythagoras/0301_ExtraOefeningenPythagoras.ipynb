# %% [markdown]
# <img src="images/bannerugentdwengo.png" alt="Banner" width="300"/>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h1>EXERCICES SUPPLÉMENTAIRES FONCTIONS - PYTHAGORE</h1>    </font>
# </div>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>Exercice 1.1</h2>    </font>
# </div>

# %% [markdown]
# **Comment, en Python, calculer la longueur de l'hypoténuse à partir des trois côtés donnés d'un triangle rectangle ?**<br>
# Vous utilisez le fait que, dans un triangle rectangle, l’hypoténuse est toujours le côté le plus long.
# - Le script demande d'abord les trois côtés d'un triangle rectangle à l'utilisateur.Le script fait référence au côté le plus long à l'aide de la variable `langstezijde` et considère initialement le premier côté comme le côté potentiellement le plus long.- Maintenant, le script compare *d'abord* le deuxième côté à la valeur à laquelle `langstezijde` fait référence. Si le deuxième côté est plus long, alors `langstezijde` fait désormais référence au deuxième côté. Sinon, rien ne change.- *Enfin* le script compare le troisième côté à la valeur à laquelle `langstezijde` fait référence. Si le troisième côté est plus long, `langstezijde` fait désormais référence au troisième côté. Sinon, rien ne change.
# Ce script utilise une structure conditionnelle. Vous reconnaissez la structure conditionnelle au mot-clé `if`. Remarquez le deux-points et l'indentation.<br>La séquence est très importante ! Les deux instructions `if` sont exécutées *l'une après l'autre* et non simultanément.
# Complétez le script ci-dessous et testez-le.

# %%
print("Geef de drie zijden van een rechthoekige driehoek.")
zijde1 = ...(input("De eerste zijde: "))
zijde2 = ...(input("De tweede zijde: "))
zijde3 = ...(input("De derde zijde: "))
               
langstezijde = ...
if zijde2 > langstezijde:
    ... = zijde2
if ...:
    langstezijde = ...

print("De schuine zijde van de rechthoekige driehoek is:", langstezijde)

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>Exercice 1.2</h2>    </font>
# </div>

# %% [markdown]
# Le script est en cours de réécriture, en utilisant une fonction définie par l'utilisateur.
# Complétez le script et testez-le.

# %%
def langstezijde(a, b, c):
    "Langste zijde zoeken."
    ...
    
print("Geef de drie zijden van een rechthoekige driehoek.")
...

schuinezijde = ...

print("De schuine zijde van de rechthoekige driehoek is:", ...)

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>Exercice 2.1</h2>    </font>
# </div>

# %% [markdown]
# En utilisant le théorème de Pythagore, on peut établir la formule permettant de calculer **la distance entre deux points** dans le plan.<br>La distance entre un point $A(x_{1},y_{1})$ et un point $B(x_{2},y_{2})$ est $$\sqrt{(x_{2}-x_{1})^2 + (y_{2}-y_{1})^2}.$$
# Ci-dessous, vous trouverez un script qui donne en sortie la distance entre deux points.<br>Complétez le script et exécutez-le.

# %%
import ...

def afstand(x1, y1, x2, y2):
    """Afstand tussen twee punten."""
    d = ...
    return d

# afstand tussen A(2,3) en B(7,8)
afstand1 = afstand(2, 3, 7, 8)
print("d(A,B)=", afstand1)

# afstand tussen C(9,0) en D(-2,4)
...
...

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
# <h2>Exercice 2.2</h2>    </font>
# </div>

# %% [markdown]
# Écrivez un script qui affiche quel couple de points est le plus éloigné, E(10,-1) et F(2,3), ou G(0,0) et H(20,3).<br>Pour ce faire, intégrez la fonction définie dans le script ci-dessus dans le nouveau script.

# %%
import ...

def ...

# afprinten welke twee punten het verst van elkaar liggen, E(10,-1) en F(2,3), of G(0,0) en H(20,3)
...


if afstand1 > afstand2:
    print("  ... ")
elif ...:
    print("  ... ") 
else:
    print("  ... ")

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>Exercice 3 (défi)</h2>    </font>
# </div>

# %% [markdown]
# **Si un triangle ABC avec des côtés a, b et c est rectangle, alors le théorème de Pythagore s'applique.** <br>  -  Écrivez un script qui demande à l'utilisateur les trois côtés d'un triangle (rectangulaire ou non).<br>-  Le script vérifie, à l'aide d'une fonction définie par l'utilisateur, si le théorème de Pythagore est vérifié.-  La sortie indique si le triangle peut être un triangle rectangle.

# %% [markdown]
# <img src="images/cclic.png" alt="Banner" align="left" width="100"/><br><br>
# Notebook Python en mathématiques, voir Pensée computationnelle - Programmer en Python de <a href="http://www.aiopschool.be">AI Op School</a>, par F. wyffels et N. Gesquière, est mis à disposition sous une <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">licence Creative Commons Attribution - Pas d’Utilisation Commerciale - Partage dans les Mêmes Conditions 4.0 International</a>.
