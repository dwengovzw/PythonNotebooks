# %% [markdown]
# <img src="images/logodwengo.png" alt="Banner" width="150"/>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h1>PYTHAGORE</h1>    </font>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# Tu as déjà appris le théorème de Pythagore en cours de mathématiques. Avec ce notebook, tu automatiseras le calcul des exercices. Lors de la réalisation des exercices en cours de mathématiques, tu pourras alors te concentrer pleinement sur la réflexion.</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# Il n'y a en fait que deux types d'exercices pour le théorème de Pythagore :<br>    - calculer la longueur de l'hypoténuse si les côtés de l'angle droit sont connus;<br>    - calculer la longueur d’un cathète si l’hypoténuse et l’autre cathète sont connus.<br>Tu l'avais déjà remarqué ? Alors tu faisais de la <b>reconnaissance de motifs</b>, un concept de la pensée computationnelle.</div>

# %% [markdown]
# Cela signifie que pour l’automatisation, vous ne devez définir que 2 fonctions. Une pour chaque type d’exercice.

# %% [markdown]
# ### Importer les modules nécessaires

# %%
import math         # om vierkantswortels en pi te kunnen gebruiken

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Vous trouverez davantage d'exemples d'utilisation du module math dans le notebook 'Rekenen'.<br>Au lieu du module math, vous pouvez également utiliser le module NumPy. NumPy est également abordé plus loin dans ce notebook.</div>

# %% [markdown]
# ### Exercice introductif

# %% [markdown]
# Écrivez un script pour calculer la longueur de l'hypoténuse d'un triangle rectangle dont les côtés de l'angle droit mesurent 3 et 4.

# %% [markdown]
# Réfléchis à la manière dont tu pourrais en faire une application conviviale. Tu veux en effet pouvoir utiliser ce script également pour d'autres triangles.

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>1. Fonctions</h2>    </font>
# </div>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
# <h3>1.1 Calculer la longueur de l'hypoténuse lorsque les côtés de l'angle droit sont connus</h3>    </font>
# </div>

# %% [markdown]
# ### Exercice

# %% [markdown]
# Écrivez un script dans lequel vous définissez une fonction `pythagoras1`. <br>Le script demande à l'utilisateur de saisir les longueurs des deux côtés de l'angle droit d'un triangle rectangle. À l'aide de la fonction `pythagoras1`, le script calculera la longueur de l'hypoténuse. Le programme se termine par l'affichage de la longueur de l'hypoténuse à l'utilisateur.<br><br>
# Testez le script et améliorez-le si nécessaire.

# %% [markdown]
# <div class="alert alert-block alert-info">
# Nous pouvons décomposer le script ci-dessus en 4 parties :    <ol>
#         <li>définition de fonction</li>        <li>input</li><li>traitement</li>        <li>output</li>    </ol>
# Pour définir une fonction, on utilise le mot-clé def. Pour tester et/ou utiliser la fonction, une entrée est requise et on affiche le résultat de la fonction au moyen d'une sortie.    <img src="images/invoerverwerkinguitvoerdwengo.png" alt="Banner" width="150"/>
#      <img src="images/decompositiedwengo.png" alt="Banner" width="150"/>
#     <img src="images/abstractiedwengo.png" alt="Banner" width="150"/>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Les explications sur les entrées et sorties se trouvent dans le notebook "InputEnOutput".</div>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h3>1.2 Calculer la longueur d'un côté de l'angle droit lorsque l'hypoténuse et l'autre côté de l'angle droit sont connus</h3>    </font>
# </div>

# %% [markdown]
# ### Consigne

# %% [markdown]
# Écrivez un script dans lequel vous définissez une fonction `pythagoras2`. <br>Le script demande à l’utilisateur de saisir les longueurs de l’hypoténuse et d’un des côtés de l’angle droit d’un triangle rectangle. À l’aide de la fonction `pythagoras2`, le script calculera la longueur de l’autre côté de l’angle droit. Le programme se termine par l’affichage à l’utilisateur de la longueur de l’autre côté de l’angle droit.<br><br>
# Testez le script et améliorez-le si nécessaire.

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>2. Exemple</h2>    </font>
# </div>

# %% [markdown]
# ### Exemple 2.1

# %% [markdown]
# Calculez l’aire d’un triangle rectangle dont un côté de l’angle droit mesure 8 cm et l’hypoténuse 14 cm.

# %%
import math

# oppervlakte kan berekend worden met functie uit vorige notebook
def oppdriehoek(b, h):
    """Oppervlakte van driehoek met basis b en hoogte h."""
    opp = b * h / 2
    return opp

# oppervlakte driehoek kan je berekenen als de basis en de hoogte gekend zijn, dus hier de twee rechthoekszijden
# andere rechthoekszijde berekenen met Pythagoras2
def pythagoras2(a, c):
    """Rechthoekszijde rechthoekige driehoek met schuine zijde c en rechthoekszijde a."""
    rechthoekszijde = math.sqrt(c**2 - a**2)
    return rechthoekszijde

rhz1 = 8                           # gegeven (invoer)
sz = 14                            # gegeven (invoer)
rhz2 = pythagoras2(rhz1, sz)       # andere rechthoekszijde (verwerking)
opp = oppdriehoek(rhz1, rhz2)      # gezochte oppervlakte (verwerking)

print("De oppervlakte van de driehoek is", opp, "cm².")       # uitvoer

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>3. Exercices</h2>    </font>
# </div>

# %% [markdown]
# ### Exercice 3.1

# %% [markdown]
# Le plan des rues de New York est principalement composé de rues perpendiculaires les unes aux autres.<br>Examinez les figures et calculez à l'aide d'un code Python la distance à vol d'oiseau entre l'Empire State Building et Times Square.<img src="images/kaartnewyork.png" alt="Banner" width="400"/> <br>
# <img src="images/gpsnewyork.png" alt="Banner" width="400"/>

# %% [markdown]
# Réponse:

# %% [markdown]
# ### Exercice 3.2

# %% [markdown]
# Si vous souhaitez placer une échelle en toute sécurité contre le mur, il est préférable d'appliquer la règle '4 pour 1'. Cela signifie que pour chaque 4 unités de hauteur, l'échelle doit être à 1 unité du mur.  <br><br>Supposons qu'une échelle soit placée en toute sécurité contre le mur selon la règle du « 4 pour 1 » et qu'elle touche le mur à 5 mètres au-dessus du sol.Quelle est la longueur de l’échelle ? Calculez avec du code Python.

# %% [markdown]
# Réponse:

# %% [markdown]
# ### Exercice 3.3

# %% [markdown]
# Une échelle de 10 mètres de long est appuyée contre un mur, avec le pied à 1,5 mètre du mur. L’échelle est-elle sûre ?Effectuez vos calculs avec du code Python.

# %% [markdown]
# Réponse:

# %% [markdown]
# <img src="images/cclic.png" alt="Banner" align="left" width="100"/><br><br>
# Cahier Python en mathématiques, voir Pensée computationnelle - Programmer en Python de <a href="http://www.aiopschool.be">AI Op School</a>, de F. wyffels, B. Van de Velde & N. Gesquière, est mis à disposition sous une <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">licence Creative Commons Attribution - Pas d’Utilisation Commerciale - Partage dans les Mêmes Conditions 4.0 International</a>.
