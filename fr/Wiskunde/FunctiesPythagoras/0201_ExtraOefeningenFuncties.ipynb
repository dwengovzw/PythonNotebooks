# %% [markdown]
# <img src="images/bannerugentdwengo.png" alt="Banner" width="250"/>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
# <h1>EXERCICES SUPPLÉMENTAIRES SUR LES FONCTIONS</h1>    </font>
# </div>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>Exercice 1</h2>    </font>
# </div>

# %% [markdown]
# -  N'exécutez pas encore la cellule de code suivante, mais regardez déjà si vous comprenez le code. Quelle est la sortie de ce script ?

# %% [markdown]
# Réponse:

# %% [markdown]
# -  Complétez la docstring.-  Exécutez le script. Avez-vous correctement prédit la sortie ? Si ce n'est pas le cas, décrivez pourquoi vous vous êtes trompé.

# %%
def bewerking(a, b):
    """................................................"""
    ks = (a + b)**2
    return ks

getal1 = bewerking(2, 5)
getal2 = bewerking(1, -1)
getal3 = bewerking(7, -2)

print(getal1, getal2, getal3)

# %% [markdown]
# Réponse:

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>Exercice 2</h2>    </font>
# </div>

# %% [markdown]
# -  Complétez le script et exécutez-le.

# %%
# inhouden berekenen

import ...

def inhoud_bol(r):
    """Inhoud van bol met straal r."""
    i = 4 / 3 * math.pi * r**3
    return i

def inhoud_kubus(...):
    """Inhoud van kubus met zijde z."""
    ...
    return i

def ...:
    """Inhoud van cilinder met straal r en hoogte h."""
    ...  
    ...
  
# oefeningen
# inhoud van cilinder C met straal 4 m en hoogte 10 m
...
print("De inhoud van C is", inhoud_C, "m³.")

# inhoud van kubus K met zijde 2 cm
...
...

# inhoud van bol B met straal 15 mm
...
...

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>Exercice 3</h2>    </font>
# </div>

# %% [markdown]
# Un magasin qui fait des soldes accorde une réduction de 35 % sur tous les vêtements. <br><br>Écrivez un script qui :-  demande à l'utilisateur l'(ancien) prix (un nombre à virgule) d'un vêtement;-  calcule le nouveau prix du vêtement, en utilisant une fonction;-  une phrase qui mentionne le nouveau prix, le renvoie.
# Exécutez le script.

# %% [markdown]
# <img src="images/cclic.png" alt="Banner" align="left" width="100"/><br><br>
# Notebook Python en mathématiques, voir Pensée computationnelle - Programmer en Python de <a href="http://www.aiopschool.be">AI Op School</a>, de F. wyffels, C. Boitsios, E. Staelens et N. Gesquière est sous licence conformément à une <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Licence Creative Commons Attribution - Pas d'Utilisation Commerciale - Partage dans les Mêmes Conditions 4.0 International</a>.

# %% [markdown]
# ### Avec le soutien de

# %% [markdown]
# <img src="images/logobavo.jpg" alt="Banner" width="150"/>
