# %% [markdown]
# <img src="images/kiksmeisedwengougent.png" alt="Banner" width="1100"/>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h1>COURBE DE KEELING</h1>    </font>
# </div>

# %% [markdown]
# <div class="alert alert-box alert-success">
# Dans ce carnet, vous examinez comment la concentration de CO$_{2}$ à un endroit donné varie au cours d'une journée et comment elle évolue au cours d'une année.<br>Par ailleurs, à partir des données des mesures de CO$_{2}$ à Mauna Loa, vous réaliserez vous-même un graphique de la courbe de Keeling. Pour ce faire, vous relierez les points de données d’un <em>fichier csv</em> par une ligne brisée.</div>

# %% [markdown]
# La courbe de Keeling est l'une des courbes les plus importantes de la recherche sur le climat. La courbe porte le nom du scientifique David Keeling.

# %% [markdown]
# La concentration de CO$_{2}$ est exprimée en **ppm** : parties par million.

# %% [markdown]
# ### Importer les modules nécessaires

# %% [markdown]
# Pour pouvoir créer, à partir de **fichiers csv** - csv signifie **comma separated values** - des tableaux clairs, on utilise le module pandas. <br>Pour convertir les colonnes de ce tableau en une liste et pouvoir effectuer des calculs, importez le module NumPy. <br>Pour réaliser des représentations graphiques des données, on utilise l'interface pyplot du module Matplotlib. <br><br>Vous importez les modules nécessaires en exécutant la cellule de code suivante.

# %% [markdown]
# <div class="alert alert-box alert-warning">
# Consultez éventuellement les notebooks sur les diagrammes de dispersion pour savoir comment visualiser des données à partir d'un fichier CSV.  </div>

# %%
import pandas as pd

import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>1. Données d'une journée</h2>    </font>
# </div>

# %% [markdown]
# Vous utilisez des données de 1958 [1], la deuxième année où Keeling a effectué ses mesures à Manau Loa.

# %% [markdown]
# Keeling a consigné des mesures toutes les 10 à 20 minutes.<br>Les données sont des valeurs moyennes sur une période de 10 minutes.- Par ex., la valeur de la mesure du compteur 3 est la moyenne de 0 h 40 à 0 h 50 (car 0,75 correspond à 0 h 45).- Par exemple, la valeur de la mesure avec le compteur 91 est la moyenne de 22h40 à 22h50 (car 22,75 correspond à 22h45).- Par ex., la valeur de la mesure avec le compteur 92 est la moyenne de 23 h 00 à 23 h 10 (car 23,0833... correspond à 23 h 05, à savoir deux sixièmes d'heure plus tard, autrement dit un tiers d'heure plus tard, ou 20 minutes plus tard que 22,75).

# %%
# metingen van 30 november 1958
dag = pd.read_csv("data/keelingCO230111958.csv")    # data Scripps
dag

# %%
dag.head()

# %% [markdown]
# Dans la première colonne figure le numéro de la mesure, dans la deuxième colonne l'heure et dans la dernière colonne la concentration.

# %%
# lijsten maken van uur en concentratie
x_dag = dag["uur"]
y_dag = dag["CO2"]

# %%
# NumPy-lijsten maken van uur en concentratie
x_dag = np.array(x_dag)
y_dag = np.array(y_dag)

# %% [markdown]
# ### Exercice 1.1- Affichez les données avec un graphique en courbes.- Que nous dit ce graphique ? Pensez aussi au comportement des plantes.

# %% [markdown]
# Réponse :

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>2. Données d'une année</h2>    </font>
# </div>

# %% [markdown]
# Vous utilisez des données de 1959 [2], la troisième année où Keeling a effectué ses mesures à Manau Loa.

# %% [markdown]
# Les mesures sont généralement notées une semaine sur deux, parfois toutes les deux semaines.

# %%
# data 1959
jaar = pd.read_csv("data/keelingCO21959.csv")    # data Scripps
jaar

# %% [markdown]
# Regardez le tableau. Donnez un exemple d’un endroit où l’on mesurait une semaine sur deux et d’un endroit où l’on mesurait toutes les deux semaines.

# %% [markdown]
# Réponse:

# %% [markdown]
# ### Exercice 2.1- Tracez un graphique (diagramme linéaire) qui représente la concentration de CO$_{2}$ en fonction du jour.Convertissez d'abord les données au bon format.- Que nous dit ce graphique ? Pense à tes cours de biologie.

# %% [markdown]
# Réponse:

# %% [markdown]
# ### Exercice 2.2- Comparez le taux d’accroissement sur l’intervalle [88,93] avec le taux d’accroissement sur l’intervalle [145,155]. Où le taux d’accroissement est-il le plus grand ?

# %% [markdown]
# Réponse:

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>3. La courbe de Keeling</h2>    </font>
# </div>

# %% [markdown]
# Nous considérons les données à partir de 1958 [2], lorsque Keeling a commencé ses mesures.

# %% [markdown]
# Lisez le fichier en exécutant la cellule de code suivante :

# %%
keeling = pd.read_csv("data/keeling.csv")    # data Scripps
keeling

# %% [markdown]
# ### Exercice 3.1- Jusqu'à quand ces mesures ont-elles lieu ?

# %% [markdown]
# Réponse:

# %% [markdown]
# Réponse: Jusqu'à la fin de 2019.

# %% [markdown]
# Pour représenter ces données sur un graphique, choisissez deux variables : x pour l'année et y pour la concentration de CO$_{2}$. <br>Vous créez une liste des années et une liste des concentrations de CO$_{2}$. Avec Pandas, cela se fait assez simplement, car vous pouvez utiliser l'en-tête du tableau comme **clé** (*key*).

# %%
x_keel = keeling["Date.1"]                 # jaartal
y_keel = keeling["CO2"]                    # concentratie

# %%
print(x_keel, y_keel)

# %%
x_keel = np.array(x_keel)
y_keel = np.array(y_keel)

# %% [markdown]
# Dans les données, il y a une valeur remarquable qui revient à plusieurs reprises : -99.99.<br>Ce sont en fait des **mesures manquantes**. Il faut les retirer.Pieter Tans [3] déclare : "-99.99 signifie en effet qu'il n'y a pas de mesures valides pour cette heure, ce jour ou ce mois. Parfois, il y a un problème technique, un ouragan ou une éruption volcanique lors desquels l'électricité a été coupée."

# %% [markdown]
# Pour supprimer -99.99, il faut d’abord vérifier à quels endroits du tableau NumPy cette valeur apparaît. Il faut également supprimer l’année correspondante de x_keel.

# %% [markdown]
# Les valeurs ayant ces indices doivent être supprimées. Les 'années' correspondantes issues de x_keel doivent l’être également.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Pour la procédure, vous pouvez consulter le notebook 'Quelques opérations sur les listes NumPy'.</div>

# %% [markdown]
# Tracez le graphique.

# %% [markdown]
# Attention à la mise en forme.-  Quelle tendance pouvez-vous constater ?-  Peux-tu expliquer le mouvement en zigzag ?

# %% [markdown]
# Réponse:

# %% [markdown]
# <div class="alert alert-box alert-success">
# Félicitations ! Tu as toi-même réalisé une visualisation des données de Keeling, la très célèbre courbe de Keeling.</div>

# %% [markdown]
# <div>
# <h2>Liste de références</h2></div>

# %% [markdown]
# [1] Walker, S.J., Keeling, R.F., & Piper, S. C. (2016). Reconstruction of the Mauna Loa Carbon Dioxide Record using High Frequency APC Data <br> &nbsp; &nbsp; &nbsp; &nbsp; from 1958 through 2004. *Scripps Institution of Oceanography: 1-17*. La Jolla, California.<br> &nbsp; &nbsp; &nbsp; &nbsp; Consulté le 5 septembre 2019 via http://scrippsco2.ucsd.edu/data/atmospheric_co2/mlo<br>[2] Keeling, C.D., Piper, S.C., Bacastow, R.B., Wahlen, M., Whorf, T.P., Heimann, M., & Meijer, H.A. (2001).<br> &nbsp; &nbsp; &nbsp; &nbsp;  Exchanges of atmospheric CO2 and 13CO2 with the terrestrial biosphere and oceans from 1978 to 2000.<br> &nbsp; &nbsp; &nbsp; &nbsp;  *I. Global aspects, SIO Reference Series*. No. 01-06, Scripps Institution of Oceanography, San Diego, 88 pages, 2001.<br> &nbsp; &nbsp; &nbsp; &nbsp; Consulté le 5 septembre 2019 via http://scrippsco2.ucsd.edu/data/atmospheric_co2/primary_mlo_co2_record.<br>[3] Tans, P. (2018). Par e-mail.

# %% [markdown]
# <img src="images/cclic.png" alt="Banner" align="left" width="100"/><br><br>
# Notebook Python et STEM, voir <a href="http://www.aiopschool.be">AI op School</a>, de F. wyffels & N. Gesquière, est mis à disposition selon les termes d’une <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">licence Creative Commons Attribution - Pas d’Utilisation Commerciale - Partage dans les Mêmes Conditions 4.0 International</a>.

# %% [markdown]
# <div>
#     <h2>Avec le soutien de</h2></div>

# %% [markdown]
# <img src="images/kikssteun.png" alt="Banner" width="800"/>
