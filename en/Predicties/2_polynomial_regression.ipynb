# %% [markdown]
# # Polynomial Regression
#
# ## Objective
# In this notebook we will use the [scikit-learn](https://scikit-learn.org/stable/) library to predict crop yields based on temperature measurements through polynomial regression.

# %% [markdown]
# ## Setup

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import PolynomialFeatures

# %%
# When working in colab, also download the datasets
# Switch to colab by changing "github.com" to "githubtocolab.com" in the URL
import sys
IN_COLAB = 'google.colab' in sys.modules
if IN_COLAB:
    print("Running in Google Colab, downloading datasets...")
    # !wget https://raw.githubusercontent.com/dwengovzw/PythonNotebooks/refs/heads/server_setup_2024/en/Predicties/data/crop_yield.csv
    data_path_crop_yield = 'crop_yield.csv'
else:
    print("Not running in Google Colab, assuming datasets are available locally.")
    data_path_crop_yield = './data/crop_yield.csv'

# %% [markdown]
# ## Load the data
# We'll use the same dataset as before and we will again store the different columns as variables.

# %%
df = pd.read_csv(data_path_crop_yield)

# Independent variables (features)
soil_moisture = df["soil_moisture"].to_numpy(dtype=float)
temperature = df["temperature"].to_numpy(dtype=float)
sunlight = df["sunlight"].to_numpy(dtype=float)
fertilizer = df["fertilizer"].to_numpy(dtype=int)

# Dependent variable (feature
crop_yield = df["crop_yield"].to_numpy(dtype=float)

# %% [markdown]
# ## Predicting crop yield based on temperature
#
# Let's now try to predict the crop yield using the temperature measurements only.
# In the following code cell, first try to visualise their relationship using a scatter plot. Put the temperature measurements on the X-axis, and the crop yield on the Y-axis.

# %%
# TODO: scatter plot of sunlight and crop yield measurements.

# %% [markdown]
# As you can see, temperature and crop yield are not linearly related to one another! Consequently, we'll have to up our game and switch from linear regression to polynomial regression.
#
# Start by splitting the data into a training and test set in the next code cell.

# %%
# TODO: overwrite these variables with actual data (do not forget to reshape the arrays to (num_sample, num_features) matrices).
x, y = None, None

x_train, x_test, y_train, y_test = None, None, None, None

# %% [markdown]
# Polynomial regression using the sklearn library can be done with the [PolynomialFeatures](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.PolynomialFeatures.html) class.
# This will transform our temperature samples to (1, temperature, temperature^2).

# %%
polynomial_features = PolynomialFeatures(degree=2)
x_poly_train = polynomial_features.fit_transform(x_train)
x_poly_test = polynomial_features.fit_transform(x_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 polynomial_features = PolynomialFeatures(degree=2)
# ----> 2 x_poly_train = polynomial_features.fit_transform(x_train)
#       3 x_poly_test = polynomial_features.fit_transform(x_test)
#
# NameError: name 'x_train' is not defined

# %% [markdown]
# Essentially, the LinearRegression class from before fits coefficients (1 slope per feature + the intercept) to minimize the errors between observed targets in the dataset, and the targets predicted by the approximation.
# By just treating the higher-degree terms as new features, we can reuse the LinearRegression class to fit the coefficients of our Polynomial Regression.

# %%
poly_regressor = LinearRegression()
poly_regressor.fit(x_poly_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 # Create and fit the polynomial regression model
#       2 poly_regressor = LinearRegression()
# ----> 3 poly_regressor.fit(x_poly_train, y_train)
#
# NameError: name 'x_poly_train' is not defined

# %% [markdown]
# Great, we have fitted our model! Now, similarly as for the simple linear regression, try to:
#
# - qualitatively evaluate the model by creating scatter plots
# - quantitatively evaluate the model by calculating the error metrics
# - take a look at the fitted coefficients
