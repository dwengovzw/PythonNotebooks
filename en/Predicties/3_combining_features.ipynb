# %% [markdown]
# # Combining all features
#
# Up until now, we have only predicted the crop field using a single feature at a time. We can however expect that we can create a better model if we let it use all the available features. Based on what you've learned in the previous notebooks, try to do this yourself now.

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import PolynomialFeatures

# %%
# When working in colab, also download the datasets
# Switch to colab by changing "github.com" to "githubtocolab.com" in the URL
import sys
IN_COLAB = 'google.colab' in sys.modules
if IN_COLAB:
    print("Running in Google Colab, downloading datasets...")
    # !wget https://raw.githubusercontent.com/dwengovzw/PythonNotebooks/refs/heads/server_setup_2024/en/Predicties/data/crop_yield.csv
    data_path_crop_yield = 'crop_yield.csv'
else:
    print("Not running in Google Colab, assuming datasets are available locally.")
    data_path_crop_yield = './data/crop_yield.csv'

# %% [markdown]
# ## Load the data

# %%
# TODO

# %% [markdown]
# ## Data inspection
#
# Visualise the relationship between the different features (soil_moisture, temperature, and sunlight) and the targeted outcome (crop yield) using scatter plots. This allows you to decide whether to use linear regression or polynomial regression (and if the latter, which degree).

# %%
# TODO

# %% [markdown]
# ## Fitting the model

# %% [markdown]
# Split the data into a train and test set.

# %%
# TODO

# %% [markdown]
# Create the chosen model and fit it on the training data.

# %%
# TODO

# %% [markdown]
# Qualitatively evaluate your model by plotting the actual crop yields versus the predicted crop yields.

# %%
# TODO

# %% [markdown]
# Quantitatively evaluate your model (and compare it to the previous models) by calculating the error metrics as we did in the other notebooks.

# %%
# TODO
