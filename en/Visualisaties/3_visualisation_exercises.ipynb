# %% [markdown]
# # Matplotlib visualisation exercises
#
# Now that you have a basic idea of how to use the matplotlib library, and how to load, inspect and manipulate data using the pandas library, we will bring these two together to create some interesting visualisations.
#
# In the `visualisations/data` directory, you can find three datasets:
# - `most_populated_cities_per_continent.csv`: This dataset contains information about the most populated cities across different continents. It includes the continent, country, city name, and population of each city. The dataset can be used to analyze urban population distribution across continents.
# - `revenues_per_music_format.csv`: This dataset records the number of medals won by various countries in different macro areas during the Olympic Games. It includes the year of the Olympics, the macroarea, the country, and the total number of medals won. This dataset is useful for analyzing the performance of countries or regions in the Olympics over time.
# - `olympic_medals.csv`: This dataset provides data on the revenues generated by different music formats over the years. It includes the category and format of the music, the year, and the corresponding revenue in millions, both in actual figures and adjusted for inflation. This dataset can be used to study trends in the music industry, particularly how revenue from various formats has changed over time.
#
# Select one of these datasets and try to make an interesting visualisation with it.

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# When working in colab, also download the datasets
# Switch to colab by changing "github.com" to "githubtocolab.com" in the URL
import sys
IN_COLAB = 'google.colab' in sys.modules
if IN_COLAB:
    print("Running in Google Colab, downloading datasets...")
    # !wget https://raw.githubusercontent.com/dwengovzw/PythonNotebooks/refs/heads/server_setup_2024/en/Visualisaties/data/most_populated_cities_per_continent.csv
    data_path_most_populated_cities_per_continent = 'most_populated_cities_per_continent.csv'

    # !wget https://raw.githubusercontent.com/dwengovzw/PythonNotebooks/refs/heads/server_setup_2024/en/Visualisaties/data/olympic_medals.csv
    data_path_olympic_medals = 'olympic_medals.csv'

    # !wget https://raw.githubusercontent.com/dwengovzw/PythonNotebooks/refs/heads/server_setup_2024/en/Visualisaties/data/revenues_per_music_format.csv 
    data_path_revenues_per_music_format = 'revenues_per_music_format.csv'
else:
    print("Not running in Google Colab, assuming datasets are available locally.")
    data_path_most_populated_cities_per_continent = './data/most_populated_cities_per_continent.csv'
    data_path_olympic_medals = './data/olympic_medals.csv'
    data_path_revenues_per_music_format = './data/revenues_per_music_format.csv'

# %% [markdown]
# ## Load the data into a Pandas dataframe
# To get you started, the following code cell shows how to load in the `olympic_medals.csv` dataset. Feel free to change this to the dataset of your choice.

# %%
# all datasets are stored in csv format with tabs (\t) as separators
df = pd.read_csv("./data/olympic_medals.csv", sep="\t") 
df.head()
# Out:
#    Year     Macroarea      Country  Medals
# 0  2008    South Asia  Afghanistan       1
# 1  2012    South Asia  Afghanistan       1
# 2  1984  North Africa      Algeria       2
# 3  1992  North Africa      Algeria       2
# 4  1996  North Africa      Algeria       3

# %% [markdown]
# ## Inspect the data
# Use the Pandas library to inspect the data. Think about some interesting properties to visualise. Think about what you want to "tell" your  (i.e., what is the message) and how you can most effectively communicate it.
#
# Note: all of these datasets are available on [RawGraphs](https://app.rawgraphs.io/) as well. Optionally, you can first explore the data using RawGraph's dashboard, and possibly even create a target graph which you can try to recreate via matplotlib. The main goal here is to learn how to work with matplotlib.

# %%
# TODO

# %% [markdown]
# ## Data manipulation with Pandas
# Manipulate the data in order to get the desired representation of values.

# %%
# TODO

# %% [markdown]
# ## Visualise using Matplotlib

# %%
# TODO
