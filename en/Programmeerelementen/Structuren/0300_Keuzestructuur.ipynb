# %% [markdown]
# ![kiks meise dwengo ugent](images/kiksmeisedwengougent.png)

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h1>SELECTION STRUCTURE</h1>    </font>
# </div>

# %% [markdown]
# <div class="alert alert-box alert-success">
# In this notebook, you will be introduced to conditional selection.</div>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>1. Selection structure</h2>    </font>
# </div>

# %% [markdown]
# ### Example 1.1Execute the following code.

# %%
# keuzestructuur

getal = float(input("Geef een getal: "))     # na input() steeds aangezien als string, dus typecasting gebruiken

if getal > 0: 
    print(getal, "is strikt positief.")
elif getal < 0:    
    print(getal, "is strikt negatief.")
else:
    print(getal, "is nul.")

# %% [markdown]
# <div class="alert alert-box alert-info">
# The keyword combination <b>if - elif - else</b> stands for <b>if - else if - else</b>.</div>

# %% [markdown]
# ### Exercise 1.1Write a script that asks the user for a word, and then displays whether the word contains exactly 8 letters, or more or fewer than 8.

# %% [markdown]
# ### Exercise 1.2Write a script that asks the user for the slope of two lines (in the plane), and then displays whether the lines are parallel or intersect.

# %% [markdown]
# ### Exercise 1.3Write a script that asks the user for the slope of a line, and then displays whether the line rises, falls, or is parallel to the x-axis.

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>2. Nested structure</h2>    </font>
# </div>

# %% [markdown]
# <div class="alert alert-box alert-info">
# If structures are interwoven, it is referred to as <b>nested structures.</b><br></div>

# %% [markdown]
# ### Example 2.1Execute the following code.

# %%
# geneste structuur: herhalings- en keuzestructuur

getallen = [3, 7, 1, 13, 2, 4, 5, 11, 15] 

for getal in getallen:
    if getal % 2 == 0:
        print("Het getal", getal, "is even.")
    else: 
        print("Het getal", getal, "is oneven.")

# %% [markdown]
# ### Exercise 2.1Extend the code so that a list of the even numbers and a list of the odd numbers are displayed.

# %% [markdown]
# ### Example 2.2In the following code cell, the variable `wiskundigen' refers to a list of names of male and female mathematicians. Note that the names of the women start with an 'N' or an 'L' and those of the men do not. This fact is used in the code to count the number of women in the list.<br>Run the following code.

# %%
# geneste structuur

wiskundigen = ["Fermat", "Gauss", "Euler", "Fibonacci", "Galois", "Noether", "Nightingale", "Lovelace"]
aantal_vrouwen = 0 

for persoon in wiskundigen: 
    geslacht = "vrouwelijk"
    if persoon[0] in ["N", "L"]:
        aantal_vrouwen += 1
    else:
        geslacht = "mannelijk"    
    print(persoon, "is van het geslacht:", geslacht)
    
print("Er zijn", aantal_vrouwen, "vrouwelijke wiskundigen in de lijst.")

# %% [markdown]
# ### Exercise 2.2Extend the code so that the number of male mathematicians is also displayed, without counting them explicitly.

# %% [markdown]
# ### Challenge 2.1Write a script that prints 12 multiples of 3.The script should therefore start with the given list and should 'clean up' and supplement this list.

# %%
lijst = [1, 3, 6, 7, 8, 9]

# %% [markdown]
# Procedure: When Python iterates through a list in a for loop, Python will use the index of an element in that list.When you remove an element, the elements in the list get a new index. So the element following the removed element gets the index that has already been used. However, in the for loop the variable (the iterator) is incremented, so that next element is skipped. <br>What you need to do to avoid this is to first store the elements to be removed in a new list, and then remove all the elements from that list one by one.<br><br>You can also add extra print statements to your script so you can see what's happening. You can optionally 'remove' them afterward by placing a # in front of them.

# %% [markdown]
# ### Challenge 2.2Complete and improve the code, so that:-  every multiple of 3 from the list of numbers is removed, unless it is also a multiple of 5;-  every multiple of 7 from the list of numbers is removed, unless it is also a multiple of 2.
# Create a second list that contains the remaining numbers, each multiplied by 10.<br>Finally print both lists.<br><br>

# %% [markdown]
# Tip: first look for the syntax errors, and only then complete the code until it does what it is supposed to do.

# %%
getallen = [3, 7, 1, 25, 10, 8, 30, 40, 28, 49, 33, 13, 37, 101, 56, 111, 2, 4, 5, 11, 15] 
lijst2 = []

for getal in getallen:
    print(getal)
    if getal % 3 == 0:
        if getal % 5 != 0
            getallen.remove(getal)
        else:
            lijst2.append(getal * 10)
    elif getal % == 0:
        if getal % != 0:
            getallen.remove(getal)
        else
            lijst2.append(getal * 10)
    else:
        lijst2.append(getal * 10)
    
print getallen

# %% [markdown]
# <div class="alert alert-box alert-info">
# In a selection structure, you specify a condition. If the condition is met, a certain instruction is executed. You use the combination of keywords if - elif - else.<br><img src="images/keuzestructuurdwengo.png" alt="Banner" width="100"/>
# </div>

# %% [markdown]
# <img src="images/cclic.png" alt="Banner" align="left" width="100"/><br><br>
# Notebook KIKS, see <a href="http://www.aiopschool.be">AI At School</a>, by F. wyffels & N. Gesquière is licensed under a <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International license</a>.

# %% [markdown]
# <div>
#     <h2>With the support of</h2></div>

# %% [markdown]
# ![partners](images/kikssteun.png)
