# %% [markdown]
# <img src="images/logodwengo.png" alt="Banner" width="150"/>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
# <h1>IMPORTANCE OF VISUALIZING DATA</h1>    </font>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# In this notebook you practice reading, displaying, and visualizing data stored in a CSV file. <br>You also compute the mean and the variance of the different variables using functions from the NumPy module.</div>

# %% [markdown]
# The task you will complete consists of subtasks (**decomposition**). <br>Before you proceed further through the notebook, first think about what those subtasks are.

# %% [markdown]
# Answer:

# %% [markdown]
# <img src="images/decompositiedwengo.png" alt="Banner" width="100"/>

# %% [markdown]
# ### Assignment-  Import the necessary modules.

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>1. A first dataset</h2>    </font>
# </div>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h3>1.1 Reading in data and calculating features</h2>    </font>
# </div>

# %% [markdown]
# ### Assignment-  Read the data from the file `data.csv` that you can find in the `data` folder.-  Show the table on the screen.
# You can’t infer anything about the data from the filename. So you have precious little information about the data points. You will agree that, in that case, the data are uninformative.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# In the notebook 'Scatter plot. Data from file' you were given a code cell at the end to use in practice for reading data from a file and displaying it. You will, of course, need to adapt the cell to the new problem.</div>

# %%
# praktische code uit vorige notebook

csv = pd.read_csv("data/punten.csv")                 # inlezen van bestand, je kan zelf de variabelenaam kiezen!

x = csv["x"]                                         # 2e kolom een naam geven m.b.v. de sleutel x (hoofding van de kolom)
y = csv["y"]                                         # 3e kolom een naam geven m.b.v. de sleutel y

x = np.array(x)                                      # NumPy-lijst aanmaken met de gewenste data
y = np.array(y)

print(x)                                             # NumPy-lijst weergeven
print(y)

# %% [markdown]
# ### AssignmentCalculate the mean and variance of the different variables. <br> You use the `mean()` and `var()` functions from the NumPy module.

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h3>1.2 Visualizing data</h2>    </font>
# </div>

# %% [markdown]
# To get a better idea of the data, you will visualize the data.

# %% [markdown]
# ### Assignment-  Visualize the data from the file `data.csv`.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# In the notebook 'Scatter plot. Data from file' you were given, at the end, an overview of the code for practical use in visualizing data that has already been read in. You will, of course, need to adapt the cell to the new problem.</div>

# %%
# praktische code uit vorige notebook

x_min = x.min()
x_max = x.max()
y_min = y.min()
y_max = y.max()

print(x_min, x_max, y_min, y_max)

plt.figure()                                       # creëer tekenvenster

plt.axis(xmin=..., xmax=..., ymin=..., ymax=...)   # vensterinstellingen
plt.xticks(np.arange(..., ..., step=...))
plt.yticks(np.arange(..., ..., step=...))

plt.scatter(x, y)                                  # plot punten

...                                                # titel en labels

plt.show()                                         # toon grafiek

# %% [markdown]
# Now give the graph an appropriate title!

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>2. A second dataset</h2>    </font>
# </div>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h3>2.1 Loading data and calculating features</h2>    </font>
# </div>

# %% [markdown]
# ### Assignment-  Load the data from the file `data2.csv` that you can find in the `data` folder.-  Show the table on the screen.
# Once again, the file name is non-descriptive.

# %% [markdown]
# ### Assignment-  Calculate the mean and the variance of the different variables.-  Compare these characteristics with those of the previous dataset. What could this mean for the scatter plot of this second dataset?

# %% [markdown]
# Answer:

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h3>2.2 Visualizing data</h2>    </font>
# </div>

# %% [markdown]
# ### Assignment-  Visualize the data from the file `data2.csv`.-  Was your previous answer correct?

# %% [markdown]
# <div class="alert alert-block alert-info">
# You calculate the mean and the variance of a quantity using the functions mean() and var() from the NumPy module.<br><br>Datasets whose means and variances are almost the same can still yield completely different graphs.</div>

# %% [markdown]
# <div class="alert alert-box alert-warning">
# Also see the notebook 'Importance of visualization - Anscombe' and possibly the notebook 'Standardizing'. </div>

# %% [markdown]
# <div>
#     <h2>Reference list</h2></div>

# %% [markdown]
# [1] Cairo, A. (2016). *Download the Datasaurus: Never trust summary statistics alone; always visualize your data* [Blogpost].<br>&nbsp; &nbsp; &nbsp; &nbsp; http://helloworld.cc/datasaurus<br>[2] Matejka, J. & Fitzmaurice, G. (2017). Same Stats, Different Graphs: Generating Datasets with Varied Appearance and <br>&nbsp; &nbsp; &nbsp; &nbsp;Identical Statistics through Simulated Annealing. <br>&nbsp; &nbsp; &nbsp; &nbsp;*Proceedings of the 2017 CHI Conference on Human Factors in Computing Systems*. Association for Computing Machinery, <br>&nbsp; &nbsp; &nbsp; &nbsp;New York, NY, USA, 1290–1294. https://doi.org/10.1145/3025453.3025912

# %% [markdown]
# <img src="images/cclic.png" alt="Banner" align="left" width="100"/><br><br>
# Python notebook in mathematics, see Computational thinking - Programming in Python from <a href="http://www.aiopschool.be">AI Op School</a>, by F. wyffels & N. Gesquière, licensed under a <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International license</a>.
