# %% [markdown]
# <img src="images/logodwengo.png" alt="Banner" width="150"/>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h1>REGRESSION - AVERAGE TEMPERATURE</h1>    </font>
# </div>

# %% [markdown]
# <div class="alert alert-box alert-success">
# In this notebook you will look for a curve that fits the average temperature measured in Uccle in the period 1991–2020.</div>

# %% [markdown]
# ### AssignmentFor this notebook you have a CSV file that contains the data. <br>You will find the file in the `data` folder: `klimtemp.csv`.
# - Read in the data.- Plot the data on a graph.- Draw a curve that fits the data: a regression line.- Determine the equation of the regression line.

# %% [markdown]
# <div>
#     <h2>Reference list</h2></div>

# %% [markdown]
# [1] KMI (17 October 2022). Climate of Belgium. Climate normals at Uccle. https://www.meteo.be/nl/klimaat/klimaat-van-belgie/klimaatnormalen-te-ukkel/luchttemperatuur/gemiddelde-temperatuur

# %% [markdown]
# <img src="images/cclic.png" alt="Banner" align="left" width="100"/><br><br>
# Python notebook for mathematics, see Computational thinking - Programming in Python from <a href="http://www.aiopschool.be">AI Op School</a>, by F. wyffels & N. Gesquière, licensed under a <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International license</a>.
