# %% [markdown]
# <img src="images/logodwengo.png" alt="Banner" width="150"/>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
# <h1>APPLICATION SCATTER PLOT - REGRESSION </h1>        <h2>BELGIAN POPULATION - EXERCISE</h2>    </font>
# </div>

# %% [markdown]
# <div class="alert alert-box alert-success">
# In this notebook, you will determine a regression line for the data regarding the population size in Belgium.</div>

# %% [markdown]
# ### Import necessary modules

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from scipy.optimize import curve_fit                # voor regressie

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
# <h2>1. Reading and visualizing data</h2>    </font>
# </div>

# %% [markdown]
# You import a CSV file that contains the evolution of population figures over several decades [1]. You will visualize this data. <br>You can find the file in the `data` folder: `bevolkingbelgie.csv`.

# %% [markdown]
# ### AssignmentRead the file and show the point cloud.

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
# <h2>2. Linear regression and graphical representation</h2>    </font>
# </div>

# %% [markdown]
# ### AssignmentWrite a Python script that, when executed, shows the regression line that fits the scatter plot.

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>3. Equation of the regression line</h2>    </font>
# </div>

# %% [markdown]
# ### Assignment- Create a Python script to determine the equation of the regression line.- Run the script.

# %% [markdown]
# ### Reference list

# %% [markdown]
# [1] STATBEL. Population change in 2020. https://statbel.fgov.be/nl/themas/bevolking/loop-van-de-bevolking#figures

# %% [markdown]
# <img src="images/cclic.png" alt="Banner" align="left" width="100"/><br><br>
# Python notebook in mathematics, see Computational thinking - Programming in Python by <a href="http://www.aiopschool.be">AI Op School</a>, by F. wyffels & N. Gesquière, licensed under a <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International license</a>.
