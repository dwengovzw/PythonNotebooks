# %% [markdown]
# <img src="images/logodwengo.png" alt="Banner" width="150"/>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
# <h1>SCATTER PLOT APPLICATION: OLD FAITHFUL GEYSER - EXERCISE</h1>    </font>
# </div>

# %% [markdown]
# <div class="alert alert-box alert-success">
# In this notebook, you will present data about the activity of the Old Faithful geyser.</div>

# %% [markdown]
# ### Import necessary modules

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib widget
import ipywidgets as widgets

# %% [markdown]
# [![Video Old Faithful](images/oldfaithful.jpg)](https://www.nps.gov/media/video/embed.htm?id=CAC818D4-155D-451F-677DCE1D358B9F71)

# %% [markdown]
# <center> Photo: Old Faithful 2003; Daniel Mayer [1].</center>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>1. Reading data</h2>    </font>
# </div>

# %% [markdown]
# The Old Faithful geyser in Yellowstone National Park in the US erupts at regular intervals. <br>You read in a CSV file that, for 272 observations, contains the duration of the eruption and the waiting time until the next eruption in minutes [2]. You will visualize these data.<br>The csv file `oldfaithfulgeiser.csv` can be found in the `data` folder.

# %% [markdown]
# ### Exercise 1.1Read the file and show the result.

# %% [markdown]
# ### Exercise 1.2
# Now define the 2 variables `eruptie` and `wacht` that you will place on the axes. <br>You are supposed to investigate whether the waiting time until the next eruption depends on the duration of an eruption. Think about which variable belongs on which axis.

# %% [markdown]
# ### Exercise 1.3
# Convert these pandas tables to NumPy lists and print the lists.

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>2. Visualizing data</h2>    </font>
# </div>

# %% [markdown]
# Now that you have loaded the data and placed it in NumPy lists, you can plot the data in a graph!

# %% [markdown]
# ### Exercise 2.1
# Determine the limits for the axes.

# %% [markdown]
# ### Exercise 2.2
# Now that you know the boundaries of the dataset, you can create a preliminary plot. Try to keep this as simple as possible!

# %% [markdown]
# Checklist:
# - Is the drawing window large enough?- Is the range adjusted to the data?- Did you give the graph a title?- Are the axes labeled?

# %% [markdown]
# ### Reference list

# %% [markdown]
# [1] Mayer, D. (2003). CC BY-SA 3.0, via Wikimedia Commons. <br>       &nbsp; &nbsp; &nbsp; &nbsp; https://commons.wikimedia.org/wiki/File:Old_Faithful_Geyser_at_Yellowstone.JPG <br>[2] Wasserman, L. (2013). All of Statistics. https://www.stat.cmu.edu/~larry/all-of-statistics/<br>

# %% [markdown]
# <img src="images/cclic.png" alt="Banner" align="left" width="100"/><br><br>
# Python notebook in mathematics, see Computational Thinking - Programming in Python from <a href="http://www.aiopschool.be">AI Op School</a>, by F. wyffels & N. Gesquière, licensed under a <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International license</a>.
