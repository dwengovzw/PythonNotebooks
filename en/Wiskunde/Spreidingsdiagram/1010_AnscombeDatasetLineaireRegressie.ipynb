# %% [markdown]
# <img src="images/logodwengo.png" alt="Banner" width="150"/>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h1>IMPORTANCE OF VISUALIZATION - ANSCOMBE</h1>    </font>
# </div>

# %% [markdown]
# <div class="alert alert-box alert-success">
# In 1973, the statistician Francis Anscombe created four data sets, the x- and y-coordinates of a number of points.<br>In the notebook 'Importance of visualization - Anscombe' you already worked with this data. The data were visualized there in a scatter plot and the correlation coefficients were calculated.<br>In this notebook you plot the regression lines for each of the four datasets.</div>

# %% [markdown]
# ### AssignmentYou resume the assignment from the notebook 'Importance of visualization - Anscombe'.- You load four CSV files with the data of Ascombe [1}. You can find them in the `data` folder: `anscombe1.csv`, `anscombe2.csv`, `anscombe3.csv`, and `anscombe4.csv`. Each dataset contains two columns, one with key "x" and one with key "y".
# Complete with:- Calculate the equation of the regression line for each dataset.- Visualize each dataset with the regression line included. Place all plots together in one figure with 4 subplots.- What is your conclusion about the relationship and the regression line?

# %% [markdown]
# ### Import required modules

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from scipy.optimize import curve_fit                # voor regressie

# %% [markdown]
# ### Example: plot with subplots

# %% [markdown]
# To generate a plot with 12 subplots or *subplots*, you can, for example, proceed as follows:- You create a drawing window.- You divide the window into three rows and four columns, so twelve areas, with the instruction `subplot(3,4,...)`. The `subplot()` function can be found in the pyplot submodule of Matplotlib.- You refer to the first area at the top left with `subplot(3,4,1)`, to the area next to it with `subplot(3,4,2)`, to the one next to that with `subplot(3,4,3)`, and you reach the last area of the first row with `subplot(3,4,4)`.- You reach the area on the left on the second row via `subplot(3,4,5)`, ..., and the one at the bottom right via `subplot(3,4,12)`.
# Run the code cell:

# %%
x = np.array([2, 4, 6, 8])
y = np.array([8, 6, 4, 2])

plt.figure(figsize=(14,10))                     # creëer tekenvenster

plt.subplot(3,4,1)                              # eerste subplot
plt.axis(xmin=0, xmax=10, ymin=0, ymax=10)      # vensterinstellingen
plt.title("Subplot 1")
plt.xticks(np.arange(0, 11, step=1))
plt.yticks(np.arange(0, 11, step=1))    
plt.scatter(x, y, color="orange", marker="x")   # plo puntenwolk

plt.subplot(3,4,2)                              # tweede subplot
plt.axis(xmin=0, xmax=10, ymin=0, ymax=10)        
plt.title("Subplot 2")
plt.xticks(np.arange(0, 11, step=1))
plt.yticks(np.arange(0, 11, step=1))    
plt.scatter(x, y, color="green", marker="o")     

plt.subplot(3,4,3)                               # derde subplot
plt.axis(xmin=0, xmax=10, ymin=0, ymax=10)        
plt.title("Subplot 3")
plt.xticks(np.arange(0, 11, step=1))
plt.yticks(np.arange(0, 11, step=1))    
plt.scatter(x, y, color="blue", marker="o") 

plt.subplot(3,4,4)                               # vierde  subplot
plt.axis(xmin=0, xmax=10, ymin=0, ymax=10)        
plt.title("Subplot 4")
plt.xticks(np.arange(0, 11, step=1))
plt.yticks(np.arange(0, 11, step=1))    
plt.scatter(x, y, color="red", marker=">")

plt.subplot(3,4,5)                               # vijfde  subplot
plt.axis(xmin=0, xmax=10, ymin=0, ymax=10)        
plt.title("Subplot 5")
plt.xticks(np.arange(0, 11, step=1))
plt.yticks(np.arange(0, 11, step=1))    
plt.scatter(x, y, color="red", marker="o")

plt.subplot(3,4,6)                               # zesde  subplot
plt.axis(xmin=0, xmax=10, ymin=0, ymax=10)        
plt.title("Subplot 6")
plt.xticks(np.arange(0, 11, step=1))
plt.yticks(np.arange(0, 11, step=1))    
plt.scatter(x, y, color="orange", marker="o")

plt.subplot(3,4,7)                                
plt.axis(xmin=0, xmax=10, ymin=0, ymax=10)        
plt.title("Subplot 7")
plt.xticks(np.arange(0, 11, step=1))
plt.yticks(np.arange(0, 11, step=1))    
plt.scatter(x, y, color="blue", marker="<")

plt.subplot(3,4,8)                                
plt.axis(xmin=0, xmax=10, ymin=0, ymax=10)        
plt.title("Subplot 8")
plt.xticks(np.arange(0, 11, step=1))
plt.yticks(np.arange(0, 11, step=1))    
plt.scatter(x, y, color="red", marker="x")

plt.subplot(3,4,9)                                
plt.axis(xmin=0, xmax=10, ymin=0, ymax=10)        
plt.title("Subplot 9")
plt.xticks(np.arange(0, 11, step=1))
plt.yticks(np.arange(0, 11, step=1))    
plt.scatter(x, y, color="orange", marker="<")

plt.subplot(3,4,10)                                
plt.axis(xmin=0, xmax=10, ymin=0, ymax=10)        
plt.title("Subplot 10")
plt.xticks(np.arange(0, 11, step=1))
plt.yticks(np.arange(0, 11, step=1))    
plt.scatter(x, y, color="green", marker="<")

plt.subplot(3,4,11)                               
plt.axis(xmin=0, xmax=10, ymin=0, ymax=10)        
plt.title("Subplot 11")
plt.xticks(np.arange(0, 11, step=1))
plt.yticks(np.arange(0, 11, step=1))    
plt.scatter(x, y, color="blue", marker="x")

plt.subplot(3,4,12)                               # twaalfde  subplot
plt.axis(xmin=0, xmax=10, ymin=0, ymax=10)        
plt.title("Subplot 12")
plt.xticks(np.arange(0, 11, step=1))
plt.yticks(np.arange(0, 11, step=1))    
plt.scatter(x, y, color="green", marker="x")

plt.show()                                        # toon grafiek

# %% [markdown]
# ### Execute the assignment now

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>Conclusion</h2>    </font>
# </div>

# %% [markdown]
# Answer:

# %% [markdown]
# <div class="alert alert-box alert-info">
# The key is to recognize a certain pattern in the shape of the scatter plot, such as a straight line or a parabola. You can then use a suitable curve for the regression line. <br>Optionally, you can remove outliers first, but you will lose information. And those outliers might be important for making predictions about the future.  </div>

# %% [markdown]
# ### Reference list

# %% [markdown]
# [1] Wikipedia (2019). Anscombe's quartet. Accessed on 16 September 2021 via <br>&nbsp; &nbsp; &nbsp; &nbsp; https://nl.wikipedia.org/wiki/Kwartet_van_Anscombe

# %% [markdown]
# <img src="images/cclic.png" alt="Banner" align="left" width="100"/><br><br>
# Python notebook in mathematics, see Computational thinking - Programming in Python from <a href="http://www.aiopschool.be">AI Op School</a>, by F. wyffels, B. Van de Velde & N. Gesquière, licensed under a <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International license</a>.
