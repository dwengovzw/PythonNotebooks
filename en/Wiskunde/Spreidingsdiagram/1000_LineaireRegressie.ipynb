# %% [markdown]
# <img src="images/logodwengo.png" alt="Banner" width="150"/>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h1>LINEAR REGRESSION</h1>    </font>
# </div>

# %% [markdown]
# <div class="alert alert-box alert-success">
# In this notebook you will learn how to determine a regression line using Python. A regression line is a straight line that best fits the data and reflects any trend contained in the data.</div>

# %% [markdown]
# <div class="alert alert-box alert-warning">
# You use the data from the notebook 'Spreidingsdiagram - Data uit bestand'. In that notebook you can also find how to display the data in a scatter plot.</div>

# %% [markdown]
# ### Import necessary modules

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from scipy.optimize import curve_fit    # voor regressie

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>1. Loading and visualizing data</h2>    </font>
# </div>

# %% [markdown]
# You read a CSV file that contains 15 data points. You will visualize this data.<br>You can find the file in the `data` folder: `punten.csv`.

# %% [markdown]
# ### Exercise- Read the file.- Show the content.

# %% [markdown]
# - Show the scatter plot.

# %% [markdown]
# The point cloud looks *elliptical*.<br>This is referred to as a *linear relationship*: there is a *straight line* that fits the data quite well. The stronger the relationship between the points, the better the line will fit the data. <br><br>The extent to which there is a relationship between the x and y coordinates of the given points can be examined using the *correlation coefficient R*.

# %% [markdown]
# The correlation coefficient R is a real number that always lies between -1 and 1. The closer R is to 0, the weaker the relationship. The closer R is to 1 or -1, the stronger the relationship.<br>With a positive R, we speak of a positive correlation; with a negative R, of a negative correlation.

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
# <h2>2. The correlation coefficient</h2>    </font>
# </div>

# %% [markdown]
# You can determine the correlation coefficient with the `corrcoef()` function from the NumPy module. This function actually returns a table with 2 rows and 2 columns, where the correlation coefficient can be found in the first row in the second column.

# %%
print("Correlatiecoëfficiënt R =", np.corrcoef(x, y)[0,1])     # 0 wijst op eerste rij en 1 op tweede kolom

# %% [markdown]
# This indicates a *positive and strong linear relationship*.

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>3. Linear regression</h2>    </font>
# </div>

# %% [markdown]
# An (oblique) line has an equation of the form $y = a x + b$, i.e., it is the graph of a function $f$ with formula $f(x) = a x + b$. In the case that $ a = 0$, the line is horizontal. <br><br>To use Python to find the line that best fits the data—the **regression line**—you use two user-defined functions: `rechte()` and `linreg()`.- The function `rechte()` shows how the equation of an (oblique) line is constructed;The function `linreg()` searches for the coefficients in that functional form.
# The function `linreg()` internally uses the `curve_fit()` function from the SciPy module. `curve_fit()` returns two things, referred to as `popt` and `pcov`.- `popt` refers to a list of the optimal parameters (i.e., the coefficients in the equation of the best-fit line);- `pcov` refers to the 'error', the degree to which the data deviate from the fitted line.
# Here you will restrict yourself to finding the coefficients. So you only need `popt`: the list that `popt` refers to contains the coefficients $a$ and $b$.

# %%
# regressielijn is rechte

# ingeven hoe vergelijking rechte is opgebouwd 
def rechte(x, a, b):
    """Voorschrift (schuine) rechte met variabele x en coëfficiënten a en b."""
    return a * x + b

# rechte zoeken die beste past bij bepaalde data, vergelijking tonen en coëfficiënten teruggeven
def linreg(x, y):
    """Rechte best passend bij data x en y."""
    popt, pcov = curve_fit(rechte, x, y)            # curve_fit() kijkt in def rechte() hoe functievoorschrift eruitziet
    # curve_fit() geeft twee zaken terug, waaraan gerefereerd wordt met popt en pcov
    # enkel eerste nodig, popt, die a en b van gezochte rechte geeft
    a, b = popt                                     # coëfficiënten
    print("y = ", a, "x +", b)                      # toon vergelijking regressielijn
    return a, b                                     # geeft coëfficiënten terug van vergelijking regressielijn

# %% [markdown]
# In the next code cell, the function `linreg()` is called, using the given data x and y from the beginning of this notebook as the arguments for parameters x and y. The function prints the equation of the desired regression line and returns the coefficients so that you can use them later in the notebook.

# %%
# coëfficiënten regressielijn bij gegeven punten
a, b = linreg(x, y)
print(a, b)

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>4. Graph</h2>    </font>
# </div>

# %% [markdown]
# ### Now display the scatter plot and the regression line together in a graph

# %% [markdown]
# The scatter plot of the data has already been drawn. You used NumPy lists of the x-values and the y-values for that. Now you need to plot the regression line on the same graph. The graph of a straight line is built from points that are then connected. You can use the same x-values, but the y-values for the line must satisfy the equation of the regression line. In the code, those y-values are referred to with the variable `y_regressielijn`.

# %% [markdown]
# <div class="alert alert-box alert-warning">
# You learned how to draw a straight line in Python, starting from the equation, in the notebook 'Rechten'.</div>

# %%
y_regressielijn = rechte(x, a, b)                   
# y_regressielijn verwijst naar lijst y-waarden van punten gelegen op regressielijn 
# om die y-waarden te berekenen wordt er vertrokken van de gekende x-waarden
# die x-waarden worden ingevuld in uitdrukking a x + b
print(y_regressielijn)

# %% [markdown]
# Reuse the code above to plot the scatter plot and complete the code to add the regression line.

# %% [markdown]
# <div class="alert alert-box alert-info">
# In the event that the data reveal a certain trend, the regression line is also called a <b>trendline</b>.</div>

# %% [markdown]
# <div class="alert alert-box alert-warning">
# In the following notebooks, you will work on visualizing the regression line for specific data and displaying the equation of the line.</div>

# %% [markdown]
# <img src="images/cclic.png" alt="Banner" align="left" width="100"/><br><br>
# Python notebook in mathematics, see Computational thinking - Programming in Python from <a href="http://www.aiopschool.be">AI Op School</a>, by F. wyffels & N. Gesquière, licensed under a <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International license</a>.
