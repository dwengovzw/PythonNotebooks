# %% [markdown]
# <img src="images/logodwengo.png" alt="Banner" width="150"/>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h1>APPLICATION OF SCATTER PLOT: TRAIN STATIONS</h1>    </font>
# </div>

# %% [markdown]
# <div class="alert alert-box alert-success">
# In this notebook, you will try to present data regarding the location of Belgian train stations in a proper manner. To do this, you will need all the modules, functions, and methods you have learned so far!</div>

# %% [markdown]
# ### Import necessary modules

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>1. Reading data</h2>    </font>
# </div>

# %% [markdown]
# You will visualize data on train stations served by the NMBS. <br>The file `nmbsstations.csv` in the `data` folder contains the geographical coordinates of all these train stations [1].

# %% [markdown]
# In the chart you will create, the following items must be present:- the location of all Belgian train stations, each represented by a point;- the title 'Train stations Belgium';- labels on horizontal and vertical axes.

# %% [markdown]
# ### Exercise 1.1Read the file and retrieve the result.

# %% [markdown]
# How many rows and columns does the table have?<br>Rows: ...<br>Columns: ...

# %% [markdown]
# ### Exercise 1.2
# Now define the 2 variables `lengtegraad` and `breedtegraad` that you will place on the axes. <br>Make sure you place 'longitude' and 'latitude' on the most appropriate axis!

# %% [markdown]
# ### Exercise 1.3
# Convert these pandas tables to NumPy lists and print the lists.

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>2. Visualizing data</h2>    </font>
# </div>

# %% [markdown]
# Now that you have read the data and placed it into NumPy lists, you can plot the data in a graph!

# %% [markdown]
# ### Exercise 2.1
# Determine the limits for the axes.

# %% [markdown]
# ### Exercise 2.2
# Now that you know the boundaries of the dataset, you can create a preliminary plot. Try to keep this as simple as possible!

# %% [markdown]
# ### Exercise 2.3
# This is already a start, but these are clearly not just Belgian train stations. The list apparently also included train stations in the Netherlands, Germany, France, and Great Britain!<br>Now format the graph so that you get a clearer picture. To do so, do the following:- Adjust the size of the drawing window.- Adjust the range so that stations located outside Belgium are no longer listed. (If needed, look up Belgium’s geographic coordinates.)- Name the graph "Belgian Train Stations".- Label the axes.

# %% [markdown]
# If you did everything correctly, you now have a scatter plot in the shape of Belgium. If you take a quick look at it, you can very quickly recognize major cities and railways!

# %% [markdown]
# ### Exercise 2.4
# - Which cities do you recognize?- Give two cities between which an important railway line runs.

# %% [markdown]
# Answer:

# %% [markdown]
# This is just one example of how you can use scatter plots! In other notebooks, these will be used to investigate relationships between variables, for example by means of regression.

# %% [markdown]
# <div class="alert alert-box alert-info">
# Congratulations! You have just:<br>    - real data read from a CSV file;<br>    - prepared the data;<br>    - the data visualized;<br>    - formatted the graph;<br>    - the data interpreted.</div>

# %% [markdown]
# <div class="alert alert-box alert-danger">
# If you need to make a graph from data consisting of measurements, <b>it can be useful to use a coordinate system where the scale on the x-axis and y-axis is the same, and where the origin is drawn</b>! Otherwise, your data can be misrepresented, with differences being exaggerated or diminished!</div>

# %% [markdown]
# ### Reference list

# %% [markdown]
# [1] FOD BOSA. Data.gov.be. NMBS-stations. https://data.gov.be/nl/dataset/nmbs-stations

# %% [markdown]
# <img src="images/cclic.png" alt="Banner" align="left" width="100"/><br><br>
# Python notebook in mathematics, see Computational Thinking - Programming in Python from <a href="http://www.aiopschool.be">AI At School</a>, by F. wyffels, B. Van de Velde & N. Gesquière, licensed under a <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International license</a>.
