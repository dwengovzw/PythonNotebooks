# %% [markdown]
# <img src="images/logodwengo.png" alt="Banner" width="150"/>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
# <h1>LINEAR REGRESSION - TRENDLINE APPLICATION - DISNEYLAND PARIS</h1>    </font>
# </div>

# %% [markdown]
# <div class="alert alert-box alert-success">
# In this notebook you are presented with data on the number of visitors to Disneyland Paris. <br>- You determine the degree of association based on the correlation coefficient.<br>    - You determine the equation of the trendline. <br>    - You clearly present the given data and the trendline on a graph.</div>

# %% [markdown]
# ### AssignmentFor this notebook, you have a CSV file that contains figures on this. In the data, you can observe a trend: you see how the number of visitors changes as a function of the year. <br>You can find the file in the `data` folder: `eurodisney.csv`.
# - Read in the data.
# Next, you determine:- the degree of correlation between the year (for the period 1992-**2019**) and the number of visitors;the equations of the regression line (trend line) for the visitors as a function of the year. <br>
# Finally, present the given data and the trendline clearly on a graph.- What trend emerges in the data?- How many visitors could one have expected in 2020 if the trend had continued?- Compare this with the actual number of visitors.

# %% [markdown]
# <div>
#     <h2>Reference list</h2></div>

# %% [markdown]
# [1] Wikipedia. (28 September 2021). Disneyland Paris. https://en.wikipedia.org/wiki/Disneyland_Paris

# %% [markdown]
# <img src="images/cclic.png" alt="Banner" align="left" width="100"/><br><br>
# Python notebook in mathematics, see Computational thinking - Programming in Python from <a href="http://www.aiopschool.be">AI Op School</a>, by F. wyffels & N. Gesquière, licensed under a <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International license</a>.
