# %% [markdown]
# <img src="images/logodwengo.png" alt="Banner" width="150"/>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h1>IMPORTANCE OF VISUALIZATION - ANSCOMBE</h1>    </font>
# </div>

# %% [markdown]
# <div class="alert alert-box alert-success">
#     In 1973, the statistician Francis Anscombe compiled four datasets: the x- and y-coordinates of a number of points. In this notebook, you will work with this data.<br>You will also learn a new concept: the correlation coefficient.</div>

# %% [markdown]
# ### Importing necessary modules

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
# <h2>1. Loading data, computing features and interpreting</h2>    </font>
# </div>

# %% [markdown]
# ### Assignment- You read four CSV files with Ascombe's data. You can find them in the `data` folder: `anscombe1.csv`, `anscombe2.csv`, `anscombe3.csv`, and `anscombe4.csv`. Each dataset contains two columns, one with key "x" and one with key "y".- Use x$_{1}$, y$_{1}$, x$_{2}$, y$_{2}$, x$_{3}$ and y$_{3}$ as the names for the variables.- Calculate for each dataset:    * the average of the x-coordinates;    * the average of the y-coordinates;    * the variance of the x-coordinates;    * the variance of the y-coordinates.

# %% [markdown]
# - The extent to which there is a relationship between the x and y coordinates of the given points can be assessed using the correlation coefficient R.

# %% [markdown]
# <div class="alert alert-box alert-info">
# The correlation coefficient R is a real number that always lies between -1 and 1. The closer R is to 0, the weaker the association. <br>For a positive R, there is a positive association; for a negative R, a negative association.<br> If the correlation coefficient is close to 1 or -1, then there is a strong association.<br>You can determine the correlation coefficient with the `corrcoef()` function from the NumPy module. This function actually returns a table with 2 rows and 2 columns, where the correlation coefficient can be found in the first row in the second column.     </div>

# %% [markdown]
# You can determine the correlation coefficient with the `corrcoef()` function from the NumPy module. This function actually returns a table with 2 rows and 2 columns, where the correlation coefficient can be found in the first row in the second column.

# %% [markdown]
# - Compare the correlation coefficients of the three point clouds:

# %%
# correlatiecoëfficiënt voor dataset anscombe1
print("Correlatiecoëfficiënt R1 =", np.corrcoef(x1, y1)[0,1])     # 0 wijst op eerste rij en 1 op tweede kolom

# %% [markdown]
# You will notice that you get nearly the same result for each dataset.- What do you think that means for the datasets?

# %% [markdown]
# Answer:

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
# <h2>2. Visualizing data</h2>    </font>
# </div>

# %% [markdown]
# ### Assignment- Visualize the data from the four CSV files in four point clouds.

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>3. Conclusion</h2>    </font>
# </div>

# %% [markdown]
# ### AssignmentWhat is your conclusion?

# %% [markdown]
# Answer:

# %% [markdown]
# <div class="alert alert-box alert-warning">
# In the notebook 'Anscombe dataset - Linear regression' you add a best-fitting straight line to the graphs each time.  </div>

# %% [markdown]
# ### Reference list

# %% [markdown]
# [1] Wikipedia (2019). Anscombe's quartet. Retrieved on 16 September 2021 via <br>&nbsp; &nbsp; &nbsp; &nbsp; https://nl.wikipedia.org/wiki/Kwartet_van_Anscombe

# %% [markdown]
# <img src="images/cclic.png" alt="Banner" align="left" width="100"/><br><br>
# Python notebook in mathematics, see Computational thinking - Programming in Python from <a href="http://www.aiopschool.be">AI Op School</a>, by F. wyffels & N. Gesquière, licensed under a <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International license</a>.
