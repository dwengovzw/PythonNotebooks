# %% [markdown]
# <img src="images/logodwengo.png" alt="Banner" width="150"/>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h1>SCATTER PLOT - ENTER DATA MANUALLY</h1>    </font>
# </div>

# %% [markdown]
# <div class="alert alert-box alert-success">
# In this notebook you draw scatter plots.<br>You will use the pyplot submodule of the Matplotlib module. The functions of pyplot allow you to create and customize plots, including scatter plots, such as adding a grid, showing a specific part of a coordinate system, adding colors… <br>Besides the Matplotlib module, you will need a second module: NumPy. NumPy is designed to use mathematical concepts with Python and to perform scientific computations.</div>

# %% [markdown]
# <div class="alert alert-box alert-info">
#     To interpret data from multiple variables, one often begins by displaying the data in a <em>scatter plot</em> or <em>point cloud</em>.This means that the data points are plotted in a coordinate system. Then one examines, for example, the relationship between the variables and, using <em>regression</em>, can determine a best-fitting curve for the scatter plot.
# </div>

# %% [markdown]
# ### Import necessary modules

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>1. Scatter plot</h2>    </font>
# </div>

# %% [markdown]
# The data points associated with multiple variables can be displayed in a coordinate system. The result of plotting these *multivariate data* is a *scatter plot*, also called a *point cloud*. In other words: you can plot these points in a coordinate system. When you do this, you obtain a *scatter plot* or *point cloud*. Figure 1 shows an example of such a point cloud for two variables.

# %% [markdown]
# <img src="images/spreidingsdiagram.jpg" alt="Banner" width="400"/><br>
# <center>Figure 1: A scatter plot with arm strength and grip strength as variables<br> for 149people who work in physically demanding jobs, such as <br> electricians, construction workers and auto mechanics [1].</center>

# %% [markdown]
# <div class="alert alert-box alert-info">
# The pairs (0,3), (1,24), (2,12), (3,48), (4,6), for example, are <b>bi</b>variate data (data with two coordinate values, an x-coordinate and a corresponding y-coordinate). They are data points that correspond to two variables.<br><br>    To be able to plot these points on a graph, you think about the subproblems you need to tackle. You apply the computational thinking concept of <em>decomposition</em>: you break the problem down into subproblems that are more manageable.
# Using the NumPy module, you enter a list of the x-coordinates and a list of the y-coordinates.-  You create a drawing window.-  You instruct that the points should be plotted in it.-  Finally, you say that the scatter plot must be shown. </div>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>2. Manually enter data and plot data</h2>    </font>
# </div>

# %% [markdown]
# Now you will actually plot the pairs (0,3), (1,24), (2,12), (3,48), (4,6) in a graph.

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
# <h3>2.1 Manual data entry</h3>    </font>
# </div>

# %% [markdown]
# To input a list of x-coordinates and a list of y-coordinates using the NumPy module, run the following code cell.

# %%
# koppels (O,3), (1,24), (2,12), (3,48), (4,6) ingeven m.b.v. NumPy-lijsten

x = np.array([0, 1, 2, 3, 4])            # NumPy-lijst met x-coördinaten          
y = np.array([3, 24, 12, 48, 6])         # NumPy-lijst met corresponderende y-coördinaten, volgorde is van belang

# %% [markdown]
# You can use the following code cell to see what such a NumPy list looks like.

# %%
print(x, y)

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
# <h3>2.2 Creating a drawing window</h3>    </font>
# </div>

# %% [markdown]
# You already know how to create a drawing window from the notebook 'Tekenvenster'. <br> To do so, you need to use the `figure()` and `show()` functions from Matplotlib's pyplot submodule.    <br><br> Run this again below.

# %% [markdown]
# <div style='color: #690027;' markdown="1">
#     <h3>2.3 Plotting data</h3></div>

# %% [markdown]
# With the `scatter()` function from pyplot, you plot the points. <br>When plotting, Matplotlib will pair the x's and y's that have the same position in the list (see Figure 2). <br><br>

# %% [markdown]
# <img src="images/overeenkomst.png" alt="Banner" width="200"/><br>
# <center>Figure 2.</center>

# %% [markdown]
# In the following code cell, the necessary instructions for the subproblems are combined. Run the code cell.

# %%
# SPREIDINGSDIAGRAM

# koppels (O,3), (1,24), (2,12), (3,48), (4,6) ingeven m.b.v. NumPy-lijsten
x = np.array([0, 1, 2, 3, 4])            # NumPy-lijst met x-coördinaten          
y = np.array([3, 24, 12, 48, 6])         # NumPy-lijst met corresponderende y-coördinaten, volgorde is van belang 

plt.figure()                             # creëer tekenvenster

plt.scatter(x, y)                        # plot punten
      
plt.show()                               # toon grafiek

# %% [markdown]
# So such a graph is a scatter plot. <br>As you can see, Python uses blue dots by default to represent the points.

# %% [markdown]
# Note that pyplot's `axis()` is not required if you have data points to display. Python will then choose the window settings itself to display all the data points.

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>3. Format chart</h2>    </font>
# </div>

# %% [markdown]
# Once you have drawn the graph in the drawing window, you can consider formatting it. <br>Some options are:- adjusting the range of the drawing window;- adjusting the size of the drawing window;- adding a schedule.

# %% [markdown]
# To that end, you need to add instructions to the code: `plt.axis()` for the range, `figsize=(a, b)` for the size, and `plt.grid(True)` for the grid.

# %% [markdown]
# In the code cell below, the code for the above scatter plot has been expanded to make it look a bit neater.<br>You should, among other things, take into account the smallest and largest x- and y-values when choosing the range.

# %% [markdown]
# ### Example 3.1

# %%
# VOORBEELD 3.1

# koppels (O,3), (1,24), (2,12), (3,48), (4,6) ingeven m.b.v. Numpy-lijsten
x = np.array([0, 1, 2, 3, 4])            # NumPy-lijst met x-coördinaten          
y = np.array([3, 24, 12, 48, 6])         # NumPy-lijst met corresponderende y-coördinaten, volgorde is van belang

plt.figure(figsize=(9,5))                       # creëer tekenvenster

# vensterinstellingen
plt.axis(xmin=-1, xmax=5, ymin=-10, ymax=70)    # bereik x-as en y-as

plt.grid(True)                                  # rooster

plt.scatter(x, y)                               # plot punten  

plt.show()                                      # toon grafiek

# %% [markdown]
# ### Example 3.2

# %% [markdown]
# The spacing on the horizontal and vertical axes can also be adjusted manually. Since the spacing on the horizontal axis is fine, adjust only the vertical axis: instead of steps of 10, make them steps of 5. To do this, use the `yticks()` function from pyplot and the `arange()` function from NumPy.

# %%
# VOORBEELD 3.2

# koppels (O,3), (1,24), (2,12), (3,48), (4,6) ingeven m.b.v. Numpy-lijsten
x = np.array([0, 1, 2, 3, 4])                    # NumPy-lijst met x-coördinaten          
y = np.array([3, 24, 12, 48, 6])                 # NumPy-lijst met corresponderende y-coördinaten, volgorde is van belang

plt.figure(figsize=(9,5))                        # creëer tekenvenster

# vensterinstellingen
plt.axis(xmin=-1, xmax=5, ymin=-10, ymax=70)     # bereik x-as en y-as
plt.yticks(np.arange(-10, 71, step=5))           # verdeling y-as (halfopen interval [-10, 71[ verdelen in stappen van 5)

plt.grid(True)                                   # rooster
 
plt.scatter(x, y)                                # plot punten

plt.show()                                       # toon figuur

# %% [markdown]
# <div class="alert alert-box alert-info">
#     Using NumPy's arange() function, a NumPy list is generated. <br>    Here the instruction np.arange(-10, 71, step=5) returns the list: <br>      <center>  [-10,  -5,   0,   5,  10,  15,  20,  25,  30,  35,  40,  45,  50, 55,  60,  65,  70].</center></div>

# %% [markdown]
# ### Assignment 3.1See the code from example 3.2.
# - In the code it says `scatter(x, y)`. <br>What would happen if you change that to `scatter(y, x)`?- In the code, `grid(True)` is used to display a grid on the graph. <br>How can you modify the code so that there is no grid? (You can achieve that in several ways).- In the code it says `ymax=70`. <br>What would happen if you change that to `ymax=40`?- In the code it says `arange(-10,71,step=5)`. <br>What would happen if you changed that to `arange(-10,70,step=10)`?

# %% [markdown]
# Answer:

# %% [markdown]
# ### Assignment 3.2Plot the scatter plot for the following points:(28,33); (40,35); (41,47); (44;35); (45;55);(51,56); (54,50); (57,50); (57,70); (60,65);(62,53); (72,82); (74,80); (90,95); (113,100). <br>Make sure the plot window is large enough to clearly see the spread of the points. Ensure a good distribution on the x-axis and y-axis.

# %%
# ANTWOORD OPDRACHT 3.2

# %% [markdown]
# ### Assignment 3.3Oops! Someone clearly wasn't well-rested when this was programmed. Everything is all mixed up.-  Run the code cell. Do you see that an error message appears? -  Reorder the code below so that it works correctly.

# %%
# OPDRACHT 3.3

plt.show()                                       

plt.grid(True)                                   
   
plt.yticks(np.arange(-4, 21, step=2))             
 
plt.scatter(b, a)                                

a = np.array([1, 4, 7, 10, 13])                   
b = np.array([10, 8, 6, 4, 2])                   

plt.figure(figsize=(9,5))

# %%
# ANTWOORD OPDRACHT 3.3

# %% [markdown]
# <div class="alert alert-box alert-info">
# Finding and fixing errors in a program is called <b>debugging</b>.    <img src="images/debuggendwengo.png" alt="Banner" align="center" width="100"/><br>
# Why is an error in a computer program called a <em>bug</em>?<br>The term "bug" arose when, in old computers, a real insect (in English, "bug") was inside, causing them to suddenly stop working. To solve this problem, they had to find the insect and remove it (debugging). </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Optional formatting of graphs is covered in the notebook <em>'Formatting of graphs'</em>.</div>

# %% [markdown]
# <div class="alert alert-box alert-info">
# When creating a graph, <b>concepts of computational thinking</b> come into play:<br>    - <b>Decomposition</b>: when constructing a chart, you should carefully consider the different elements that should be included in the chart. <br>    <img src="images/decompositiedwengo.png" alt="Banner" align="center" width="100"/><br>
# - <b>Algorithm</b>: the construction of the graph itself follows an algorithm, as shown in the diagram. <br>    <img src="images/schema.png" alt="Banner" align="center" width="250"/><br>
#     You program this algorithm in Python. <br>    <img src="images/algoritmedwengo.png" alt="Banner" align="center" width="100"/><br>
#     - <b>Pattern recognition</b>: the structure of the algorithm proceeds in a similar manner for each chart. <br>    <img src="images/patroonherkenningdwengo.png" alt="Banner" align="center" width="100"/><br><br>
#     - The order of the instructions in the algorithm is crucial. The instructions are executed one by one. This <b>principle of programming</b> is called <b>sequence</b>.     <img src="images/sequentiedwengo.png" alt="Banner" align="center" width="100"/><br>
#  </div>

# %% [markdown]
# ### Reference list

# %% [markdown]
# [1] Introduction to Statistics. https://onlinestatbook.com/Online_Statistics_Education.pdf

# %% [markdown]
# <img src="images/cclic.png" alt="Banner" align="left" width="100"/><br><br>
# Python notebook in mathematics, see Computational thinking - Programming in Python from <a href="http://www.aiopschool.be">AI Op School</a>, by F. wyffels, B. Van de Velde & N. Gesquière is licensed under a <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International license</a>.
