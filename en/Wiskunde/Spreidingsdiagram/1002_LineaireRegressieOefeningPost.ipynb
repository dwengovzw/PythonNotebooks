# %% [markdown]
# <img src="images/logodwengo.png" alt="Banner" width="150"/>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h1>LINEAR REGRESSION - TRENDLINE APPLICATION - THE POST</h1>    </font>
# </div>

# %% [markdown]
# <div class="alert alert-box alert-success">
# In this notebook you are presented with data on Belgian postal delivery. <br>- You determine the degree of association based on the correlation coefficient.<br>- You determine the equation of the regression line. <br>    - You clearly present the given data and the regression line on a graph.</div>

# %% [markdown]
# ### AssignmentIn the figure you can see that the number of letters a Belgian sends per year decreased sharply in the period 2010-2015. The number of letters sent therefore shows a **downward trend**. This has led to the mail carrier no longer delivering your letters daily.
# You are looking at the number of letters sent per Belgian per year as a function of the year. <br>Retrieve the data you need from the figure. Enter the data as follows: - the x-values correspond to the year;- the y-values correspond to the number of letters per Belgian per year.
# Pay attention to the wording '**as a function of**'! From that you can infer which quantity goes on the x-axis and which on the y-axis.
# Next, you determine:- the degree of association between the year and the number of letters based on the correlation coefficient;- the equation of the **trendline**. <br>
# Finally, clearly present the given data and the trendline on a graph.
# Tip: You can improve the representation of the trendline by using additional x-values. This way, you can indicate how the figures may evolve in the future. With such a trendline, you are essentially setting up a mathematical model that allows you to study possible evolutions.
# Don't forget to import the necessary modules.

# %% [markdown]
# <img src="images/postbode.jpg" alt="Banner" width="400"/>
# <center>Figure 1: The mail carrier no longer comes to the house every day. [1]</center>

# %% [markdown]
# Proceed step by step:- import the necessary modules;- enter the data;- visualize the data in a scatter plot;- calculate the correlation coefficient;- enter the user-defined functions you need for linear regression;- have the coefficients of the trendline calculated;- compute the y-values for the points located on the trendline;- draw the trendline on the scatter plot;- use extra x-values to visualize the trend into the future.

# %% [markdown]
# <div class="alert alert-box alert-warning">
# In another notebook "LineaireRegressieOefeningPostpakken' you are given the following two assignments to complete: <br>    - Do the same for the number of postal parcels that a Belgian sends annually.<br>- Between which quantities is there the strongest correlation: between the number of letters and the year, or between the number of parcels and the year?</div>

# %% [markdown]
# # Example solution

# %% [markdown]
# ### Import required modules

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>1. Entering and visualizing data</h2>    </font>
# </div>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>2. The correlation coefficient</h2>    </font>
# </div>

# %% [markdown]
# Interpretation:

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>3. Linear regression</h2>    </font>
# </div>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>4. Graph</h2>    </font>
# </div>

# %% [markdown]
# <div>
#     <h2>Reference list</h2></div>

# %% [markdown]
# [1] tlb, mtm. (21 February 2017). Postman no longer comes to the house every day. *Het Nieuwsblad*. https://www.nieuwsblad.be/cnt/dmf20170220_02742099

# %% [markdown]
# <img src="images/cclic.png" alt="Banner" align="left" width="100"/><br><br>
# Python notebook in mathematics, see Computational Thinking - Programming in Python from <a href="http://www.aiopschool.be">AI Op School</a>, by F. wyffels & N. Gesquière, licensed under a <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International license</a>.
