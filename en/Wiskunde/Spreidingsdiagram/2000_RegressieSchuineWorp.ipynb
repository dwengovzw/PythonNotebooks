# %% [markdown]
# ![UGentDwengologo](images/bannerugentdwengo.png)

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h1>REGRESSION - PROJECTILE MOTION</h1>    </font>
# </div>

# %% [markdown]
# <div class="alert alert-box alert-success">
# In this notebook, you are presented with data from an angled throw that was collected using the Kinovea software.</div>

# %%
from IPython.display import YouTubeVideo

# %% [markdown]
# Watch the following video showing a projectile launched at an angle, whose data were collected. (Video by C. Boitsios.)

# %%
YouTubeVideo("lsHVw0XfFYo")

# %% [markdown]
# ### AssignmentFor this notebook, you have a CSV file with the data: `schuineworp2.csv`.You can find the file in the `data` folder.
# - Read in the data.- Plot the given data on a graph.- Draw a curve that fits the given data.- Determine the equation of the curve.

# %% [markdown]
# <div>
# <h2> Thanks to:</h2></div>

# %% [markdown]
# ![Saint Bavo](images/logobavo.jpg)

# %% [markdown]
# ![by-nc-sa](images/cclic.png)
# Python notebook in mathematics, see Computational thinking - Programming in Python from <a href="http://www.aiopschool.be">AI Op School</a>, by F. wyffels & N. Gesquière, licensed under a <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International license</a>.
