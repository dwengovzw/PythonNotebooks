# %% [markdown]
# <img src="images/logodwengo.png" alt="Banner" width="150"/>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h1>SCATTER PLOT APPLICATION - REGRESSION </h1><h2>POVERTY WORLD POPULATION - EXERCISE</h2>    </font>
# </div>

# %% [markdown]
# <div class="alert alert-box alert-success">
# In this notebook, you will determine a regression line for the data regarding the poverty rate in the world population.</div>

# %% [markdown]
# The poverty line is set at $1.90 per person per day. The World Bank collects data to monitor the percentage of the world's population living below the poverty line and to conduct research into the extent and causes of that poverty.

# %% [markdown]
# ### Import necessary modules

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>1. Loading and visualizing data</h2>    </font>
# </div>

# %% [markdown]
# You read a CSV file that contains the percentage of the world population living below the poverty line over several decades [1]. You will visualize this data. <br>You can find the file in the `data` folder: `armoedecijferswereldbank.csv`.

# %% [markdown]
# ### ExerciseRead the file and show the point cloud.

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>2. Linear regression and graphical representation</h2>    </font>
# </div>

# %% [markdown]
# ### AssignmentWrite a Python script that, when executed, displays the regression line that fits the scatter plot.

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>3. Equation of the regression line</h2>    </font>
# </div>

# %% [markdown]
# ### Assignment- Create a Python script to determine the equation of the regression line.- Run the script.

# %% [markdown]
# ### Reference list

# %% [markdown]
# [1] Poverty headcount ratio at $1.90 a day (2011 PPP) (% of population). https://data.worldbank.org/topic/11

# %% [markdown]
# <img src="images/cclic.png" alt="Banner" align="left" width="100"/><br><br>
# Python notebook in mathematics, see Computational Thinking - Programming in Python from <a href="http://www.aiopschool.be">AI Op School</a>, by F. wyffels & N. Gesquière, licensed under a <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International license</a>.
