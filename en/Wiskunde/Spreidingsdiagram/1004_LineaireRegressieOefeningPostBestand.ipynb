# %% [markdown]
# <img src="images/logodwengo.png" alt="Banner" width="150"/>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
# <h1>LINEAR REGRESSION - TRENDLINE APPLICATION - THE POST (FILE)</h1>    </font>
# </div>

# %% [markdown]
# <div class="alert alert-box alert-success">
# In this notebook you get data in a file about Belgian postal delivery. <br>    - You determine the strength of the association using the correlation coefficient.<br>    - You determine the equation of the regression line. <br>- You clearly present the given data and the regression line on a graph.</div>

# %% [markdown]
# ### AssignmentThe number of letters sent annually in Belgium is on a downward trend. The number of parcels being sent is booming. For this notebook, you have a CSV file that contains figures on this for the period 2004–2017. <br>You can find the file in the `data` folder: `post.csv`.
# - Read in the data.
# Next, you determine:- the degree of correlation between the year and the number of letters;- the degree of correlation between the year and the number of packages;- the equations of the trend lines for the letters and for the parcels, each as a function of the year. <br>
# Finally, present the given data and the trend lines clearly on a graph.

# %% [markdown]
# ### Extra assignmentNow look at bpost’s revenue from letters and parcels. The unit of the revenue is the same, so you can visualize both on the same graph. The revenue from the letters sent annually in Belgium shows a downward trend. The revenue from the parcels that are sent is increasing. The data are in the same file as in the first assignment.
# Next, you determine:- the degree of correlation between the year and the income from the letters;- the correlation between the year and the revenue from packages;- the equations of the regression lines for the letters and for the parcels, each as a function of the year. <br>
# Finally, clearly display the given data and the regression lines on a single graph.

# %% [markdown]
# ### Another extra assignmentExamine the relationship between letter revenue as a function of parcel revenue.Also fit a regression line for this and visualize it.

# %% [markdown]
# <div>
#     <h2>Reference list</h2></div>

# %% [markdown]
# [1] Grommen, S. (20 August 2018). Why Bpost wants to overhaul mail delivery: the declining letter mail in figures. <br> &nbsp; &nbsp; &nbsp; &nbsp;https://www.vrt.be/vrtnws/nl/2018/08/20/de-tanende-brievenpost-en-boomende-pakjespost-in-cijfers/

# %% [markdown]
# <img src="images/cclic.png" alt="Banner" align="left" width="100"/><br><br>
# Python notebook in mathematics, see Computational Thinking - Programming in Python from <a href="http://www.aiopschool.be">AI Op School</a>, by F. wyffels, B. Van de Velde & N. Gesquière, licensed under a <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International license</a>.
