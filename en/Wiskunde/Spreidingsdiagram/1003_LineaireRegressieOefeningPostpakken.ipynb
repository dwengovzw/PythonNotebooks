# %% [markdown]
# <img src="images/logodwengo.png" alt="Banner" width="150"/>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h1>LINEAR REGRESSION - TRENDLINE APPLICATION - POSTAL PARCELS</h1>    </font>
# </div>

# %% [markdown]
# <div class="alert alert-box alert-success">
# In this notebook you are presented with a similar assignment as in the notebook 'Linear regression - Trendline application - Post'. </div>

# %% [markdown]
# ### AssignmentIn the figure you can see that the number of parcels a Belgian sends per year increased in the period 2010-2015.
# You are viewing the number of postal parcels sent per Belgian per year as a function of the year. <br>Extract the data you need from the figure.
# Next, you determine:- the degree of association between the year and the number of postal packages based on the correlation coefficient;- the equation of the **trendline**. <br>
# Finally, clearly present the given data and the trendline on a graph.
# - Between which quantities is there the most correlation: between the number of letters and the year, or between the number of postal parcels and the year?

# %% [markdown]
# <img src="images/postbode.jpg" alt="Banner" width="400"/>
# <center>Figure 1: Postman no longer comes to the house every day. [1]</center>

# %% [markdown]
# <div>
# <h2>Reference list</h2></div>

# %% [markdown]
# [1] tlb, mtm. (21 February 2017). Mail carrier no longer comes to the house every day. *Het Nieuwsblad*. https://www.nieuwsblad.be/cnt/dmf20170220_02742099

# %% [markdown]
# <img src="images/cclic.png" alt="Banner" align="left" width="100"/><br><br>
# Python notebook in mathematics, see Computational Thinking - Programming in Python from <a href="http://www.aiopschool.be">AI Op School</a>, by F. wyffels & N. Gesquière, licensed under a <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International license</a>.
