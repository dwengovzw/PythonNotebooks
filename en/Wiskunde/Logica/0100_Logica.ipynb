# %% [markdown]
# <img src="images/bannerugentdwengo.png" alt="Banner" width="400"/>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h1>TRUTH TABLES</h1>    </font>
# </div>

# %% [markdown]
# <div class="alert alert-box alert-success">
# In this notebook you will learn how to generate truth tables with Python.</div>

# %% [markdown]
# <div class="alert alert-box alert-info">
# A proposition is denoted by $p, q,  r \;...$ <br>    A statement is <b>true</b> or <b>not true (false)</b>. This corresponds to the Boolean values <b>True</b> and <b>False</b>. <br> A true statement is often denoted by <b>$1$</b> and a false one by <b>$0$</b>.<br><br>You can also compose statements, for example using <b>and</b> ($\land$) and <b>or</b> ($\lor$). You can also make use of <b>not</b> (~ or $\neg$); these correspond to <b><span style="background-color:whitesmoke; font-family:consolas; font-size:1em;">and</span></b>, <b><span style="background-color:whitesmoke; font-family:consolas; font-size:1em;">or</span></b> and <b><span style="background-color:whitesmoke; font-family:consolas; font-size:1em;">not</span></b> (that is, and, or, and not).<br><br>Also important are the arrows: the implication arrow ($\Rightarrow$) and the equivalence arrow ($\Leftrightarrow$), which correspond to <b><span style="background-color:whitesmoke; font-family:consolas; font-size:1em;">implies</span></b> and <b><span style="background-color:whitesmoke; font-family:consolas; font-size:1em;">equivalentto</span></b> (thus <b>implies</b> and  <b>is equivalent to</b>).</div>

# %% [markdown]
# <div class="alert alert-box alert-info">
#     <b>The statement $p \wedge q$ is only true if both $p$ and $q$ are true.</b> <br>So if either one is false or both are false, then $p \wedge q$ is false.<br><br>    <b>A statement $p \vee q$ is only false if $p$ and $q$ are both false.</b><br>So if either one is true or both are true, then $p \vee q$ is true.<br>This <b>or</b> is an <b>inclusive or</b>, and thus differs from <em>either/or</em>.<br><br><b>The statement $\neg p$ is true if $p$ is false and vice versa.</b><br><br><b>The statement $p \Rightarrow q$ is only false if $p$ is true and $q$ is false.</b> <br> If $p$ is false, then $p \Rightarrow q$ is true regardless of the truth value of $q$.<br><br><b>The statement $p \Leftrightarrow q$ is true whenever $p$ and $q$ have the same truth value.</b><br> So $p \Leftrightarrow q$ is true if $p$ and $q$ are both true or both false.</div>

# %% [markdown]
# <div class="alert alert-box alert-success">
# In Python you have access by default to the logical operators <b>and</b>, <b>or</b> and <b>not</b>. Notations such as ~ and $\neg$, and arrows such as $\Rightarrow$ and $\Leftrightarrow$ are not available by default. But you do need those arrows, for example, if you want to generate a truth table for certain statements.</div>

# %% [markdown]
# ### Computational thinking assignment-  Think about how you can still automatically generate the truth table for statements that contain $\neg$.-  Consider how you can still have the truth table automatically generated from statements in which these arrows occur.

# %% [markdown]
# Answer:

# %% [markdown]
# ### Install and import necessary modules

# %%
pip install prettytable

# %%
pip install tabulate

# %%
from scripts import ttg           # truth table generator

# %% [markdown]
# In the code you can use `and`, `or`, `not`, `~`, `implies`, `=>`, `equivalentto`, `<=>`, and parentheses. So you cannot use $\land$, $\lor$, or $\neg$.

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>1. Construction of a truth table</h2>    </font>
# </div>

# %% [markdown]
# $p$ has a truth value of <b>$1$</b> or <b>$0$</b>. The same applies to $q$.
# How many possible combinations can you form this way for $p$ combined with $q$?<img src="images/boompq.png" alt="Banner" width="300">
#
# You can display this in a table as follows:<img src="images/waarheidstabelpq.png" alt="Banner" width="100">

# %% [markdown]
# You can also retrieve this table with Python as part of a truth table. In the next code cell you can see how to do this. <br>Run the code cell.

# %%
print(ttg.Truths(["p", "q"]))

# %% [markdown]
# ### Assignment 1.1Show the first three columns of a truth table with statements `p`, `q` and `r`.

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
# <h2>2. Truth table for a simple statement with 'and', 'or', 'not'</h2>    </font>
# </div>

# %% [markdown]
# -  In the truth table, you can easily derive the value of `~p` from the value of `p`. <br>(Sometimes ~p is also denoted as $\neg$ p.)

# %%
print(ttg.Truths(["p"], ["not p"]))

# %% [markdown]
# **Let in the given instruction in place of the square brackets.**

# %%
# ook mogelijk als notatie
print(ttg.Truths(["p"], ["~p"]))

# %% [markdown]
# -  From the truth values of `p` and `q`, you deduce that of p $\wedge$ q.

# %%
print(ttg.Truths(["p", "q"], ["p and q"]))

# %% [markdown]
# -  From the truth values of `p` and `q` you derive those of p $\wedge$ q and ~p in a single truth table.

# %%
print(ttg.Truths(["p", "q"], ["p and q", "not p"]))

# %% [markdown]
# ### Assignment 2.1-  From the truth values of `p` and `q`, you derive that of p $\lor$ q.

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>3. Truth table for a simple statement with 'implies', 'equivalent'</h2>    </font>
# </div>

# %% [markdown]
# - From the truth values of `p` and `q`, you derive that of p $\Rightarrow$ q.

# %% [markdown]
# - From the truth values of `p` and `q` you derive that of p $\Leftrightarrow$ q.

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>4. Truth table for a compound statement</h2>    </font>
# </div>

# %% [markdown]
# ### Exercise 4.1From the truth values of `p`, `q`, and `r`, you derive the truth value of:- p $\land$ q $\land$ r;- p $\lor$ q $\lor$ r;- (p $\; \lor \;$ (~q)) $\; \Rightarrow$ r.
# Do this with only one truth table.<br>Show all ***intermediate steps*** that you would perform manually in the columns of that truth table.

# %% [markdown]
# ### Exercise 4.2From the truth values of `p` and `q`, you infer the truth value of:- p $\land$ q;- p $\lor$ q;- (p $\; \lor \;$ (~q)) $\; \Rightarrow$ ~p.
# Do this with only one truth table.<br>Show all the ***intermediate steps*** you would manually perform in the columns of the truth table.

# %% [markdown]
# <div class="alert alert-box alert-info">
# A <b>tautology</b> is a statement that is always true.<br> A <b>contradiction</b> is a statement that is never true.    </div>

# %% [markdown]
# ### Example using a variableFrom the truth values of `p`, you infer the truth value of:- p $\lor$ (~p);
# Next, you ask whether p $\; \lor \;$ (~p) is a tautology or a contradiction.

# %%
waarheidstabel = ttg.Truths(["p"], ["p or (~p)"])
print(waarheidstabel)

# %%
waarheidstabel.valuation()

# %% [markdown]
# <div class="alert alert-box alert-danger">
# Note that <b>~p</b> or <b>not p</b> should be typed in parentheses when <b>~</b> or <b>not</b> follows another operator.    </div>

# %% [markdown]
# ### Exercise 4.3 (with variable)Generate a truth table that, from the truth values of `p` and `q`, derives the truth values of the following expressions, use a variable:- p $\Leftrightarrow$ q;- p $\land$ (~p);

# %% [markdown]
# ### Exercise 4.4 (with variable)Generate a truth table that, from the truth values of `p` and `q`, derives the truth value of the following expression; use a variable:- (p $\; \land \;$ q) $\; \Rightarrow$ p.
# Next, you ask whether (p $\; \land \;$ q) $\; \Rightarrow$ p is a tautology or a contradiction.

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>5. Exercises</h2>    </font>
# </div>

# %% [markdown]
# ### Exercise 5.1From the truth value of `p` you infer the truth value of:Please provide the Dutch text you’d like me to translate to English.- p $\; \wedge \;$ (~p).
# Then you ask whether p $\; \wedge \;$ (~p) is a tautology or a contradiction.

# %% [markdown]
# ### Exercise 5.2For each of the expressions below, generate a truth table that, from the truth values of `a` and `c`, determines the truth value of the expression each time:- $a \; \land \; c \; \lor \; (\sim a) \; \land \; (\sim c)$;- $(a \; \land \; c) \; \lor \; ((\sim a) \; \land \; (\sim c))$;- $a \; \land \; (c \; \lor \; (\sim a)) \; \land \; (\sim c)$.
#
# For each truth table, determine whether the expression is a tautology or a contradiction.

# %% [markdown]
# ### Exercise 5.3Determine the truth value of `p` if:- (p $\; \land \;$ q) $\; \Rightarrow \;$ (q $\; \lor \;$ r) is false;- (q $\; \land \;$ r) $\; \Rightarrow \;$ (p $\; \land \;$ q) is false.

# %% [markdown]
# ### Exercise 5.4
# Given are four statements:- Storm is a dog.- Appa is a cat.- Cheeta is a monkey.- Mowgli is a tiger.
# Determine when the following statement is true or false:<br>If Appa is a cat and Storm is a dog, then it is not true that Cheeta is a monkey or Mowgli is a tiger.

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>6. Layout with pandas</h2>    </font>
# </div>

# %%
tabel = ttg.Truths(["p", "q"], ["p => q", "p <=> q"])

# %%
print(tabel)

# %% [markdown]
# By importing the Python module `pandas`, you can give this table a nicer layout. Try it out!

# %%
import pandas

# %%
tabel.as_pandas()

# %% [markdown]
# <img src="images/cclic.png" alt="Banner" align="left" width="100"/><br><br>
# Notebook Python in the Mathematics lesson, see Computational Thinking - Programming in Python from <a href="http://www.aiopschool.be">AI Op School</a>, by F. wyffels & N. Gesquière is licensed under a <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International license</a>.
