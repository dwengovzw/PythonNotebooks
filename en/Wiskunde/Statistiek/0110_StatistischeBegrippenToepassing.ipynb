# %% [markdown]
# <img src="images/bannerugentdwengo.png" alt="Banner" width="400"/>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h1>APPLICATION OF ABSOLUTE AND RELATIVE FREQUENCY</h1>    </font>
# </div>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>SPACE MISSIONS</h2>    </font>
# </div>

# %% [markdown]
# <div class="alert alert-box alert-success">
#     In this notebook you extract information from a <em>real-world</em> dataset.    </div>

# %% [markdown]
# In this notebook you use the dataset *Space Mission Launches* [1]. This dataset is provided in a CSV file `missionlaunches.csv` in the `data` folder.

# %% [markdown]
# ### Import required modules

# %%
import pandas as pd  # importeer pandas-module

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>1. Absolute frequency</h2>    </font>
# </div>

# %% [markdown]
# ### Assignment 1.1
# Load the dataset in Python. Refer to it with the variable `ruimtemissies`.

# %%
# dataset inladen

# %% [markdown]
# At first glance, this dataset looks quite complex.

# %% [markdown]
# ### Assignment 1.2
# -  How many space missions does the table contain?-  How many characteristics of space missions do you find?

# %% [markdown]
# Answer:

# %% [markdown]
# ### Assignment 1.3
# You will investigate for each organization how many space missions they have already carried out.

# %% [markdown]
# -  The column `Organisation` shows for each space mission which organization carried it out. So create a variable `organisaties` that refers to that column.

# %%
# organisaties

# %% [markdown]
# - How many space missions has each organization carried out?

# %%
# aantal ruimtemissies per organisatie

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>2. Information</h2>    </font>
# </div>

# %% [markdown]
# <div class="alert alert-box alert-info">
# To find out how many space missions each organization has carried out, you compiled the absolute frequency table. It shows the number of space missions per organization.<br>To set up the absolute frequency table, one has to count. Counting 4324 values would take a human several hours of work; for a computer that takes only a few milliseconds.</div>

# %% [markdown]
# Using the absolute frequency table, you can already derive a lot of useful information from the dataset that seemed complicated at first glance.

# %% [markdown]
# <div class="alert alert-box alert-info">
# Note that 'data' and 'information' are not synonyms. </div>

# %% [markdown]
# ### Assignment 2.1
# - Which organization has completed the most missions?

# %% [markdown]
# Answer:

# %% [markdown]
# - How many missions has Roscosmos completed so far?

# %% [markdown]
# Answer:

# %% [markdown]
# Of course, you can read this yourself from the absolute frequency table. But you can also obtain this using program code.

# %% [markdown]
# ### Assignment 2.2

# %% [markdown]
# - Write program code that uses a variable to refer to the number of space missions by Boeing and displays that number on the screen.

# %%
# Boeing

# %% [markdown]
# ### Assignment 2.3- Calculate the absolute frequency of the value `SpaceX` and refer to it with the variable `absolute_frequentie_SpaceX`.- Next, display on the screen the sum of the number of space missions that were organized by Boeing and by SpaceX. Provide a sentence with it.

# %% [markdown]
# ### Assignment 2.4- Calculate the size of the *mission_launches* dataset and refer to it with the variable `aantal_ruimtemissies`.

# %% [markdown]
# - How many rows does the dataset contain?

# %% [markdown]
# Answer:

# %% [markdown]
# ### Assignment 2.5You can see whether a mission succeeded or failed in the column named `Mission_Status`.- How many missions succeeded and how many failed?

# %% [markdown]
# Answer:

# %% [markdown]
# ### Assignment 2.6Now write a Python script that returns the following information:-  the number of successful missions;-  the number of completely failed missions (i.e., the sum of the number of missions with Failure or Prelaunch Failure);-  the total number of failed missions.

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h3>3. Relative frequency</h3>    </font>
# </div>

# %% [markdown]
# ### Assignment 3.1- What percentage of the space missions were carried out by NASA?

# %% [markdown]
# Answer:

# %% [markdown]
# ### Assignment 3.2- Write Python code to calculate the percentage of missions that failed before launch (`Prelaunch Failure`).

# %% [markdown]
# ### Assignment 3.3- Construct a relative frequency table.- Use the relative frequency table to determine the percentage of space missions that were carried out by ESA.

# %% [markdown]
# ### Assignment 3.4-  Calculate with Python what percentage of the missions have an active `Rocket_Status`?

# %% [markdown]
# ### Reference list

# %% [markdown]
# [1] Space Mission Launches. https://www.kaggle.com/datasets/sefercanapaydn/mission-launcheswith data from https://nextspaceflight.com/

# %% [markdown]
# <img src="images/cclic.png" alt="Banner" align="left" width="100"/><br><br>
#
# Notebook Python in mathematics - Statistics, by D. De Bolster, F. wyffels & N. Gesquière, is licensed under a <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International license</a>.
