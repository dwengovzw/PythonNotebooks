# %% [markdown]
# <img src="images/bannerugentdwengo.png" alt="Banner" width="400"/>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h1>APPLICATION WITH ABSOLUTE AND RELATIVE FREQUENCY</h1>    </font>
# </div>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>VIDEOGAMES</h2>    </font>
# </div>

# %% [markdown]
# <div class="alert alert-box alert-success">
# In this notebook, you use a dataset that is provided in a CSV file `video_games_sales.csv` in the `data` folder.    </div>

# %% [markdown]
# While doing the exercises, you will notice that the dateset has not been updated for a while. The most recent data are from 2017.

# %% [markdown]
# ## Assignment
# Use Python code to provide an answer to the following questions.
# - How many video games from the list were released in 2015?- Give the percentage of video games in the dataset that were released by Nintendo?- Generate a relative frequency table for the genres of the video games.- Give the percentage of video games from the list that were released for the PlayStation. These are the video games for the platforms PS, PS2, PS3, PS4, or PSP.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# Tips:<ul><li>First, view the dataset on the screen and visit the source of the data. It contains an explanation of what each column means. This helps to maintain an overview during the exercise.</li></ul><ul><li>Afterwards, you complete each task step by step. Trying to complete the entire exercise in one go increases the chance of errors.</li></ul></div>

# %% [markdown]
# ### Reference list

# %% [markdown]
# Video Game Sales. https://www.kaggle.com/datasets/gregorut/videogamesales with data from https://www.vgchartz.com/

# %% [markdown]
# <img src="images/cclic.png" alt="Banner" align="left" width="100"/><br><br>
#
# Python Notebook in Mathematics - Statistics, by D. De Bolster, F. wyffels & N. Gesquière, is licensed under a <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International license</a>.
