# %% [markdown]
# <img src="images/bannerugentdwengo.png" alt="Banner" width="400"/>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h1>THE NORMAL DISTRIBUTION: APPLICATION</h1>    </font>
# </div>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>WEATHER STATION</h2>    </font>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#         The normal distribution is a probability distribution that applies to many random variables. In this notebook, this is illustrated by means of several large datasets.</div>

# %% [markdown]
# ### Import the necessary modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from scipy.stats import norm

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>1. Weather Station Exercise</h2>    </font>
# </div>

# %% [markdown]
# The data in a dataset are in many cases approximately normally distributed. <br>When working with large datasets, using a computer can save you a lot of time.

# %% [markdown]
# Consider the dataset `weather_in_Antwerp.csv` in the `data` folder [1]. This dataset contains measurements of the weather in Antwerp at different times.

# %% [markdown]
# **Throughout the following exercises, you will look for the probability that the air pressure is lower than 1 bar (1000 mbar or 1000 hPa).** <br>
# You do this in *two ways*: once without and once with the normal distribution.

# %% [markdown]
# ### Assignment 1.1

# %% [markdown]
# -  Load the dataset and plot a clear histogram of the relative frequencies of the air pressure (`"barometer"`).

# %% [markdown]
# - Show the elements of `air pressure'.

# %% [markdown]
# ### Assignment 1.2

# %% [markdown]
# -  Use a new variable to refer to all values from `"barometer"` that are less than 1 bar.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Remember that in <i>Statistics in Python 3: Analyzing Data</i> you used slicing to filter values from a column.</div>

# %% [markdown]
# -  Calculate the ratio of the length of the filtered column to the length of the original column.

# %% [markdown]
# - What is the meaning of this number?

# %% [markdown]
# Answer:

# %% [markdown]
# -  You obtained a good approximation of the probability that the air pressure in Antwerp is less than 1 bar. Why do you refer to this as an approximation?

# %% [markdown]
# Answer:

# %% [markdown]
# -  How can you ensure that this approach becomes more accurate?

# %% [markdown]
# Answer:

# %% [markdown]
# -  Using the histogram, estimate the mean and the standard deviation of the air pressure.

# %% [markdown]
# Answer:

# %% [markdown]
# ### Assignment 1.3

# %% [markdown]
# You now calculate the same probability by approximating the data with a normal distribution.

# %% [markdown]
# -  Calculate the exact average air pressure with Python.-  Also calculate the standard deviation of the air pressure. This is possible with the function `std()` (from the English *standard deviation*), analogous to the `mean()` function.-  Refer to the results using the variables `luchtdruk_gemiddelde` and `luchtdruk_standaardafwijking`.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Take another look at the notebook <i>Statistics in Python 3: Analyzing Data</i> if you no longer remember how to calculate the mean of the elements of a column.</div>

# %% [markdown]
# - Do the values match your estimate?

# %% [markdown]
# Answer:

# %% [markdown]
# - Use this mean and this standard deviation as parameters for a normal distribution. <br> Write code to show this normal distribution along with the histogram in a chart.

# %% [markdown]
# You can see that the air pressure is indeed approximately normally distributed.

# %% [markdown]
# To easily compute the probability that a normally distributed random variable is less than a given value, use the cumulative distribution function.

# %% [markdown]
# - Use the cumulative distribution function to calculate the probability that the air pressure is less than 1000 mbar.

# %% [markdown]
# - How much do the results of both methods differ?

# %% [markdown]
# Answer:

# %% [markdown]
# - What does that mean for that chance?

# %% [markdown]
# Answer:

# %% [markdown]
# ### Assignment 1.4

# %% [markdown]
# Use the normal distribution to calculate the following probabilities:* the probability that the air pressure is higher than 1040 mbar;* the probability that the air pressure is between 1000 mbar and 1010 mbar.

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>2. Exercise: Misleading graphs</h2>    </font>
# </div>

# %% [markdown]
# You saw earlier that you could increase the accuracy of a probability estimate by collecting more data. However, this does not always lead to an estimate that better matches reality. This is illustrated in the following exercises.

# %% [markdown]
# ### Assignment 2.1

# %% [markdown]
# The dataset from the previous exercise contains data from a weather station that recorded a measurement every half hour from 2012 to 2016. Suppose a research team wants to increase the accuracy of the calculations by adding measurements up to 2019 to the dataset, but due to an error they only add the measurements for the months of May through August.
# **See what the effect of this error is on the estimate of the temperature.**
# -  First, load the updated dataset `weather_in_Antwerp_2012to2019.csv` into the `data` folder in [1].-  Generate a histogram of the temperature for the dataset `weather_in_Antwerp_2012to2016` and for `weather_in_Antwerp_2012to2019`. The temperature is given in °C in the column `temp`.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# Display the histograms in a separate graphics window.</div>

# %% [markdown]
# - What differences between the two datasets can you observe? Pay attention to the mean and the standard deviation.

# %% [markdown]
# Answer:

# %% [markdown]
# ### Assignment 2.2

# %% [markdown]
# -  Calculate the mean and the standard deviation of both datasets.-  Refer to it using the variables `temperatuur_gemiddelde_2016`, `temperatuur_gemiddelde_2019`, `temperatuur_standaardafwijking_2016` and `temperatuur_standaardafwijking_2019`.

# %% [markdown]
# - Write code to generate a plot of two normal distributions. A blue curve approximates the dataset up to 2016 and a red curve up to 2019.

# %% [markdown]
# ### Assignment 2.3

# %% [markdown]
# Calculate the probability that the temperature is higher than 30 °C.-  First use a normal distribution based on the dataset up to 2016 to approximate the probability.-  Afterwards, use the updated dataset up to 2019.

# %% [markdown]
# The estimated probability that a temperature higher than 30 °C occurs over the course of a year is greater with the incorrectly updated dataset.

# %% [markdown]
# Various terms are used to describe this phenomenon, such as **selective shopping**, **selection bias**, or **cherry-picking**. Sometimes it happens unconsciously, but all too often it is used to distort results. <br>Consider climate deniers who, for example, can add more measurements from the winter months to the dataset and thus conclude that climate change does not exist. It is therefore important to always check the source of the data from a study before drawing your own conclusions.

# %% [markdown]
# ### Reference list

# %% [markdown]
# [1] Weather dataset in Antwerp, Belgium. https://www.kaggle.com/datasets/ramima/weather-dataset-in-antwerp-belgium<br>Data used with permission from CustomWeather, owner of the data www.customweather.com used in this dataset.

# %% [markdown]
# <img src="images/cclic.png" alt="Banner" align="left" width="100"/><br><br>
#
# Notebook Python in mathematics - Statistics, by D. De Bolster, F. wyffels & N. Gesquière, is licensed under a <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International license</a>.
