# %% [markdown]
# <img src="images/bannerugentdwengo.png" alt="Banner" width="400"/>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
# <h1>STATISTICS IN PYTHON 3: VISUALIZING DATA (HISTOGRAM)</h1>        <h2>Application: Spotify playlist</h2>    </font>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# In this notebook you generate a histogram with Python.    </div>

# %% [markdown]
# ### First import the necessary modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# At the location `data/artists.csv` you will find a dataset that contains information about artists on Spotify [1].
# ## AssignmentDraw a clear histogram that displays the distribution of the artists' popularity. Choose a suitable bin width and ensure that the values on both axes are clear.

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>Solution</h2>    </font>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     To easily indicate the boundaries of the classes you can use the function <code>linspace()</code>from the module <code>NumPy</code>.<br> <code>np.linspace(a, b, c)</code> generates an array with c elements from a to b that are equally spaced.</div>

# %% [markdown]
# <div>Some examples:<ul>
#   <li><code>np.linspace(0, 10, 6)</code> = <code>[0, 2, 4, 6, 8, 10]</code></li>  <li><code>np.linspace(200, 600, 9)</code> = <code>[200, 250, 300, 350, 400, 450, 500, 550, 600]</code></li>  <li><code>np.linspace(8, 9, 5)</code> = <code>[8, 8.25, 8.5, 8.56, 9]</code></li>  <li>...</li>
# </ul>
# </div>

# %% [markdown]
# Which class width did you choose and why?

# %% [markdown]
# Answer:

# %% [markdown]
# What happens if we choose the bins too wide? Why does this lead to an unclear histogram?

# %% [markdown]
# Answer:

# %% [markdown]
# What happens if we choose the classes too narrowly? Why does this lead to an unclear histogram?

# %% [markdown]
# Answer:

# %% [markdown]
# ### Assignment 3.2

# %% [markdown]
# By adding the argument `density=True` to `plot()`, you obtain a histogram of the relative frequencies. Apply this to the histogram of the popularity of the artists.

# %% [markdown]
# ### Reference list

# %% [markdown]
# [1] 6K Spotify Playlists. https://www.kaggle.com/datasets/viktoriiashkurenko/278k-spotify-songs

# %% [markdown]
# <img src="images/cclic.png" alt="Banner" align="left" width="100"/><br><br>
#
# Python notebook in mathematics - Statistics, by D. De Bolster, F. wyffels & N. Gesquière, licensed under a <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International license</a>.
