# %% [markdown]
# <img src="images/bannerugentdwengo.png" alt="Banner" width="400"/>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
# <h1>STATISTICS IN PYTHON 3: VISUALIZING DATA (BAR CHART)</h1>    </font>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# In this notebook, you will learn how to generate a bar chart with Python.    </div>

# %% [markdown]
# ### First import the necessary modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# In this notebook, you will visualize the dataset in the file `smartphoneafhankelijk.csv`. This dataset contains results from the Digimeter [1]: what percentage of Flemish people in a given age group feel dependent on the smartphone (in 2022)?

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>1. Dataset</h2>    </font>
# </div>

# %% [markdown]
# ### Assignment 1.1

# %% [markdown]
# Load the dataset, refer to it with the variable `smartphone`, and display it on the screen. The file name is `smartphoneafhankelijk.csv` and you can find the file in the `data` folder.

# %% [markdown]
# Here you are dealing with a **bivariate variable** in which each 'data point' consists of an age group and a percentage. For each age group, smartphone dependency is examined. This data is best represented with a bar chart. The age groups go on the x-axis, and the percentage on the y-axis.

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>2. Bar chart</h2>    </font>
# </div>

# %% [markdown]
# ### Assignment 2.1

# %% [markdown]
# Visualize this data by using the pandas method `plot()` with `kind="bar"` and applying it to `smartphone`.Also provide the `plot()` method with a value for the `figsize` parameter, namely `figsize=(15,8)`.

# %% [markdown]
# ### Reference list

# %% [markdown]
# [1] imec.digimeter 2022. https://www.imec.be/nl/kennisuitwisseling/techmeters/digimeter/digimeter-2022

# %% [markdown]
# <img src="images/cclic.png" alt="Banner" align="left" width="100"/><br><br>
#
# Python notebook in Mathematics - Statistics, by F. wyffels & N. Gesquière, is licensed under a <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International license</a>.
