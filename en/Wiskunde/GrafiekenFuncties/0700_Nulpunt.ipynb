# %% [markdown]
# <img src="images/logodwengo.png" alt="Banner" style="width: 150px;"/>

# %% [markdown]
# <div style='color: #690027;' markdown="1">
# <h1>SLIDERS AND LINES</h1></div>

# %% [markdown]
# <div class="alert alert-box alert-success">
# Intro</div>

# %% [markdown]
# ### Importing required modules

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# <div style='color: #690027;' markdown="1">
#     <h2>1.Title</h2></div>

# %% [markdown]
# ### Subheading 1.1Text

# %% [markdown]
# Text

# %%
# CODECEL

# %% [markdown]
# <div class="alert alert-box alert-success">
# Box 1: Explanation</div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Box 2: Reference</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# Box 3: Fun fact</div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# Box 4: Note</div>

# %% [markdown]
# <img src="images/cclic.png" alt="Banner" align="left" style="width:100px;"/><br><br>
# Python notebook in mathematics, see <a href="http://www.aiopschool.be">AI At School</a>, by F. wyffels, B. Van de Velde & N. Gesquière is licensed under a <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International license</a>.
