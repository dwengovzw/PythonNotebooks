# %% [markdown]
# <img src="images/kiksmeisedwengougent.png" alt="Banner" width="1100"/>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
# <h1>FROM JPG FILE TO NPY FILE</h1>    </font>
# </div>

# %% [markdown]
# <div class="alert alert-box alert-success">
# This notebook provides an example of how to convert a jpg file to a grayscale image, represented by a matrix, and how you can save that image as a npy file.You use the scikit-image (skimage) module for this, which provides algorithms for digital image processing and <em>computer vision</em>.</div>

# %% [markdown]
# ### Import the necessary modules

# %%
import numpy as np
import matplotlib.pyplot as plt
import scripts.helper as helper
import skimage.color as skc

# %% [markdown]
# <div class="alert alert-block alert-warning">
# The notebooks 'Matrices and grayscale images' and 'Tensors and RGB' explain how a grayscale image and a colour image are represented so that a computer understands them.</div>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
# <h2>1. Colour Photo</h2>    </font>
# </div>

# %% [markdown]
# A photo was taken with a smartphone of a self-written four: a four written with a black marker on a white sheet. <br>This photo was imported into Paint and cropped. The photo was then converted to 28 by 28 pixels in Paint.<br>The result was saved as `vier.jpg`.

# %% [markdown]
# Read the photo and query the mathematical dimension. View the photo.

# %%
four = plt.imread("images/vier.jpg")

# %%
four.shape                    # jpg so RGB and 3D-tensor
# Out:
# (28, 28, 3)

# %%
plt.imshow(four)              # black on white background, 28 by 28 pixels

# %% [markdown]
# View the three matrices of the tensor.

# %%
print(four[:,:,0])     # red shades
print(four[:,:,1])     # green shades
print(four[:,:,2])     # blue shades
# Out:
# [[223 227 219 220 222 222 221 221 222 223 228 228 224 221 228 219 218 220
#   218 221 218 216 220 218 219 218 219 220]
#  [221 223 223 224 221 219 223 222 224 239 233 215 241 229 222 226 224 218
#   215 219 218 216 220 217 219 218 219 220]
#  [221 220 223 224 219 220 227 226 222 153  51  55  85 191 237 225 223 220
#   220 225 216 224 218 219 220 219 219 220]
#  [222 220 220 220 219 226 222 235 159  43  67  65  61  56 200 233 226 221
#   223 218 220 219 220 221 220 219 219 220]
#  [220 218 217 222 222 225 222 245 122  62  71  70  77  65 146 244 229 224
#   225 221 223 225 216 222 220 219 219 220]
#  [219 218 218 223 223 224 232 229  68  76  63  75  73  67 207 229 229 233
#   227 228 222 222 226 221 220 219 219 220]
#  [220 218 221 221 223 227 240 155  64  77  72  71  64 101 237 240 208 181
#   213 227 227 227 217 221 220 219 219 220]
#  [219 220 223 221 228 231 237  67  75  75  78  84  61 207 247  65  54  50
#    65 227 230 225 227 220 221 219 219 220]
# ...

# %% [markdown]
# Note that the values range from 0 to 255.

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
# <h2>2. Convert the Colour Photo to a Greyscale Image</h2>    </font>
# </div>

# %% [markdown]
# Convert the photo to a greyscale image and look at the effect on the mathematical dimension.

# %%
four_grey = skc.rgb2gray(four)         # convert jpg (RGB) to greyscale 
four_grey.shape                  # represented by matrix instead of tensor
# Out:
# (28, 28)

# %%
plt.imshow(four_grey, cmap="gray")

# %% [markdown]
# View the matrix.

# %%
print(four_grey)
# Out:
# [[0.86130863 0.8769949  0.85460431 0.85852588 0.87226275 0.87226275
#   0.86834118 0.86834118 0.86636902 0.87029059 0.88091647 0.88091647
#   0.8652302  0.85346549 0.88989843 0.86049804 0.85657647 0.86750784
#   0.85966471 0.87142941 0.85966471 0.85182157 0.86750784 0.85966471
#   0.86358627 0.85966471 0.86049804 0.86441961]
#  [0.85346549 0.87029059 0.87029059 0.88010588 0.86834118 0.86049804
#   0.87618431 0.86636902 0.87421216 0.92405373 0.89743608 0.82684784
#   0.92880863 0.88483804 0.85738706 0.88205529 0.88010588 0.85966471
#   0.8479     0.86358627 0.85966471 0.85182157 0.86750784 0.85574314
#   0.86358627 0.85966471 0.86049804 0.86441961]
#  [0.86244745 0.86441961 0.87618431 0.88010588 0.86021529 0.86413686
#   0.88569412 0.88177255 0.85401608 0.58342784 0.17444588 0.19013216
#   0.30777922 0.72346549 0.90385765 0.87167451 0.87029059 0.86441961
#   0.86441961 0.88402745 0.84873333 0.88010588 0.85657647 0.86049804
#   0.86441961 0.86049804 0.86049804 0.86441961]
# ...

# %% [markdown]
# Note that the values are between 0 and 1. This means that all values from 0 to 255 have been divided by 255. The values have been **normalised**, so a rescaling has happened. 0 corresponds to black and 1 to white.

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
# <h2>3. Invert Colours</h2>    </font>
# </div>

# %% [markdown]
# By performing an operation on the matrix, you can invert the colours. By replacing 0 with 1, 1 by 0, 0.3 by 0.7 and so on, you get a white four on a black background. <br>Test this out by running the next code cell.

# %%
four_bw = 1 - four_grey    # inverting grey values
print(four_bw.shape)
# Out:
# (28, 28)

# %%
plt.imshow(four_bw, cmap="gray")

# %% [markdown]
# Have a look at the matrix and see how the first elements have been modified.

# %%
print(four_bw)
# Out:
# [[0.13869137 0.1230051  0.14539569 0.14147412 0.12773725 0.12773725
#   0.13165882 0.13165882 0.13363098 0.12970941 0.11908353 0.11908353
#   0.1347698  0.14653451 0.11010157 0.13950196 0.14342353 0.13249216
#   0.14033529 0.12857059 0.14033529 0.14817843 0.13249216 0.14033529
#   0.13641373 0.14033529 0.13950196 0.13558039]
#  [0.14653451 0.12970941 0.12970941 0.11989412 0.13165882 0.13950196
#   0.12381569 0.13363098 0.12578784 0.07594627 0.10256392 0.17315216
#   0.07119137 0.11516196 0.14261294 0.11794471 0.11989412 0.14033529
#   0.1521     0.13641373 0.14033529 0.14817843 0.13249216 0.14425686
#   0.13641373 0.14033529 0.13950196 0.13558039]
#  [0.13755255 0.13558039 0.12381569 0.11989412 0.13978471 0.13586314
#   0.11430588 0.11822745 0.14598392 0.41657216 0.82555412 0.80986784
#   0.69222078 0.27653451 0.09614235 0.12832549 0.12970941 0.13558039
#   0.13558039 0.11597255 0.15126667 0.11989412 0.14342353 0.13950196
#   0.13558039 0.13950196 0.13950196 0.13558039]
# ...

# %% [markdown]
# Optional: You may choose to convert the values back to numbers in [0, 255]. You can do it as follows:

# %%
four_bw_0to255 = four_bw * 255
print(four_bw_0to255)
four_bw_uint = four_bw_0tot255.astype("uint")
print(four_bw_uint)
# Out:
# [[ 35.3663  31.3663  37.0759  36.0759  32.573   32.573   33.573   33.573
#    34.0759  33.0759  30.3663  30.3663  34.3663  37.3663  28.0759  35.573
#    36.573   33.7855  35.7855  32.7855  35.7855  37.7855  33.7855  35.7855
#    34.7855  35.7855  35.573   34.573 ]
#  [ 37.3663  33.0759  33.0759  30.573   33.573   35.573   31.573   34.0759
#    32.0759  19.3663  26.1538  44.1538  18.1538  29.3663  36.3663  30.0759
#    30.573   35.7855  38.7855  34.7855  35.7855  37.7855  33.7855  36.7855
#    34.7855  35.7855  35.573   34.573 ]
#  [ 35.0759  34.573   31.573   30.573   35.6451  34.6451  29.148   30.148
#    37.2259 106.2259 210.5163 206.5163 176.5163  70.5163  24.5163  32.723
#    33.0759  34.573   34.573   29.573   38.573   30.573   36.573   35.573
#    34.573   35.573   35.573   34.573 ]
#  [ 32.573   33.7855  33.7855  33.7855  35.6451  30.148   34.148   22.723
#   102.5163 219.448  196.8067 198.9509 202.8067 207.0192  63.0192  28.5163
# ...

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
# <h2>4. Save and Read Image</h2>    </font>
# </div>

# %% [markdown]
# With the right functions, you can save the matrix as a matrix, without changing the mathematical dimension.<br>If you were to save the matrix as a `jpg`, then the mathematical dimension changes, and you will get a tensor again.

# %% [markdown]
# You can, however, save the file as a npy file.

# %% [markdown]
# Save in the `data` folder as follows:

# %%
np.save("data/four.npy", four_bw)         # save as npy file

# %% [markdown]
# You retrieve the npy file as follows:

# %%
four2 = np.load("data/four.npy")          # reading in a npy file

# %% [markdown]
# You can now show the result.

# %%
plt.figure()

plt.subplot(1,2,1)
plt.imshow(four, cmap="gray")
plt.subplot(1,2,2)
plt.imshow(four2, cmap="gray")

plt.show()

# %%
# check format
print(four2.shape)

# %% [markdown]
# You can review the npy file again:

# %%
print(four2)

# %% [markdown]
# You will see that it has not changed.

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>5. Task</h2>    </font>
# </div>

# %% [markdown]
# ### Assignment 5.1
# Convert the colour photo of the Morteratsch Glacier into a greyscale image.<br>You can find the photo `lvtmorteratsch2018.jpg` at the location `images`.

# %% [markdown]
# ### Assignment 5.2: Expansion
# Save the result as an npy file in the `data` folder.<br>You can download that file for later use. You can temporarily find it on the server in the `data` folder.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# The 'MNIST' notebook allows you to test whether the model can read your handwritten numbers. This notebook can be used to help prepare the data. <br>The notebook <em>0310_MNISTDataset.ipynb</em> introduced the MNIST dataset.</div>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
# <h2>6. Upload Your Own image</h2>    </font>
# </div>

# %% [markdown]
# Using the cells below, you can upload and save your own `jpg` image in the `images` folder as `own_image.jpg`. You can then later convert it into a `npy` as above.

# %%
display(helper.upload_image_widget)

# %%
own_image = helper.save_image()

# %% [markdown]
# <img src="images/cclic.png" alt="Banner" align="left" width="100"/><br><br>
# Python in STEM Notebook, see <a href="http://www.aiopschool.be">AI At School</a>, by F. Wyffels & N. Gesquière is licensed under a <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International License</a>.

# %% [markdown]
# <div>
# <h2>With support from</h2></div>

# %% [markdown]
# <img src="images/kikssteun2.png" alt="Banner" width="800"/>
