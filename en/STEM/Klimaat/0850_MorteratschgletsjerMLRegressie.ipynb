# %% [markdown]
# <img src="images/kiksmeisedwengougent.png" alt="Banner" width="1100"/>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h1>ML REGRESSION WITH DATA FROM THE MORTERATSCH GLACIER</h1>    </font>
# </div>

# %% [markdown]
# <div class="alert alert-box alert-success">
# In this notebook, the future length of the Morteratsch Glacier is predicted by applying <em>regression</em>.<br>  To do this, you apply a technique from <em>machine learning</em>. It is typical of this approach to split the data into <em>training data and test data</em>. The data is also always <em>standardized</em>. Using the test data, one will check whether the system predicts accurately enough. <br>The functionality of the Python module <em>scikit-learn</em> is used.    </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     This notebook is a follow-up to the notebooks 'Linear regression with data from the Morteratsch Glacier' and 'Stomata - Tree Height - ML Regression'.</div>

# %% [markdown]
# Since the Industrial Revolution, the concentration of greenhouse gases in the atmosphere has steadily increased. Since 1880, the average global temperature has risen by about 0.85 °C. This warming is accompanied by ocean warming, a 20 cm rise in sea level, more frequent extreme weather events, and a 40% decrease in Arctic sea ice. Glacial ice is also melting, almost everywhere in the world.<br><br>The meltwater from mountain glaciers will largely determine how much sea level will rise in the future. Possible scenarios speak of a rise of up to 30 cm due to the melting of mountain glaciers. <br>Moreover, glaciers have an impact on local water supplies and are important for tourism.<br>The rate at which a glacier’s volume decreases under the influence of global temperature increase varies from glacier to glacier. Local factors play a role in this: e.g., the orientation of the glacier, the extent to which the glacier is in the shade ... [1].

# %% [markdown]
# The 6 km long Morteratsch Glacier is located in Switzerland and lies in the shadow of the surrounding mountain peaks for much of the year [1].

# %% [markdown]
# <img src="images/lvtmorteratsch2018.jpg" alt="Banner" width="600"/>
# <center> Photo: Morteratsch 2018, &copy; Lander Van Tricht.</center>

# %% [markdown]
# Lander Van Tricht (VUB) provided us with data from his research into how the Morteratsch Glacier is evolving. Since 1880, records have been kept of how many meters the glacier retreats each year [2].

# %% [markdown]
# ## Assignment**Create a trend line for the annual retreat of the Morteratsch.**
# - Read the data from the file `morteratsch.csv` in the folder `data`.- Visualize the data in this file.- The scatter plot shows a trend. Determine the equation of a straight line as the trendline. Use training and test data.- Display the trendline on the chart.

# %% [markdown]
# <div>
#     <h2>Reference list</h2></div>

# %% [markdown]
# [1] Zekollari, H., Fürst, J. J., & Huybrechts, P. (2014). Modelling the evolution of Vadret da Morteratsch, Switzerland, since the Little Ice Age and into the future.<br>&nbsp; &nbsp; &nbsp; &nbsp; *Journal of Glaciology*, 60 (244). doi:10.3189/2014JoG14J053.<br>[2] Van Tricht, L. (2019). By e-mail.

# %% [markdown]
# <div>
#     <h2>With the support of</h2></div>

# %% [markdown]
# <img src="images/kikssteun.png" alt="Banner" width="1100"/>

# %% [markdown]
# <img src="images/cclic.png" alt="Banner" align="left" width="100"/><br><br>
# Notebook KIKS, see <a href="http://www.aiopschool.be">AI At School</a>, by F. wyffels & N. Gesquière, is licensed under a <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International license</a>.
