# %% [markdown]
# <img src="images/kiksmeisedwengougent.png" alt="Banner" width="1100"/>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h1>ML REGRESSION WITH DATA FROM THE SILVRETTA GLACIER</h1>    </font>
# </div>

# %% [markdown]
# <div class="alert alert-box alert-success">
# In this notebook, the future thickness of the Silvretta Glacier is predicted by applying <em>regression</em>.<br>  To do this, you apply a technique from <em>machine learning</em>. A typical step in this approach is to split the data into <em>training data and test data</em>. The data are also always <em>standardized</em>. Using the test data, one checks whether the system predicts accurately enough. <br>The functionality of the Python module <em>scikit-learn</em> is used.   </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     This notebook follows on from the notebooks 'Regression with data from the Silvretta Glacier' and 'Stomata - Tree Height - ML Regression'.</div>

# %% [markdown]
# Since the Industrial Revolution, the concentration of greenhouse gases in the atmosphere has steadily increased. Since 1880, the average global temperature has risen by about 0.85 °C. This warming is accompanied by an increase in ocean temperatures, a 20 cm rise in sea level, more frequent extreme weather events, and a 40% decrease in Arctic sea ice. Glacial ice is also melting, almost everywhere in the world.<br><br>The meltwater from mountain glaciers will largely determine how much the sea level will rise in the future. Possible scenarios speak of a rise of up to 30 cm due to the melting of mountain glaciers. <br>Moreover, glaciers have an impact on local water supplies and are important for tourism.<br>The rate at which a glacier's volume decreases due to the global temperature rise varies from glacier to glacier. Local factors play a role in this, e.g., the glacier's orientation and the extent to which it is in the shade ... [1].

# %% [markdown]
# The 3 km long Silvretta Glacier is located in the northeast of Switzerland. Since 1954, the glacier has already lost 400 m in length [3].

# %% [markdown]
# Lander Van Tricht (VUB) provided us with data from his research into how the Silvretta Glacier is evolving. Since 1919, the glacier's annual thinning has been recorded in meters [2].

# %% [markdown]
# ## Assignment**Create a trendline for the annual thinning of the Silvretta.**
# - Read the data from the file `silvretta.csv` in the `data` folder.- Visualize the data in this file.The scatter plot shows a trend. Determine the equation of a straight line as a trendline. Use training and test data.- Show the trendline on the chart.

# %% [markdown]
# <div>
#     <h2>Reference list</h2></div>

# %% [markdown]
# [1] Zekollari, H., Fürst, J. J., & Huybrechts, P. (2014). Modelling the evolution of Vadret da Morteratsch, Switzerland,<br> &nbsp; &nbsp; &nbsp; &nbsp;since the Little Ice Age and into the future. *Journal of Glaciology*,60, 244. doi:10.3189/2014JoG14J053 <br>[2] Van Tricht, L. (2019). Via email. <br>[3] Schweizer Gletscher. Glacier Monitoring Switzerland (Glamos).<br> &nbsp; &nbsp; &nbsp; &nbsp; Accessed on 18 August 2019 via https://www.glamos.ch/factsheet#/A10g%2F05.

# %% [markdown]
# <img src="images/cclic.png" alt="Banner" align="left" width="100"/><br><br>
# Notebook KIKS, see <a href="http://www.aiopschool.be">AI at School</a>, by F. wyffels & N. Gesquière is licensed under a <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International license</a>.
