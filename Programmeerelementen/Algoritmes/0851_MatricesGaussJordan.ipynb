# %% [markdown]
# ![Dwengologo](images/logodwengo.png)

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h1>STELSEL VAN LINEAIRE VERGELIJKINGEN OPLOSSEN MET METHODE VAN GAUSS-JORDAN</h1>
#     </font>
# </div>

# %% [markdown]
# <div class="alert alert-box alert-success">
# ALs je een stelsel manipuleert a.d.h.v. elementaire rij-operaties, dan zal de overeenkomstige matrix mee veranderen. Het doel is om de matrix te diagonaliseren zodat je de oplossingen van het stelsel onmiddellijk kunt aflezen.
# </div>

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>1. Inleiding</h2>
#     </font>
# </div>

# %% [markdown]
# Eerst zal je enkele functies definiëren, die overeenkomen met de elementaire rij-operaties, om die (eventueel) achteraf te gebruiken.

# %% [markdown]
# ##### Opdracht 1.1: Maak een functie die twee rijen (rij_1 en rij_2) van plaats wisselt. De functie heeft als naam `verwissel` en krijgt als parameters: `matrix, rij_1, rij_2`.

# %% [markdown]
# ##### Opdracht 1.2: Maak een functie met als naam `deel_door` die alle elementen van een rij deelt door een getal. De functie krijgt als parameters `rij` en `deler` mee.

# %% [markdown]
# ##### Opdracht 1.3: Maak een functie met als naam `trek_veelvoud_af` die van een rij een veelvoud van een andere rij aftrekt. De functie heeft als parameters `rij_1`, `rij_2` en `factor`. Als er bijvoorbeeld een 1 in rij_1 staat en een 3 in rij_2 en de factor is 2, dan is het de bedoeling dat de 1 in rij_1 vervangen wordt door 1-3*2.

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>2. Diagonaliseren</h2>
#     </font>
# </div>

# %% [markdown]
# Beschouw het volgende stelsel van vergelijkingen:
# $$\begin{cases} 3 x + y - 4 z = 3 \\ 3 y - 5 z = -11 \\ x - 5 y - 2 z = 11 \end{cases}$$
#
# De overeenkomstige matrix is: $$\begin{bmatrix} 3 & 1 & -4 & 3 \\ 0 & 3 & -5 & -11 \\ 1 & -5 & -2 & 11 \end{bmatrix}$$

# %%
matrix = [[3, 1, -4, 3], [0, 3, -5, -11], [1, -5, -2, 11]]

# %% [markdown]
# Na het diagonaliseren van deze matrix wil je de volgende vorm bekomen, waarbij *x, y, z* de oplossing van het stelsel geeft:
# $$\begin{bmatrix} 1 & 0 & 0 & x \\ 0 & 1 & 0 & y \\ 0 & 0 & 1 & z \end{bmatrix}$$

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>3. Functie om te diagonaliseren</h2>
#     </font>
# </div>

# %% [markdown]
# Na het diagonaliseren van een matrix wil je de volgende vorm bekomen, waarbij *x, y, z* de oplossing van het stelsel geeft:
# $$\begin{bmatrix} 1 & 0 & 0 & x \\ 0 & 1 & 0 & y \\ 0 & 0 & 1 & z \end{bmatrix}$$

# %% [markdown]
# ##### Opdracht 2.1: Maak een functie met de naam `diagonaliseren` om een matrix te diagonaliseren, de functie krijgt als parameter een matrix mee:
# <ul>
#     <li>Creëer een 1 op de eerste plaats (linksboven op de diagonaal van de matrix). Deel daarvoor de eerste rij door het eerste element van die rij (in dit geval 3). Werk met de functie <code>deel_door</code>.</li>
#     <li>Zorg dat in de eerste kolom nu overal nullen komen te staan behalve bij het eerste element, dit blijft 1. Gebruik de functie <code>trek_veelvoud_af</code></li>
#     <li>Ga naar de volgende kolom en doe hetzelfde voor het tweede element op de diagonaal van de matrix, tot een matrix bekomen wordt zoals hierboven.</li>
#     <li>Tot slot geeft de functie een rijmatrix [<em>x, y, z</em>] terug, die overeenkomt met de oplossing van de matrix.</li>
# </ul>
# Maak gebruik van lussen (<em>loops</em>) om de code zo eenvoudig mogelijk te houden.
# </b>

# %% [markdown]
# Test deze functie uit.

# %%
matrix = [[3, 1, -4, 3], [0, 3, -5, -11], [1, -5, -2, 11]]
diagonaliseren(matrix)

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h2>4. Oefeningen</h2>
#     </font>
# </div>

# %% [markdown]
# ##### Oefening 4.1: Bepaal de oplossing van dit stelsel:
# $\begin{cases} x + y + z = 27 \\ x - 2 y = 0 \\ - y + z = 3 \end{cases}$

# %% [markdown]
# ##### Oefening 4.2: Bepaal de oplossing van dit stelsel:
# $\begin{cases} 3 x - y = 0 \\ y - 2 z = 2 \\ - x + z = 7 \end{cases}$

# %% [markdown]
# <div>
#     <font color=#690027 markdown="1">
#         <h3>Referentie</h3>
#     </font>
# </div>

# %% [markdown]
# Kris Coolsaet (2024). *Algoritmen en programmeren. Nota’s voor de leerkrachten*.

# %% [markdown]
# # Met dank aan
# ![ptilogo](images/ptikortrijk.jpg)

# %% [markdown]
# ![by-nc-sa](images/cclic.png)
#
# Notebook Numerieke methodes met Python van <a href="https://dwengo.org/algoritmes">Lesthema Algoritmes</a>, van M. Benoit, F. wyffels & N. Gesquière is in licentie gegeven volgens een <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Naamsvermelding-NietCommercieel-GelijkDelen 4.0 Internationaal-licentie</a>.
