# %% [markdown]
# # Het super sociaal netwerk
#
# In deze notebook verken je verschillende technieken om inzicht te krijgen in een sociaal netwerk. Je zal bekijken hoe uitgespreid het netwerk is. Welke influencers er zijn in het netwerk en welke communities er zijn in het netwerk.

# %% [markdown]
# Voor je start, installeer en importeer je de nodige bibliotheken.

# %%
# !pip install networkx
# Out:
# Requirement already satisfied: networkx in c:\users\tomne\documents\work\applications\pythonnotebooks\.venv\lib\site-packages (3.4.2)

# %%
import csv
import numpy as np
import networkx as nx

# %% [markdown]
# ## Het sociaal netwerk laden
#
# In de map *dataset* kan je een bestand vinden met de naam *hero-network.csv*. Elke lijn van dit bestand bevat twee namen van superhelden. Zo'n paar werd aan het bestand toegevoegd wanneer de twee helden samen voorkomen in een strip.

# %% [markdown]
# **Opdracht**:
# - Open het bestand *hero-network.csv* in de map *dataset*;
# - Bekijk het bestand.
# - Zijn er helden die je herkent?
# - Zijn er helden die je niet herkent?

# %% [markdown]
# Met de volgende codecel laden we de inhoud van het csv bestand in in een numpy array.

# %%
# Lees het csv bestand.
data = None
with open('./dataset/hero-network-small-sample.csv', newline='') as csvfile:
    data = np.array(list(csv.reader(csvfile)))
    
# Verwijder de eerste rij, deze bevat de kolomnamen.
data = data[1:]

# %% [markdown]
# ## Inzicht krijgen in de dataset
#
# Voor je start met een analyse op een dataset, is het goed om een idee te krijgen van de gegevens die in die dataset zitten. Hieronder verkennen we een aantal eenvoudige eigenschappen van de dataset.

# %% [markdown]
# Voer de volgende codecel uit om 20 willekeurige heldenkoppels af te drukken.

# %%
# Print 20 radom rijen van de data.
print(data[np.random.randint(0, len(data), 20)])
# Out:
# [['DRAGONFLY II/MEIKO Y' 'WATSON-PARKER, MARY ']
#  ["SHANNA/SHANNA O'HARA" 'VASHTI']
#  ['BALDER [ASGARDIAN]' 'MASTERSON, KEVIN']
#  ['AUSTIN, SUSAN' 'HOGUN [ASGARDIAN]']
#  ['THING/BENJAMIN J. GR' 'WATSON-PARKER, MARY ']
#  ['CYCLOPS/SCOTT SUMMER' 'KINCAID, DR. JANE FO']
#  ['BLACK WIDOW/NATASHA ' 'STANKOWICZ, FABIAN']
#  ['ANGEL/WARREN KENNETH' 'SHIP']
#  ['INVISIBLE WOMAN/SUE ' 'PAIBOK, CAPT. [SKRUL']
#  ['CYCLOPS/SCOTT SUMMER' 'ICEMAN/ROBERT BOBBY ']
#  ['CALLISTO' 'MARROW/SARAH ']
#  ['BISHOP /' 'WOLVERINE/LOGAN ']
#  ['CAPTAIN BRITAIN/BRIA' 'ICEMAN/ROBERT BOBBY ']
#  ['JAMESON, J. JONAH' 'MAYE, APRIL']
#  ['MASTERSON, KEVIN' 'STEELE, MARCY MASTER']
#  ['COUNTERWEIGHT/JACK P' 'NIGHTCRAWLER/KURT WA']
#  ['HYDROMAN/MORRIE BENC' 'RHINO']
#  ['THRENODY' 'X-MAN/NATHAN GREY ']
#  ['CAPTAIN AMERICA' 'IKARIS/IKE HARRIS [E']
#  ['GEE/ALEX POWER' 'JUSTICE II/VANCE AST']]

# %% [markdown]
# Door het formaat van onze numpy array af te drukken, komen we te weten hoeveel heldenkoppels er in de dataset zitten.

# %%
# Druk het formaat af van de dataset.
print(f"Er zitten {data.shape[0]} duo's in de dataset.")
# Out:
# Er zitten 5542 duo's in de dataset.

# %% [markdown]
# Wanneer je het csv bestand bekijkt, zal je zien dat er veel helden meerdere keren in de dataset voorkomen. Met de volgende codecel tellen we hoeveel unieke helden er in de dataset voorkomen.

# %%
# Verzamel de unieke helden in een lijst.
helden = np.unique(data)
print(f"Er zitten {len(helden)} unieke helden in de dataset.")
# Out:
# Er zitten 2220 unieke helden in de dataset.

# %% [markdown]
# We kunnen de helden ook alfabetisch afdrukken.

# %%
helden_alfabetisch = list(np.sort(helden))
for held in helden_alfabetisch[:20]:
    print(f"{held}")
# Out:
# 4-D MAN/MERCURIO
# A'YIN
# ABEL
# ABSORBING MAN/CARL C
# ACHEBE, REVEREND DOC
# ACHILLES II/HELMUT
# ADAM X
# ADAMS, CINDY
# ADAMS, NICOLE NIKKI
# ADORA
# ADVA
# ADVERSARY
# AENTAROS
# AGAMEMNON III/
# AGED GENGHIS
# AGEE, DR. AUBREY
# AGONY/
# AHAB/RORY CAMPBELL
# AHURA
# AINET

# %% [markdown]
# Om te weten in hoeveel strips twee helden met elkaar in contact komen, tellen we het aantal keer dat elk koppel voorkomt in de dataset. Merk op dat de volgorde waarin de namen van de helden in de dataset staan niet van belang is. Het koppel (Captain America, The Hulk) is hetzelfde als (The Hulk, Captain Amerika).

# %%
# Maak een dictionary die het aantal interacties per koppel helden bijhoudt.

# Initialiseer de dictionary.
interacties = {}

# Overloop alle heldenkoppels
for rij in data:
    # Sorteer de namen van het koppel zodat de volgorde niet uitmaakt.
    heldenpaar = tuple(sorted(rij))
    # Voeg het heldenpaar toe aan de dictionary of verhoog het aantal interacties.
    if heldenpaar in interacties:
        interacties[heldenpaar] += 1
    else:
        interacties[heldenpaar] = 1

# %% [markdown]
# Hieronder drukken we af hoe vaak de eerste 10 heldenparen voorkomen in de dataset.

# %%
for paar in list(interacties.keys())[:20]:
    print(f"{paar[0]} en {paar[1]} interageren {interacties[paar]} keer.")
# Out:
# 4-D MAN/MERCURIO en FURY, COL. NICHOLAS  interageren 1 keer.
# A'YIN en CAPTAIN BRITAIN/BRIA interageren 1 keer.
# A'YIN en NIGHTCRAWLER/KURT WA interageren 1 keer.
# ABEL en CANNONBALL II/SAM GU interageren 1 keer.
# ABSORBING MAN/CARL C en ROBERTSON, MARTHA interageren 1 keer.
# ABSORBING MAN/CARL C en MURDOCK, BATTLING JA interageren 1 keer.
# ABSORBING MAN/CARL C en VIZIER interageren 1 keer.
# ABSORBING MAN/CARL C en HERCULES [GREEK GOD] interageren 1 keer.
# ABSORBING MAN/CARL C en WASP/JANET VAN DYNE  interageren 2 keer.
# ABSORBING MAN/CARL C en PHARAOH RAMA-TUT interageren 1 keer.
# ABSORBING MAN/CARL C en GALACTUS/GALAN interageren 1 keer.
# ABSORBING MAN/CARL C en JAGRFELM [ASGARDIAN] interageren 1 keer.
# ABSORBING MAN/CARL C en QUASAR III/WENDELL V interageren 1 keer.
# ABSORBING MAN/CARL C en LIZARD/DR. CURTIS CO interageren 1 keer.
# ABSORBING MAN/CARL C en BALDER [ASGARDIAN] interageren 1 keer.
# ABSORBING MAN/CARL C en SHE-HULK/JENNIFER WA interageren 1 keer.
# ABSORBING MAN/CARL C en ENCHANTRESS/AMORA/HE interageren 1 keer.
# ABSORBING MAN/CARL C en EON interageren 1 keer.
# ACHEBE, REVEREND DOC en WASP/JANET VAN DYNE  interageren 1 keer.
# ACHEBE, REVEREND DOC en RASPUTIN, LUCIFER interageren 1 keer.

# %% [markdown]
# ## Een graaf opstellen
#
# Om een graaf te bouwen maken we gebruik van de networkx bibliotheek. Deze bibliotheek maakt het gemakkelijk om analyses te doen op grafen.

# %% [markdown]
# Eerst en vooral maken we een graafobject aan. Aan dit object gaan we onze knopen en bogen toevoegen.

# %%
# Maak een graafobject aan.
graaf = nx.Graph()

# %% [markdown]
# We kunnen op een eenvoudige manier onze helden toevoegen als knopen aan de graaf. Daarvoor gebruiken we de functie `add_nodes_from`. We geven een lijst mee aan deze functie. De functie zal dan voor elk element uit de lijst een knoop toevoegen.

# %%
# Voeg de helden toe als knopen.
graaf.add_nodes_from(helden)

# %% [markdown]
# Nu moeten we enkel nog de bogen toevoegen aan de graaf. Daarvoor kunnen we onze dictionary met interacties gebruiken. Elke interactie komt overeen met een boog tussen de knopen van de twee helden in het paar. Het gewicht van de boog is het aantal interacties die dat paar heeft.

# %%
# Voeg de interacties toe als gewogen bogen.
for paar in interacties:
    graaf.add_edge(paar[0], paar[1], weight=interacties[paar])

# %% [markdown]
# ## Influencers opsporen
#
# Zoals je eerder in het leerpad zag, kan je belangrijke mensen in een sociaal netwerk opsporen aan de hand van hun **graadcentraliteit**. Networkx heeft een eenvoudige methode om de graadcentraliteit van elke knoop te bepalen. Onderstaande code drukt de 10 helden af met hoogste graadcentraliteit.

# %%
graadcentraliteit = nx.degree_centrality(graaf)
gesorteerde_graadcentraliteit = sorted(graadcentraliteit.items(), key=lambda x: x[1], reverse=True)

for held, graad in gesorteerde_graadcentraliteit[:10]:
    print(f"{held} heeft een graadcentraliteit van {graad}.")
# Out:
# CAPTAIN AMERICA heeft een graadcentraliteit van 0.050473186119873815.
# SPIDER-MAN/PETER PAR heeft een graadcentraliteit van 0.04281207751239297.
# IRON MAN/TONY STARK  heeft een graadcentraliteit van 0.041910770617395225.
# WOLVERINE/LOGAN  heeft een graadcentraliteit van 0.039206849932401984.
# THING/BENJAMIN J. GR heeft een graadcentraliteit van 0.035601622352410996.
# THOR/DR. DONALD BLAK heeft een graadcentraliteit van 0.03334835511491663.
# VISION  heeft een graadcentraliteit van 0.03334835511491663.
# INVISIBLE WOMAN/SUE  heeft een graadcentraliteit van 0.03199639477242001.
# PROFESSOR X/CHARLES  heeft een graadcentraliteit van 0.031545741324921134.
# CYCLOPS/SCOTT SUMMER heeft een graadcentraliteit van 0.03064443442992339.

# %% [markdown]
# **Opdracht**: Naast graadcentraliteit kan je ook de eigenwaardecentraliteit bepalen met de functie `eigenvector_centrality`. Gebruik onderstaande codecel om de 10 populairste helden af te drukken volgens eigenwaardecentraliteit.

# %%
eigenwaardecentraliteit = nx.eigenvector_centrality(graaf)
gesorteerde_eigenwaardecentraliteit = sorted(eigenwaardecentraliteit.items(), key=lambda x: x[1], reverse=True)

for held, graad in gesorteerde_eigenwaardecentraliteit [:10]:
    print(f"{held} heeft een eigenwaardecentraliteit van {graad}.")
# Out:
# CAPTAIN AMERICA heeft een eigenwaardecentraliteit van 0.22623967278691517.
# THING/BENJAMIN J. GR heeft een eigenwaardecentraliteit van 0.20405164905465953.
# THOR/DR. DONALD BLAK heeft een eigenwaardecentraliteit van 0.1847508966981997.
# SPIDER-MAN/PETER PAR heeft een eigenwaardecentraliteit van 0.1769924765281653.
# VISION  heeft een eigenwaardecentraliteit van 0.17352137811323107.
# IRON MAN/TONY STARK  heeft een eigenwaardecentraliteit van 0.16980993569018116.
# SCARLET WITCH/WANDA  heeft een eigenwaardecentraliteit van 0.16792818393718284.
# WOLVERINE/LOGAN  heeft een eigenwaardecentraliteit van 0.1584441117403304.
# MR. FANTASTIC/REED R heeft een eigenwaardecentraliteit van 0.15749802704553423.
# ANT-MAN/DR. HENRY J. heeft een eigenwaardecentraliteit van 0.15694266580050986.

# %% [markdown]
# **Opdracht**: Vergelijk de populairste helden volgens eigenwaarde- en graadcentraliteit. Welke verschillen zie je?

# %% [markdown]
# ## Spreiding van het netwerk
#
# De spreiding van het netwerk is de maximale kortste afstand tussen elke twee helden in het netwerk. Voor elk paar van knopen berekenen we met het algoritme van Dijkstra de lengte van het kortste pad tussen deze twee knopen. Van al deze afstanden nemen we de langste afstand als *diameter* van het netwerk. Deze diameter zegt ons iets over hoe uitgespreid het netwerk is. Hoe kleiner de diameter, hoe sterker de knopen in het netwerk met elkaar verbonden zijn.

# %% [markdown]
# **Merk op dat de code in de volgende cel veel tijd in beslag kan nemen. De computer moet immers de afstand berekenen tussen elk paar knopen in de graaf er zijn zo'n 2220 x 2220 = 4928400 mogelijke paren.**

# %%
# Calculate the maximal shortest path between any two nodes
diameter = nx.diameter(graaf)
print(f"The diameter van de graaf is {diameter}")
# Out:
# The diameter van de graaf is 13

# %% [markdown]
# ## Communities zoeken
#
# Naast de influencers in het netwerk en de spreiding van het netwerk, kunnen we ook op zoek gaan naar communities binnen het netwerk. In een sociaal netwerk komt een community vaak overeen met een specifieke vriendengroep. Bijvoorbeeld mensen die elkaar kennen van in de sportclub.

# %% [markdown]
# Om communities te detecteren maken we gebruik van de Louvain methode. Dit is een algoritme die stapsgewijs op zoek zal gaan naar communities binnen het netwerk. Dit doet het algoritme door de *modulariteit* van het netwerk te berekenen en deze stap voor stap te maximaliseren. Hier gebruiken we een speciale bibliotheek die al een implementatie van het algoritme bevat.

# %% [markdown]
# Eerst installeren we de bibliotheek.

# %%
# !pip install python-louvain
# Out:
# Collecting python-louvain
#   Using cached python_louvain-0.16-py3-none-any.whl
# Requirement already satisfied: networkx in c:\users\tomne\documents\work\applications\pythonnotebooks\.venv\lib\site-packages (from python-louvain) (3.4.2)
# Requirement already satisfied: numpy in c:\users\tomne\documents\work\applications\pythonnotebooks\.venv\lib\site-packages (from python-louvain) (2.0.2)
# Installing collected packages: python-louvain
# Successfully installed python-louvain-0.16

# %% [markdown]
# Dan importeren we de bibliotheek.

# %%
import community

# %% [markdown]
# Met deze bibliotheek kunnen we op een eenvoudige manier op zoek gaan naar "vriendengroepen" in ons netwerk.

# %%
vriendengroepen = community.best_partition(graaf)

# %% [markdown]
# Eerst en vooral bekijken we hoeveel vriendengroepen het algoritme gevonden heeft.

# %%
# Druk het aantal vriendengroepen in het netwerk af.
print(f"Er zijn {len(set(vriendengroepen.values()))} vriendengroepen in het netwerk.")
# Out:
# Er zijn 35 vriendengroepen in het netwerk.

# %% [markdown]
# We kunnen ook bekijken hoeveel helden in elke vriendengroep zitten.

# %%
# Druk voor elke vriendengroep het aantal leden af.
for vriendengroep in set(vriendengroepen.values()):
    leden = [held for held, groep in vriendengroepen.items() if groep == vriendengroep]
    print(f"Vriendengroep {vriendengroep} heeft {len(leden)} leden.")
# Out:
# Vriendengroep 0 heeft 85 leden.
# Vriendengroep 1 heeft 463 leden.
# Vriendengroep 2 heeft 349 leden.
# Vriendengroep 3 heeft 216 leden.
# Vriendengroep 4 heeft 59 leden.
# Vriendengroep 5 heeft 8 leden.
# Vriendengroep 6 heeft 148 leden.
# Vriendengroep 7 heeft 141 leden.
# Vriendengroep 8 heeft 5 leden.
# Vriendengroep 9 heeft 76 leden.
# Vriendengroep 10 heeft 82 leden.
# Vriendengroep 11 heeft 5 leden.
# Vriendengroep 12 heeft 41 leden.
# Vriendengroep 13 heeft 100 leden.
# Vriendengroep 14 heeft 71 leden.
# Vriendengroep 15 heeft 25 leden.
# Vriendengroep 16 heeft 20 leden.
# Vriendengroep 17 heeft 8 leden.
# Vriendengroep 18 heeft 4 leden.
# Vriendengroep 19 heeft 3 leden.
# Vriendengroep 20 heeft 114 leden.
# Vriendengroep 21 heeft 18 leden.
# Vriendengroep 22 heeft 42 leden.
# Vriendengroep 23 heeft 9 leden.
# Vriendengroep 24 heeft 3 leden.
# Vriendengroep 25 heeft 41 leden.
# Vriendengroep 26 heeft 6 leden.
# Vriendengroep 27 heeft 16 leden.
# Vriendengroep 28 heeft 16 leden.
# Vriendengroep 29 heeft 18 leden.
# Vriendengroep 30 heeft 9 leden.
# Vriendengroep 31 heeft 4 leden.
# Vriendengroep 32 heeft 4 leden.
# Vriendengroep 33 heeft 5 leden.
# Vriendengroep 34 heeft 6 leden.

# %% [markdown]
# Om de populairste helden in elke vriendengroep te vinden, kunnen we de helden binnen een vriendengroep rangschikken volgens graadcentraliteit. Onderstaande cel drukt voor elke vriendengroep de 5 populairste helden af.

# %%
# Druk de eerste 5 leden van elke vriendengroep af gerangschikt volgens graadcentraliteit.
for vriendengroep in set(vriendengroepen.values()):
    leden = [held for held, groep in vriendengroepen.items() if groep == vriendengroep]
    graadcentraliteit_van_leden = {held: graadcentraliteit[held] for held in leden}
    gesorteerde_leden = sorted(graadcentraliteit_van_leden.items(), key=lambda x: x[1], reverse=True)
    print(f"Vriendengroep {vriendengroep} heeft de volgende top 5 leden:")
    for held, graad in gesorteerde_leden[:5]:
        print(f"    - {held} met een graadcentraliteit van {graad}.")
# Out:
# Vriendengroep 0 heeft de volgende top 5 leden:
#     - FURY, COL. NICHOLAS  met een graadcentraliteit van 0.018026137899954935.
#     - MOON KNIGHT/MARC SPE met een graadcentraliteit van 0.008562415502478594.
#     - DUGAN, TIMOTHY ALOYI met een graadcentraliteit van 0.005858494817485354.
#     - DEATH met een graadcentraliteit van 0.005407841369986481.
#     - PUNISHER II/FRANK CA met een graadcentraliteit van 0.005407841369986481.
# Vriendengroep 1 heeft de volgende top 5 leden:
#     - WOLVERINE/LOGAN  met een graadcentraliteit van 0.039206849932401984.
#     - PROFESSOR X/CHARLES  met een graadcentraliteit van 0.031545741324921134.
#     - CYCLOPS/SCOTT SUMMER met een graadcentraliteit van 0.03064443442992339.
#     - BEAST/HENRY &HANK& P met een graadcentraliteit van 0.02794051374493015.
#     - STORM/ORORO MUNROE S met een graadcentraliteit van 0.027039206849932402.
# Vriendengroep 2 heeft de volgende top 5 leden:
#     - CAPTAIN AMERICA met een graadcentraliteit van 0.050473186119873815.
#     - IRON MAN/TONY STARK  met een graadcentraliteit van 0.041910770617395225.
#     - VISION  met een graadcentraliteit van 0.03334835511491663.
#     - SCARLET WITCH/WANDA  met een graadcentraliteit van 0.028841820639927896.
#     - WASP/JANET VAN DYNE  met een graadcentraliteit van 0.028391167192429023.
# Vriendengroep 3 heeft de volgende top 5 leden:
#     - SPIDER-MAN/PETER PAR met een graadcentraliteit van 0.04281207751239297.
#     - JAMESON, J. JONAH met een graadcentraliteit van 0.022082018927444796.
#     - ROBERTSON, JOE met een graadcentraliteit van 0.014420910319963948.
#     - WATSON-PARKER, MARY  met een graadcentraliteit van 0.014420910319963948.
#     - PARKER, MAY met een graadcentraliteit van 0.010815682739972961.
# Vriendengroep 4 heeft de volgende top 5 leden:
#     - HULK/DR. ROBERT BRUC met een graadcentraliteit van 0.02658855340243353.
#     - JONES, RICHARD MILHO met een graadcentraliteit van 0.010815682739972961.
#     - BANNER, BETTY ROSS T met een graadcentraliteit van 0.005858494817485354.
#     - ETERNITY/ADAM QADMON met een graadcentraliteit van 0.004506534474988734.
#     - ROSS, GEN. THADDEUS  met een graadcentraliteit van 0.004506534474988734.
# Vriendengroep 5 heeft de volgende top 5 leden:
#     - MALICE V/NAKIA met een graadcentraliteit van 0.0018026137899954935.
#     - DARLA met een graadcentraliteit van 0.0013519603424966202.
#     - OKOYE met een graadcentraliteit van 0.0013519603424966202.
#     - ADAMS, NICOLE NIKKI met een graadcentraliteit van 0.0009013068949977468.
#     - COCKROACH/ met een graadcentraliteit van 0.0004506534474988734.
# Vriendengroep 6 heeft de volgende top 5 leden:
#     - THING/BENJAMIN J. GR met een graadcentraliteit van 0.035601622352410996.
#     - INVISIBLE WOMAN/SUE  met een graadcentraliteit van 0.03199639477242001.
#     - MR. FANTASTIC/REED R met een graadcentraliteit van 0.029743127534925643.
#     - HUMAN TORCH/JOHNNY S met een graadcentraliteit van 0.02929247408742677.
#     - GORGON [INHUMAN] met een graadcentraliteit van 0.012618296529968454.
# Vriendengroep 7 heeft de volgende top 5 leden:
#     - THOR/DR. DONALD BLAK met een graadcentraliteit van 0.03334835511491663.
#     - HERCULES [GREEK GOD] met een graadcentraliteit van 0.023433979269941417.
#     - BALDER [ASGARDIAN] met een graadcentraliteit van 0.013519603424966201.
#     - LOKI [ASGARDIAN] met een graadcentraliteit van 0.01216764308246958.
#     - ODIN [ASGARDIAN] met een graadcentraliteit van 0.010365029292474088.
# Vriendengroep 8 heeft de volgende top 5 leden:
#     - BLAQUESMITH met een graadcentraliteit van 0.0013519603424966202.
#     - MERRYWEATHER, IRENE met een graadcentraliteit van 0.0013519603424966202.
#     - SHIRE, DR. RANDALL met een graadcentraliteit van 0.0009013068949977468.
#     - AENTAROS met een graadcentraliteit van 0.0004506534474988734.
#     - WALL/ met een graadcentraliteit van 0.0004506534474988734.
# Vriendengroep 9 heeft de volgende top 5 leden:
#     - DR. STRANGE/STEPHEN  met een graadcentraliteit van 0.020279405137449302.
#     - SILVER SURFER/NORRIN met een graadcentraliteit van 0.011716989634970709.
#     - MOONDRAGON/HEATHER D met een graadcentraliteit van 0.011266336187471835.
#     - NORRISS, SISTER BARB met een graadcentraliteit van 0.008562415502478594.
#     - WONG met een graadcentraliteit van 0.007210455159981974.
# Vriendengroep 10 heeft de volgende top 5 leden:
#     - SASQUATCH/WALTER LAN met een graadcentraliteit van 0.012618296529968454.
#     - HUDSON, HEATHER met een graadcentraliteit van 0.008562415502478594.
#     - NORTHSTAR/JEAN-PAUL  met een graadcentraliteit van 0.0067598017124831005.
#     - PUCK/EUGENE MILTON J met een graadcentraliteit van 0.0067598017124831005.
#     - SHAMAN/MICHAEL TWOYO met een graadcentraliteit van 0.006309148264984227.
# Vriendengroep 11 heeft de volgende top 5 leden:
#     - LEBEAU, JEAN-LUC met een graadcentraliteit van 0.0013519603424966202.
#     - X-CUTIONER/CARL DENT met een graadcentraliteit van 0.0013519603424966202.
#     - POITIER, CLAUDE met een graadcentraliteit van 0.0009013068949977468.
#     - ALOUETTE, GENARD met een graadcentraliteit van 0.0004506534474988734.
#     - BOUDREAUX, MARIUS met een graadcentraliteit van 0.0004506534474988734.
# Vriendengroep 12 heeft de volgende top 5 leden:
#     - DIAMONDBACK II/RACHE met een graadcentraliteit van 0.005407841369986481.
#     - ANACONDA/BLANCHE SIT met een graadcentraliteit van 0.0031545741324921135.
#     - BEYONDER met een graadcentraliteit van 0.0031545741324921135.
#     - COBRA/KLAUS VORHEES met een graadcentraliteit van 0.0031545741324921135.
#     - BOOMSLANG/ met een graadcentraliteit van 0.0027039206849932404.
# Vriendengroep 13 heeft de volgende top 5 leden:
#     - SCREAMING MIMI/MELIS met een graadcentraliteit van 0.0067598017124831005.
#     - MOONSTONE II/KARLA S met een graadcentraliteit van 0.006309148264984227.
#     - POWER MAN/ERIK JOSTE met een graadcentraliteit van 0.006309148264984227.
#     - COOPER, DR. VALERIE met een graadcentraliteit van 0.005858494817485354.
#     - SITWELL, JASPER met een graadcentraliteit van 0.004506534474988734.
# Vriendengroep 14 heeft de volgende top 5 leden:
#     - DAREDEVIL/MATT MURDO met een graadcentraliteit van 0.01892744479495268.
#     - NELSON, FRANKLIN FOG met een graadcentraliteit van 0.00946372239747634.
#     - BARON STRUCKER/WOLFG met een graadcentraliteit van 0.00405588102748986.
#     - GHOST RIDER II/JOHNN met een graadcentraliteit van 0.00405588102748986.
#     - PAGE, KAREN met een graadcentraliteit van 0.0031545741324921135.
# Vriendengroep 15 heeft de volgende top 5 leden:
#     - MAKKARI/MIKE KHARY/I met een graadcentraliteit van 0.005858494817485354.
#     - ARBOGAST, BAMBI met een graadcentraliteit van 0.00405588102748986.
#     - THENA met een graadcentraliteit van 0.0031545741324921135.
#     - UNUSCIONE met een graadcentraliteit van 0.0018026137899954935.
#     - ZURAS met een graadcentraliteit van 0.0018026137899954935.
# Vriendengroep 16 heeft de volgende top 5 leden:
#     - DR. SPECTRUM/JOSEPH  met een graadcentraliteit van 0.003605227579990987.
#     - POWER PRINCESS/ZARDA met een graadcentraliteit van 0.003605227579990987.
#     - HYPERION met een graadcentraliteit van 0.0031545741324921135.
#     - NIGHTHAWK/KYLE RICHM met een graadcentraliteit van 0.002253267237494367.
#     - OVERMIND/GROM met een graadcentraliteit van 0.002253267237494367.
# Vriendengroep 17 heeft de volgende top 5 leden:
#     - YELLOWJACKET II/RITA met een graadcentraliteit van 0.002253267237494367.
#     - SNAPDRAGON/SHEOKE SA met een graadcentraliteit van 0.0018026137899954935.
#     - ARCLIGHT/PHILLIPA SO met een graadcentraliteit van 0.0013519603424966202.
#     - IRON MAIDEN/ met een graadcentraliteit van 0.0009013068949977468.
#     - MINDBLAST met een graadcentraliteit van 0.0009013068949977468.
# Vriendengroep 18 heeft de volgende top 5 leden:
#     - ERISHKIGEL II/HOLLY  met een graadcentraliteit van 0.0018026137899954935.
#     - ARISHEM [CELESTIAL] met een graadcentraliteit van 0.0004506534474988734.
#     - PUENTES, DONNA MARIA met een graadcentraliteit van 0.0004506534474988734.
#     - SOUL-EATER met een graadcentraliteit van 0.0004506534474988734.
# Vriendengroep 19 heeft de volgende top 5 leden:
#     - MISS AMERICA/MADELIN met een graadcentraliteit van 0.0027039206849932404.
#     - PATRIOT/JEFF MACE met een graadcentraliteit van 0.0027039206849932404.
#     - U-MAN/MERRANO met een graadcentraliteit van 0.0004506534474988734.
# Vriendengroep 20 heeft de volgende top 5 leden:
#     - NOVA/RICHARD RIDER met een graadcentraliteit van 0.015322217214961695.
#     - FIRESTAR/ANGELICA JO met een graadcentraliteit van 0.013068949977467327.
#     - NAMORITA/NITA PRENTI met een graadcentraliteit van 0.011716989634970709.
#     - NIGHT THRASHER/DUANE met een graadcentraliteit van 0.009914375844975214.
#     - JUSTICE II/VANCE AST met een graadcentraliteit van 0.00946372239747634.
# Vriendengroep 21 heeft de volgende top 5 leden:
#     - KA-ZAR/KEVIN PLUNDER met een graadcentraliteit van 0.008562415502478594.
#     - ZABU met een graadcentraliteit van 0.004506534474988734.
#     - SHANNA/SHANNA O'HARA met een graadcentraliteit van 0.0031545741324921135.
#     - DEVIL-SLAYER/ERIC SI met een graadcentraliteit van 0.0018026137899954935.
#     - KINCAID, DR. KEITH met een graadcentraliteit van 0.0013519603424966202.
# Vriendengroep 22 heeft de volgende top 5 leden:
#     - JUBILEE/JUBILATION L met een graadcentraliteit van 0.009013068949977467.
#     - WHITE QUEEN/EMMA FRO met een graadcentraliteit van 0.0076611086074808476.
#     - CHAMBER/JONOTHON STA met een graadcentraliteit van 0.004506534474988734.
#     - SKIN/ANGELO ESPINOSA met een graadcentraliteit van 0.004506534474988734.
#     - PENANCE/MONET ST. CR met een graadcentraliteit van 0.00405588102748986.
# Vriendengroep 23 heeft de volgende top 5 leden:
#     - BAZIN, PHILLIPPE met een graadcentraliteit van 0.0018026137899954935.
#     - POWELL, GRACE met een graadcentraliteit van 0.0018026137899954935.
#     - POWELL, JONATHAN met een graadcentraliteit van 0.0013519603424966202.
#     - PORTAL/CHARLES LITTL met een graadcentraliteit van 0.0009013068949977468.
#     - COLON, CHERYL met een graadcentraliteit van 0.0004506534474988734.
# Vriendengroep 24 heeft de volgende top 5 leden:
#     - BLACKWING/JOSEPH MAN met een graadcentraliteit van 0.0009013068949977468.
#     - MOTHER NIGHT/SUSAN S met een graadcentraliteit van 0.0009013068949977468.
#     - BENWAY, DR. met een graadcentraliteit van 0.0004506534474988734.
# Vriendengroep 25 heeft de volgende top 5 leden:
#     - IRON MAN IV/JAMES R. met een graadcentraliteit van 0.009914375844975214.
#     - HOGAN, VIRGINIA PEPP met een graadcentraliteit van 0.004957187922487607.
#     - HOGAN, HAROLD J. HAP met een graadcentraliteit van 0.00405588102748986.
#     - O'BRIEN, MICHAEL met een graadcentraliteit van 0.003605227579990987.
#     - CABE, BETHANY met een graadcentraliteit van 0.002253267237494367.
# Vriendengroep 26 heeft de volgende top 5 leden:
#     - KRAVEN THE HUNTER/SE met een graadcentraliteit van 0.002253267237494367.
#     - PEATOR met een graadcentraliteit van 0.0013519603424966202.
#     - TARANTULA/ANTON MIGU met een graadcentraliteit van 0.0013519603424966202.
#     - HOCHBERG, ROGER met een graadcentraliteit van 0.0009013068949977468.
#     - PIXIE/ [ETERNAL] met een graadcentraliteit van 0.0009013068949977468.
# Vriendengroep 27 heeft de volgende top 5 leden:
#     - ICE-MAN | MUTANT X-V met een graadcentraliteit van 0.0018026137899954935.
#     - BLOODSTORM | MUTANT  met een graadcentraliteit van 0.0013519603424966202.
#     - ELEKTRA | MUTANT X-V met een graadcentraliteit van 0.0013519603424966202.
#     - FALLEN | MUTANT X-VE met een graadcentraliteit van 0.0013519603424966202.
#     - MAGNETO | MUTANT X-V met een graadcentraliteit van 0.0013519603424966202.
# Vriendengroep 28 heeft de volgende top 5 leden:
#     - ROM, SPACEKNIGHT met een graadcentraliteit van 0.0027039206849932404.
#     - MACHINE MAN/X-51 met een graadcentraliteit van 0.002253267237494367.
#     - TORPEDO III/BROCK JO met een graadcentraliteit van 0.002253267237494367.
#     - HARRIS, EDDIE met een graadcentraliteit van 0.0018026137899954935.
#     - JONES, DANIEL DANNY met een graadcentraliteit van 0.0018026137899954935.
# Vriendengroep 29 heeft de volgende top 5 leden:
#     - SHROUD/MAXIMILLIAN Q met een graadcentraliteit van 0.002253267237494367.
#     - DRUMM, JERICHO met een graadcentraliteit van 0.0018026137899954935.
#     - NEEDLE met een graadcentraliteit van 0.0018026137899954935.
#     - WEREWOLF BY NIGHT/JA met een graadcentraliteit van 0.0018026137899954935.
#     - BROTHER VOODOO/DANIE met een graadcentraliteit van 0.0013519603424966202.
# Vriendengroep 30 heeft de volgende top 5 leden:
#     - CORTEZ, FABIAN met een graadcentraliteit van 0.0018026137899954935.
#     - MAN-BEAST met een graadcentraliteit van 0.0018026137899954935.
#     - OMEGA RED/ARKADY ROS met een graadcentraliteit van 0.0018026137899954935.
#     - VOGHT, AMELIA met een graadcentraliteit van 0.0018026137899954935.
#     - URSULA, LADY met een graadcentraliteit van 0.0013519603424966202.
# Vriendengroep 31 heeft de volgende top 5 leden:
#     - CANDRA met een graadcentraliteit van 0.0018026137899954935.
#     - CONOWAY, SEKMEHT met een graadcentraliteit van 0.0004506534474988734.
#     - LEBEAU, JACQUE met een graadcentraliteit van 0.0004506534474988734.
#     - MARCEAUX, BELIZE met een graadcentraliteit van 0.0004506534474988734.
# Vriendengroep 32 heeft de volgende top 5 leden:
#     - QUICKSAND met een graadcentraliteit van 0.0013519603424966202.
#     - GRIFFITH, D.W. met een graadcentraliteit van 0.0009013068949977468.
#     - FEROCIA/ met een graadcentraliteit van 0.0004506534474988734.
#     - WRANGLER/ met een graadcentraliteit van 0.0004506534474988734.
# Vriendengroep 33 heeft de volgende top 5 leden:
#     - WHYTE, HARMONY (HARM met een graadcentraliteit van 0.002253267237494367.
#     - WING, COLLEEN met een graadcentraliteit van 0.002253267237494367.
#     - FIREFLY met een graadcentraliteit van 0.0004506534474988734.
#     - HUNCH met een graadcentraliteit van 0.0004506534474988734.
#     - MEACHUM, JOY met een graadcentraliteit van 0.0004506534474988734.
# Vriendengroep 34 heeft de volgende top 5 leden:
#     - LEVIN, MAJOR DEBRA met een graadcentraliteit van 0.0018026137899954935.
#     - KONIEV, DMITRI met een graadcentraliteit van 0.0009013068949977468.
#     - VAZHIN, ALEXEI MIKHA met een graadcentraliteit van 0.0009013068949977468.
#     - KILLIAN met een graadcentraliteit van 0.0004506534474988734.
#     - KURASOV, SIMYON BORI met een graadcentraliteit van 0.0004506534474988734.

# %% [markdown]
# **Opdracht:** Bekijk de uitvoer van bovenstaande cel. Hoe worden de vriendengroepen volgens jou gegroepeerd? Begrijp je waarom deze helden in dezelfde vriendengroep zitten?

# %% [markdown]
# # Partners
#
# Dit materiaal werd ontwikkeld door Dwengo vzw en kwam tot stand met steun van VLAIO. Vind al het materiaal van ons wAIsda project op [dwengo.org/waisda](dwengo.org/waisda)
#
# !["VLAIO logo"](img/vlaio.png)
#
# !["Dwengo logo"](img/dwengo-groen-zwart.png)
